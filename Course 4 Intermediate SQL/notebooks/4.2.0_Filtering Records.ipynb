# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../../../") 

from utils.paths import make_dir_line

modality = 'c'
project = 'Intermediate SQL'
data = make_dir_line(modality, project)

raw = data('raw')

# %%
import sqlite3

conn = sqlite3.connect(":memory:")  ## aca se indica el nombre de la db.
cur = conn.cursor()

# %% [markdown]
# # 4.2.0 Filtering Records

# %%
conn.executescript(
    """
DROP TABLE IF EXISTS films;

CREATE TABLE films (
    id            INT,
    title         STRING,
    release_year  INT,
    country       STRING,
    duration      INT,
    language      STRING,
    certification STRING,
    gross         DOUBLE,
    budget        DOUBLE
);

DROP TABLE IF EXISTS people;

CREATE TABLE people (
    id        INT,
    name      STRING,
    birthdate STRING,
    deathdate STRING
);

DROP TABLE IF EXISTS reviews;

CREATE TABLE reviews (
    id             INT,
    film_id        INT,
    num_user       INT,
    num_critic     INT,
    imdb_score     DOUBLE,
    num_votes      DOUBLE,
    facebook_likes DOUBLE
);

DROP TABLE IF EXISTS roles;

CREATE TABLE roles (
    id        INT,
    film_id   INT,
    person_id INT,
    role      STRING
);

"""
)
conn.commit()

# %%
df = pd.read_csv(raw / 'films.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','title','release_year','country','duration','language','certification','gross','budget']
films = list(zip(df.id, df.title, df.release_year, df.country, df.duration, df.language, df.certification, df.gross, df.budget))
cur.executemany("INSERT INTO films VALUES  (?,?,?,?,?,?,?,?,?)", films)

# %%
df = pd.read_csv(raw / 'people.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','name','birthdate','deathdate']
people = list(zip(df.id, df.name, df.birthdate, df.deathdate))
cur.executemany("INSERT INTO people VALUES  (?,?,?,?)", people)

# %%
df = pd.read_csv(raw / 'reviews.csv', sep = ',', decimal = '.', header = 0, encoding = 'utf-8')
df.columns = ['id','film_id','num_user','num_critic','imdb_score','num_votes','facebook_likes']
df = df.loc[:,['id','film_id','num_user','num_critic','imdb_score','num_votes','facebook_likes']]
reviews = list(zip(df.id, df.film_id, df.num_user, df.num_critic, df.imdb_score, df.num_votes, df.facebook_likes))
cur.executemany("INSERT INTO reviews VALUES  (?,?,?,?,?,?,?)", reviews)

# %%
df = pd.read_csv(raw / 'roles.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','film_id','person_id','role']
roles = list(zip(df.id, df.film_id, df.person_id, df.role))
cur.executemany("INSERT INTO roles VALUES  (?,?,?,?)", roles)

# %% [markdown]
# ## 0.2.2 Filtering results

# %%
# -- What does the following query return?
cur.execute("""
            
            SELECT title 
            FROM films 
            WHERE release_year > 2000;
            
            """).fetchall()
# Out:
# [('15 Minutes',),
#  ('3000 Miles to Graceland',),
#  ('A Beautiful Mind',),
#  ("A Knight's Tale",),
#  ('A.I. Artificial Intelligence',),
#  ('Ali',),
#  ('Alias Betty',),
#  ("All the Queen's Men",),
#  ('Along Came a Spider',),
#  ('AmÃ©lie',),
#  ("America's Sweethearts",),
#  ('American Desi',),
#  ('American Outlaws',),
#  ('American Pie 2',),
#  ('Angel Eyes',),
#  ('Antitrust',),
#  ('Atlantis: The Lost Empire',),
#  ('Ayurveda: Art of Being',),
#  ('Baby Boy',),
#  ('Bandits',),
#  ('Behind Enemy Lines',),
#  ('Birthday Girl',),
#  ('Black Hawk Down',),
#  ('Black Knight',),
#  ('Blow',),
#  ("Bridget Jones's Diary",),
#  ('Brigham City',),
#  ('Bubble Boy',),
#  ('Buffalo Soldiers',),
#  ('Bully',),
#  ("Captain Corelli's Mandolin",),
#  ('Cats & Dogs',),
#  ('Corky Romano',),
#  ('Crazy/Beautiful',),
#  ('Crocodile Dundee in Los Angeles',),
#  ('Dogtown and Z-Boys',),
#  ('Domestic Disturbance',),
#  ("Don't Say a Word",),
#  ('Donnie Darko',),
#  ('Double Take',),
#  ('Down and Out with the Dolls',),
#  ('Down to Earth',),
#  ('Dr. Dolittle 2',),
#  ('Driven',),
#  ('Elling',),
#  ('Enemy at the Gates',),
#  ('Exit Wounds',),
#  ('Final Fantasy: The Spirits Within',),
#  ('Formula 51',),
#  ('Frailty',),
#  ('Freddy Got Fingered',),
#  ('From Hell',),
#  ('From Hell',),
#  ('Get Over It',),
#  ('Ghost World',),
#  ('Ghosts of Mars',),
#  ('Glitter',),
#  ('Gosford Park',),
#  ('Hardball',),
#  ("Harry Potter and the Sorcerer's Stone",),
#  ('Harvard Man',),
#  ('Head Over Heels',),
#  ('Heartbreakers',),
#  ('Hearts in Atlantis',),
#  ('Hedwig and the Angry Inch',),
#  ('High Heels and Low Lifes',),
#  ('How High',),
#  ('I Am Sam',),
#  ('Impostor',),
#  ('In the Bedroom',),
#  ('Iris',),
#  ('Jason X',),
#  ('Jay and Silent Bob Strike Back',),
#  ('Jeepers Creepers',),
#  ('Jimmy Neutron: Boy Genius',),
#  ('Joe Dirt',),
#  ('Joe Somebody',),
#  ('Josie and the Pussycats',),
#  ('Joy Ride',),
#  ('Jurassic Park III',),
#  ('Just Visiting',),
#  ('K-PAX',),
#  ('Kate & Leopold',),
#  ('Kiss of the Dragon',),
#  ('Kissing Jessica Stein',),
#  ('Knockaround Guys',),
#  ('L.I.E.',),
#  ('Lara Croft: Tomb Raider',),
#  ('Last Orders',),
#  ('Legally Blonde',),
#  ('Life as a House',),
#  ('Lovely & Amazing',),
#  ('Lucky Break',),
#  ('Made',),
#  ('Madison',),
#  ("Max Keeble's Big Move",),
#  ('Mean Machine',),
#  ('Megiddo: The Omega Code 2',),
#  ('Monkeybone',),
#  ('Monsoon Wedding',),
#  ("Monster's Ball",),
#  ('Monsters, Inc.',),
#  ('Moulin Rouge!',),
#  ('Mulholland Drive',),
#  ('Never Again',),
#  ('Not Another Teen Movie',),
#  ('Novocaine',),
#  ('Nowhere in Africa',),
#  ('O',),
#  ('O',),
#  ("Ocean's Eleven",),
#  ('On the Line',),
#  ('Original Sin',),
#  ('Osmosis Jones',),
#  ('Out Cold',),
#  ('Pearl Harbor',),
#  ('Planet of the Apes',),
#  ('Planet of the Apes',),
#  ('Pootie Tang',),
#  ('Rat Race',),
#  ("Recess: School's Out",),
#  ('Riding in Cars with Boys',),
#  ('Rock Star',),
#  ('Rush Hour 2',),
#  ('Save the Last Dance',),
#  ('Saving Silverman',),
#  ("Say It Isn't So",),
#  ('Scary Movie 2',),
#  ('See Spot Run',),
#  ('Serendipity',),
#  ('Session 9',),
#  ('Shallow Hal',),
#  ('Shaolin Soccer',),
#  ('Shrek',),
#  ('Someone Like You...',),
#  ('Soul Survivors',),
#  ('Spirited Away',),
#  ('Spy Game',),
#  ('Spy Kids',),
#  ('Summer Catch',),
#  ('Super Troopers',),
#  ('Sweet November',),
#  ('Swordfish',),
#  ('Texas Rangers',),
#  ('The Animal',),
#  ('The Believer',),
#  ('The Brothers',),
#  ('The Business of Strangers',),
#  ("The Caveman's Valentine",),
#  ('The Curse of the Jade Scorpion',),
#  ('The Fast and the Furious',),
#  ('The Fast and the Furious',),
#  ('The Fast and the Furious',),
#  ('The Forsaken',),
#  ('The Glass House',),
#  ('The Jimmy Show',),
#  ('The Last Castle',),
#  ('The Legend of Suriyothai',),
#  ('The Lord of the Rings: The Fellowship of the Ring',),
#  ('The Lost Skeleton of Cadavra',),
#  ('The Majestic',),
#  ('The Mexican',),
#  ('The Mummy Returns',),
#  ('The Musketeer',),
#  ('The One',),
#  ('The Other Side of Heaven',),
#  ('The Others',),
#  ('The Pledge',),
#  ('The Princess Diaries',),
#  ('The Royal Tenenbaums',),
#  ('The Score',),
#  ('The Shipping News',),
#  ('The Tailor of Panama',),
#  ('The Wash',),
#  ('The Wedding Planner',),
#  ('Thir13en Ghosts',),
#  ('Thirteen Conversations About One Thing',),
#  ('Tomcats',),
#  ('Town & Country',),
#  ('Training Day',),
#  ('Two Can Play That Game',),
#  ('Valentine',),
#  ('Vanilla Sky',),
#  ('Wasabi',),
#  ("What's the Worst That Could Happen?",),
#  ('Winged Migration',),
#  ('Y Tu MamÃ¡ TambiÃ©n',),
#  ('Zoolander',),
#  ('25th Hour',),
#  ('28 Days Later...',),
#  ('40 Days and 40 Nights',),
#  ('8 Mile',),
#  ('8 Women',),
#  ('A Walk to Remember',),
#  ('Abandon',),
#  ('About a Boy',),
#  ('About Schmidt',),
#  ('Adaptation.',),
#  ('All About the Benjamins',),
#  ('All or Nothing',),
#  ('Amen.',),
#  ('Analyze That',),
#  ('Antwone Fisher',),
#  ('Ararat',),
#  ('Austin Powers in Goldmember',),
#  ('Auto Focus',),
#  ('Bad Company',),
#  ('Ballistic: Ecks vs. Sever',),
#  ('Barbershop',),
#  ('Bend It Like Beckham',),
#  ('Better Luck Tomorrow',),
#  ('Big Fat Liar',),
#  ('Big Fat Liar',),
#  ('Big Trouble',),
#  ('Blade II',),
#  ('Blood Work',),
#  ('Bloody Sunday',),
#  ('Blue Car',),
#  ('Blue Crush',),
#  ('Boat Trip',),
#  ('Bowling for Columbine',),
#  ('Brown Sugar',),
#  ('Bubba Ho-Tep',),
#  ('Catch Me If You Can',),
#  ('Changing Lanes',),
#  ('Chicago',),
#  ('City by the Sea',),
#  ('City of Ghosts',),
#  ('City of God',),
#  ('Civil Brand',),
#  ('Clockstoppers',),
#  ('Collateral Damage',),
#  ('Confessions of a Dangerous Mind',),
#  ('Crop Circles: Quest for Truth',),
#  ('Crossroads',),
#  ('Crossroads',),
#  ('Cypher',),
#  ('Dark Blue',),
#  ('Darkness',),
#  ('Death to Smoochy',),
#  ('Deuces Wild',),
#  ('Die Another Day',),
#  ('Dirty Pretty Things',),
#  ('Divine Secrets of the Ya-Ya Sisterhood',),
#  ("Dracula: Pages from a Virgin's Diary",),
#  ('Dragonfly',),
#  ('Drumline',),
#  ('Eight Legged Freaks',),
#  ('El crimen del padre Amaro',),
#  ('Enough',),
#  ('Equilibrium',),
#  ('Extreme Ops',),
#  ('Eye See You',),
#  ('Fabled',),
#  ('Far from Heaven',),
#  ('Feardotcom',),
#  ('Femme Fatale',),
#  ('Frida',),
#  ('Friday After Next',),
#  ('Full Frontal',),
#  ('Funny Ha Ha',),
#  ('Gangs of New York',),
#  ('Gerry',),
#  ('Ghost Ship',),
#  ('Half Past Dead',),
#  ('Halloween: Resurrection',),
#  ('Harry Potter and the Chamber of Secrets',),
#  ("Hart's War",),
#  ('Hero',),
#  ('Hero',),
#  ('Hey Arnold! The Movie',),
#  ('High Crimes',),
#  ('Highway',),
#  ('Hollywood Ending',),
#  ('I Spy',),
#  ('Ice Age',),
#  ('Igby Goes Down',),
#  ('Insomnia',),
#  ('Interview with the Assassin',),
#  ('Irreversible',),
#  ('Jackass: The Movie',),
#  ('John Q',),
#  ('Jonah: A VeggieTales Movie',),
#  ('Juwanna Mann',),
#  ('K-19: The Widowmaker',),
#  ('Kung Pow: Enter the Fist',),
#  ("L'auberge espagnole",),
#  ('Life or Something Like It',),
#  ('Like Mike',),
#  ('Lilo & Stitch',),
#  ('Lilya 4-Ever',),
#  ('Maid in Manhattan',),
#  ('Manito',),
#  ('Martin Lawrence Live: Runteldat',),
#  ('May',),
#  ('Men in Black II',),
#  ('Men with Brooms',),
#  ('Minority Report',),
#  ('Mondays in the Sun',),
#  ('Moonlight Mile',),
#  ('Morvern Callar',),
#  ('Mr. Deeds',),
#  ('Murder by Numbers',),
#  ('Murder by Numbers',),
#  ('My Big Fat Greek Wedding',),
#  ('Narc',),
#  ('Nicholas Nickleby',),
#  ('One Hour Photo',),
#  ('Panic Room',),
#  ('People I Know',),
#  ('Phone Booth',),
#  ('Poolhall Junkies',),
#  ('Punch-Drunk Love',),
#  ('Queen of the Damned',),
#  ('Rabbit-Proof Fence',),
#  ('Raising Victor Vargas',),
#  ('Real Women Have Curves',),
#  ('Red Dragon',),
#  ('Reign of Fire',),
#  ('Resident Evil',),
#  ('Return to Never Land',),
#  ("Ripley's Game",),
#  ('Road to Perdition',),
#  ('Rollerball',),
#  ('Scooby-Doo',),
#  ('Secretary',),
#  ('Serving Sara',),
#  ('Sex with Strangers',),
#  ('Signs',),
#  ('Slackers',),
#  ('Snow Dogs',),
#  ('Sorority Boys',),
#  ('Spider',),
#  ('Spider-Man',),
#  ('Spirit: Stallion of the Cimarron',),
#  ('Spun',),
#  ('Spy Kids 2: Island of Lost Dreams',),
#  ('Star Trek: Nemesis',),
#  ('Star Wars: Episode II - Attack of the Clones',),
#  ('Stealing Harvard',),
#  ('Stealing Harvard',),
#  ('Stolen Summer',),
#  ('Stuart Little 2',),
#  ('Sunshine State',),
#  ('Sweet Home Alabama',),
#  ('Swept Away',),
#  ('Swimfan',),
#  ('The Adventures of Pluto Nash',),
#  ('The Banger Sisters',),
#  ('The Bourne Identity',),
#  ('The Business of Fancydancing',),
#  ('The Count of Monte Cristo',),
#  ('The Country Bears',),
#  ('The Crocodile Hunter: Collision Course',),
#  ('The Dangerous Lives of Altar Boys',),
#  ("The Emperor's Club",),
#  ('The Four Feathers',),
#  ('The Good Girl',),
#  ('The Good Thief',),
#  ('The Guru',),
#  ('The Heart of Me',),
#  ('The Hours',),
#  ('The Importance of Being Earnest',),
#  ('The Lord of the Rings: The Two Towers',),
#  ('The Master of Disguise',),
#  ('The Mothman Prophecies',),
#  ('The New Guy',),
#  ('The Pianist',),
#  ('The Quiet American',),
#  ('The Rookie',),
#  ('The Rules of Attraction',),
#  ('The Salton Sea',),
#  ('The Santa Clause 2',),
#  ('The Scorpion King',),
#  ('The Singles Ward',),
#  ('The Slaughter Rule',),
#  ('The Sum of All Fears',),
#  ('The Sweetest Thing',),
#  ('The Time Machine',),
#  ('The Transporter',),
#  ('The Tuxedo',),
#  ('The Wild Thornberrys Movie',),
#  ('They',),
#  ('Time Changer',),
#  ('Treasure Planet',),
#  ('Tuck Everlasting',),
#  ('Two Weeks Notice',),
#  ('Undercover Brother',),
#  ('Undisputed',),
#  ('Unfaithful',),
#  ('Van Wilder: Party Liaison',),
#  ('We Were Soldiers',),
#  ('Welcome to Collinwood',),
#  ('Whale Rider',),
#  ('White Oleander',),
#  ('Windtalkers',),
#  ('xXx',),
#  ('11:14',),
#  ('2 Fast 2 Furious',),
#  ('21 Grams',),
#  ('A Guy Thing',),
#  ('A Man Apart',),
#  ('A Mighty Wind',),
#  ('Agent Cody Banks',),
#  ('Alex & Emma',),
#  ('All the Real Girls',),
#  ('American Splendor',),
#  ('American Wedding',),
#  ('Anything Else',),
#  ('Bad Boys II',),
#  ('Bad Santa',),
#  ('Basic',),
#  ('Beyond Borders',),
#  ('Big Fish',),
#  ('Bon voyage',),
#  ('Bringing Down the House',),
#  ('Bruce Almighty',),
#  ('Bulletproof Monk',),
#  ("Charlie's Angels: Full Throttle",),
#  ('Chasing Papi',),
#  ('Cheaper by the Dozen',),
#  ('Code 46',),
#  ('Cold Mountain',),
#  ('Confidence',),
#  ('Cradle 2 the Grave',),
#  ('Daddy Day Care',),
#  ('Darkness Falls',),
#  ('Dickie Roberts: Former Child Star',),
#  ('Dreamcatcher',),
#  ('Dumb and Dumberer: When Harry Met Lloyd',),
#  ('Duplex',),
#  ('DysFunktional Family',),
#  ('Elf',),
#  ('Final Destination 2',),
#  ('Finding Nemo',),
#  ('Flywheel',),
#  ('Freaky Friday',),
#  ('Freddy vs. Jason',),
#  ('From Justin to Kelly',),
#  ('Gigli',),
#  ('Girl with a Pearl Earring',),
#  ('Gods and Generals',),
#  ('Good Boy!',),
#  ('Good Bye Lenin!',),
#  ('Gory Gory Hallelujah',),
#  ('Gothika',),
#  ('Grand Theft Parsons',),
#  ('Head of State',),
#  ('High Tension',),
#  ('Holes',),
#  ('Hollywood Homicide',),
#  ('Honey',),
#  ('House of 1000 Corpses',),
#  ('House of Sand and Fog',),
#  ('How to Deal',),
#  ('How to Lose a Guy in 10 Days',),
#  ('Hulk',),
#  ('I Love Your Work',),
#  ('Identity',),
#  ('In the Cut',),
#  ('Intolerable Cruelty',),
#  ('Jeepers Creepers II',),
#  ('Johnny English',),
#  ('Just Married',),
#  ('Kangaroo Jack',),
#  ('Kill Bill: Vol. 1',),
#  ('Lara Croft Tomb Raider: The Cradle of Life',),
#  ('Latter Days',),
#  ('Legally Blonde 2: Red, White & Blonde',),
#  ('Looney Tunes: Back in Action',),
#  ('Lost in Translation',),
#  ('Love Actually',),
#  ('Malevolence',),
#  ("Malibu's Most Wanted",),
#  ('Mambo Italiano',),
#  ('Marci X',),
#  ('Masked and Anonymous',),
#  ('Master and Commander: The Far Side of the World',),
#  ('Mona Lisa Smile',),
#  ('Monster',),
#  ("My Boss's Daughter",),
#  ('My Life Without Me',),
#  ('Mystic River',),
#  ('Northfork',),
#  ('Nothing',),
#  ('Old School',),
#  ('Oldboy',),
#  ('Once Upon a Time in Mexico',),
#  ('Open Range',),
#  ('Open Water',),
#  ('Osama',),
#  ('Out of Time',),
#  ('Owning Mahowny',),
#  ('Party Monster',),
#  ('Paycheck',),
#  ('Pieces of April',),
#  ('Pirates of the Caribbean: The Curse of the Black Pearl',),
#  ('Radio',),
#  ('Remember Me, My Love',),
#  ('Rugrats Go Wild',),
#  ('S.W.A.T.',),
#  ('Saints and Soldiers',),
#  ('Scary Movie 3',),
#  ('School of Rock',),
#  ('Seabiscuit',),
#  ('Secondhand Lions',),
#  ('Shade',),
#  ('Shanghai Knights',),
#  ('Shattered Glass',),
#  ('Silmido',),
#  ('Sinbad: Legend of the Seven Seas',),
#  ("Something's Gotta Give",),
#  ('Spy Kids 3-D: Game Over',),
#  ('Stuck on You',),
#  ('Sur le seuil',),
#  ('Swimming Pool',),
#  ('Tarnation',),
#  ('Tears of the Sun',),
#  ('Terminator 3: Rise of the Machines',),
#  ('The Barbarian Invasions',),
#  ('The Battle of Shaker Heights',),
#  ('The Book of Mormon Movie, Volume 1: The Journey',),
#  ('The Brown Bunny',),
#  ('The Cat in the Hat',),
#  ('The Cooler',),
#  ('The Core',),
#  ('The Flower of Evil',),
#  ('The Haunted Mansion',),
#  ('The Hebrew Hammer',),
#  ('The Hunted',),
#  ('The Italian Job',),
#  ('The Jungle Book 2',),
#  ('The Last Samurai',),
#  ('The League of Extraordinary Gentlemen',),
#  ('The Life of David Gale',),
#  ('The Lizzie McGuire Movie',),
#  ('The Lord of the Rings: The Return of the King',),
#  ('The Matrix Reloaded',),
#  ('The Matrix Revolutions',),
#  ('The Medallion',),
#  ('The Mudge Boy',),
#  ('The Order',),
#  ('The R.M.',),
#  ('The Real Cancun',),
#  ('The Return',),
#  ('The Rundown',),
#  ('The Singing Detective',),
#  ('The Statement',),
#  ('The Station Agent',),
#  ('The Triplets of Belleville',),
#  ('The Visual Bible: The Gospel of John',),
#  ('The Work and the Story',),
#  ('Thirteen',),
#  ('This Thing of Ours',),
#  ('Timeline',),
#  ('Touching the Void',),
#  ('Travelers and Magicians',),
#  ('Tupac: Resurrection',),
#  ('Under the Tuscan Sun',),
#  ('Underworld',),
#  ('Veronica Guerin',),
#  ('What a Girl Wants',),
#  ('Willard',),
#  ('Wonderland',),
#  ('Wrong Turn',),
#  ('X-Men 2',),
#  ('13 Going on 30',),
#  (2046,),
#  ('50 First Dates',),
#  ('A Cinderella Story',),
#  ('A Home at the End of the World',),
#  ('A Very Long Engagement',),
#  ('After the Sunset',),
#  ('Against the Ropes',),
#  ('Agent Cody Banks 2: Destination London',),
#  ('Alexander',),
#  ('Alfie',),
#  ('Along Came Polly',),
#  ('An American Girl Holiday',),
#  ('Anacondas: The Hunt for the Blood Orchid',),
#  ('Anchorman: The Legend of Ron Burgundy',),
#  ('Around the World in 80 Days',),
#  ('Around the World in 80 Days',),
#  ('As It Is in Heaven',),
#  ('AVP: Alien vs. Predator',),
#  ('Barbershop 2: Back in Business',),
#  ('Before Sunset',),
#  ('Being Julia',),
#  ('Beyond the Sea',),
#  ('Birth',),
#  ('Blade: Trinity',),
#  ('Bobby Jones: Stroke of Genius',),
#  ('Brave New Girl',),
#  ("Breakin' All the Rules",),
#  ('Bride & Prejudice',),
#  ('Bridget Jones: The Edge of Reason',),
#  ('Catch That Kid',),
#  ('Catwoman',),
#  ('Cellular',),
#  ('Chasing Liberty',),
#  ('Chasing Liberty',),
#  ('Christmas with the Kranks',),
#  ('Clean',),
#  ('Closer',),
#  ('Club Dread',),
#  ('Collateral',),
#  ('Confessions of a Teenage Drama Queen',),
#  ('Connie and Carla',),
#  ('Crash',),
#  ('Crash',),
#  ('D.E.B.S.',),
#  ('Dawn of the Dead',),
#  ('Dawn of the Dead',),
#  ('De-Lovely',),
#  ("Dead Man's Shoes",),
#  ('Dear Frankie',),
#  ('Dear Wendy',),
#  ('Decoys',),
#  ('District B13',),
#  ('Dodgeball: A True Underdog Story',),
#  ('Dodgeball: A True Underdog Story',),
#  ('Downfall',),
#  ('Ella Enchanted',),
#  ('Envy',),
#  ('Eternal Sunshine of the Spotless Mind',),
#  ('Eulogy',),
#  ('EuroTrip',),
#  ('Exorcist: The Beginning',),
#  ('Fahrenheit 9/11',),
#  ('Fascination',),
#  ('Fat Albert',),
#  ('Fighting Tommy Riley',),
#  ('Finding Neverland',),
#  ('Flight of the Phoenix',),
#  ('Freeze Frame',),
#  ('Garden State',),
#  ('Garfield',),
#  ('George and the Dragon',),
#  ('Godsend',),
#  ('Guiana 1838',),
#  ('Harold & Kumar Go to White Castle',),
#  ('Harry Potter and the Prisoner of Azkaban',),
#  ('Hellboy',),
#  ('Hidalgo',),
#  ('Home on the Range',),
#  ('Hotel Rwanda',),
#  ('House of D',),
#  ('House of Flying Daggers',),
#  ("Howl's Moving Castle",),
#  ('I Heart Huckabees',),
#  ('I, Robot',),
#  ('Imaginary Heroes',),
#  ('In Good Company',),
#  ('Incident at Loch Ness',),
#  ("It's All Gone Pete Tong",),
#  ('Jersey Girl',),
#  ('Johnson Family Vacation',),
#  ('Kill Bill: Vol. 2',),
#  ('Kinsey',),
#  ('Kung Fu Hustle',),
#  ('Ladder 49',),
#  ('Laws of Attraction',),
#  ('Layer Cake',),
#  ('Little Black Book',),
#  ('Live-In Maid',),
#  ('Man on Fire',),
#  ('Maria Full of Grace',),
#  ('Mean Creek',),
#  ('Mean Girls',),
#  ('Meet the Fockers',),
#  ('Million Dollar Baby',),
#  ('Mindhunters',),
#  ('Miracle',),
#  ('Mr 3000',),
#  ("My Baby's Daddy",),
#  ('My Date with Drew',),
#  ('My Summer of Love',),
#  ('Napoleon Dynamite',),
#  ('National Treasure',),
#  ('New York Minute',),
#  ('Night Watch',),
#  ('November',),
#  ("Ocean's Twelve",),
#  ('On the Downlow',),
#  ('On the Outs',),
#  ('Paparazzi',),
#  ('Peace, Propaganda & the Promised Land',),
#  ('Primer',),
#  ('Proud',),
#  ('Raise Your Voice',),
#  ('Raising Helen',),
#  ('Ray',),
#  ('Resident Evil: Apocalypse',),
#  ('Riding Giants',),
#  ('Saint Ralph',),
#  ('Saved!',),
#  ('Saving Face',),
#  ('Saw',),
#  ('Scooby-Doo 2: Monsters Unleashed',),
#  ('Secret Window',),
#  ('Seed of Chucky',),
#  ('Shall We Dance',),
#  ('Shark Tale',),
#  ('Shaun of the Dead',),
#  ('Short Cut to Nirvana: Kumbh Mela',),
#  ('Show Me',),
#  ('Shrek 2',),
#  ('Sideways',),
#  ('Sky Captain and the World of Tomorrow',),
#  ('Sleepover',),
#  ('Soul Plane',),
#  ('Spanglish',),
#  ('Spider-Man 2',),
#  ('Starsky & Hutch',),
#  ('Steamboy',),
#  ('Summer Storm',),
#  ('Super Size Me',),
#  ('Superbabies: Baby Geniuses 2',),
#  ('Suspect Zero',),
#  ('Tae Guk Gi: The Brotherhood of War',),
#  ("Teacher's Pet",),
#  ('Team America: World Police',),
#  ('The Alamo',),
#  ('The Alamo',),
#  ('The Aviator',),
#  ('The Big Bounce',),
#  ('The Blue Butterfly',),
#  ('The Bourne Supremacy',),
#  ('The Bridge of San Luis Rey',),
#  ('The Butterfly Effect',),
#  ('The Case of the Grinning Cat',),
#  ('The Chorus',),
#  ('The Chronicles of Riddick',),
#  ('The Cookout',),
#  ('The Day After Tomorrow',),
#  ('The Girl Next Door',),
#  ('The Grudge',),
#  ('The Holy Girl',),
#  ('The I Inside',),
#  ('The Incredibles',),
#  ('The Ladykillers',),
#  ('The Last Shot',),
#  ('The Libertine',),
#  ('The Life Aquatic with Steve Zissou',),
#  ('The Machinist',),
#  ('The Manchurian Candidate',),
#  ('The Merchant of Venice',),
#  ('The Notebook',),
#  ('The Passion of the Christ',),
#  ('The Phantom of the Opera',),
#  ('The Polar Express',),
#  ('The Prince and Me',),
#  ('The Princess Diaries 2: Royal Engagement',),
#  ('The Punisher',),
#  ('The Sea Inside',),
#  ('The SpongeBob SquarePants Movie',),
#  ('The Stepford Wives',),
#  ('The Terminal',),
#  ('The Village',),
#  ('The Whole Ten Yards',),
#  ('The Work and the Glory',),
#  ('Thunderbirds',),
#  ('Torque',),
#  ('Troy',),
#  ('Two Brothers',),
#  ('Vanity Fair',),
#  ('Veer-Zaara',),
#  ('Vera Drake',),
#  ('Walking Tall',),
#  ('Welcome to Mooseport',),
#  ('What the #$*! Do We (K)now!?',),
#  ('White Chicks',),
#  ('Wicker Park',),
#  ('Wicker Park',),
#  ('Wimbledon',),
#  ('Win a Date with Tad Hamilton!',),
#  ('Without a Paddle',),
#  ('Woman Thou Art Loosed',),
#  ('Yes',),
#  ('You Got Served',),
#  ('51 Birch Street',),
#  ('A History of Violence',),
#  ('A Lot Like Love',),
#  ('A Sound of Thunder',),
#  ('Ã†on Flux',),
#  ('Alone in the Dark',),
#  ('An American Haunting',),
#  ('An Unfinished Life',),
#  ('Are We There Yet?',),
#  ('Assault on Precinct 13',),
#  ('Batman Begins',),
#  ('Be Cool',),
#  ('Beauty Shop',),
#  ('Because of Winn-Dixie',),
#  ('BloodRayne',),
#  ('Boogeyman',),
#  ('Boynton Beach Club',),
#  ('Brokeback Mountain',),
#  ('Camping sauvage',),
#  ('Capote',),
#  ('Cavite',),
#  ('Charlie and the Chocolate Factory',),
#  ('Cheaper by the Dozen 2',),
#  ('Chicken Little',),
#  ('Chicken Tikka Masala',),
#  ('Chocolate: Deep Dark Secrets',),
#  ('Cinderella Man',),
#  ('Coach Carter',),
#  ('Conversations with Other Women',),
#  ('Corpse Bride',),
#  ('Cry_Wolf',),
#  ('Cursed',),
#  ('Dark Water',),
#  ("Dave Chappelle's Block Party",),
#  ('Derailed',),
#  ('Deuce Bigalow: European Gigolo',),
#  ('Diary of a Mad Black Woman',),
#  ('Dil Jo Bhi Kahey...',),
#  ('Domino',),
#  ('Doom',),
#  ('Down in the Valley',),
#  ('Dreamer: Inspired by a True Story',),
#  ('Duma',),
#  ('Dungeons & Dragons: Wrath of the Dragon God',),
#  ('Edmond',),
#  ('Elektra',),
#  ('Elizabethtown',),
#  ('End of the Spear',),
#  ('Fateless',),
#  ('Feast',),
#  ('Fetching Cody',),
#  ('Fever Pitch',),
#  ('Flightplan',),
#  ('Forty Shades of Blue',),
#  ('Four Brothers',),
#  ('Fun with Dick and Jane',),
#  ("Get Rich or Die Tryin'",),
#  ('Goal! The Dream Begins',),
#  ('Good Night, and Good Luck.',),
#  ('Guess Who',),
#  ('Hard Candy',),
#  ('Harry Potter and the Goblet of Fire',),
#  ('Harsh Times',),
#  ('Herbie Fully Loaded',),
#  ('Hide and Seek',),
#  ('Hitch',),
#  ('Hoodwinked!',),
#  ('Hostage',),
#  ('Hostel',),
#  ('House of Sand',),
#  ('House of Wax',),
#  ('House of Wax',),
#  ('Hustle & Flow',),
#  ('Ice Princess',),
#  ('Imagine Me & You',),
#  ('Inside Deep Throat',),
#  ('Insomnia Manica',),
#  ('Into the Blue',),
#  ('Jarhead',),
#  ('Joyeux Noel',),
#  ('Just Like Heaven',),
#  ('Kicking & Screaming',),
#  ('King Kong',),
#  ('King Kong',),
#  ('King Kong',),
#  ("King's Ransom",),
#  ('Kingdom of Heaven',),
#  ('Kiss Kiss Bang Bang',),
#  ('Lady Vengeance',),
#  ('Land of the Dead',),
#  ('London',),
#  ('Lonesome Jim',),
#  ('Lord of War',),
#  ('Lords of Dogtown',),
#  ('Mad Hot Ballroom',),
#  ('Madagascar',),
#  ('Man of the House',),
#  ('Manderlay',),
#  ('March of the Penguins',),
#  ('Match Point',),
#  ('Me and You and Everyone We Know',),
#  ('Memoirs of a Geisha',),
#  ('Mirrormask',),
#  ('Miss Congeniality 2: Armed and Fabulous',),
#  ('Monster-in-Law',),
#  ('Mr. & Mrs. Smith',),
#  ('Mrs Henderson Presents',),
#  ('Munich',),
#  ('Murderball',),
#  ('Must Love Dogs',),
#  ('Mutual Appreciation',),
#  ('My Big Fat Independent Movie',),
#  ('Nanny McPhee',),
#  ("Neal 'N' Nikki",),
#  ('Nomad: The Warrior',),
#  ('North Country',),
#  ('Oliver Twist',),
#  ("Pooh's Heffalump Movie",),
#  ('Pride & Prejudice',),
#  ('Racing Stripes',),
#  ('Red Eye',),
#  ('Rent',),
#  ('Rize',),
#  ('Robots',),
#  ('Roll Bounce',),
#  ('Romance & Cigarettes',),
#  ('Sahara',),
#  ('Saw II',),
#  ('Serenity',),
#  ('Shopgirl',),
#  ('Sin City',),
#  ('Sisters in Law',),
#  ('Sky High',),
#  ('Slow Burn',),
#  ('Son of the Mask',),
#  ('Star Wars: Episode III - Revenge of the Sith',),
#  ('Stealth',),
#  ('Supercross',),
#  ('Syriana',),
#  ('Syriana',),
#  ('Thank You for Smoking',),
#  ('The 40-Year-Old Virgin',),
#  ('The Adventures of Sharkboy and Lavagirl 3-D',),
#  ('The Amityville Horror',),
#  ('The Ballad of Jack and Rose',),
#  ('The Blood of My Brother',),
#  ('The Brothers Grimm',),
#  ('The Californians',),
#  ('The Call of Cthulhu',),
#  ('The Cave',),
#  ('The Chronicles of Narnia: The Lion, the Witch and the Wardrobe',),
#  ('The Chumscrubber',),
#  ('The Constant Gardener',),
#  ('The Curse of the Were-Rabbit',),
#  ('The Dark Hours',),
#  ('The Descent',),
#  ("The Devil's Rejects",),
#  ('The Dukes of Hazzard',),
#  ('The Exorcism of Emily Rose',),
#  ('The Family Stone',),
#  ('The Game of Their Lives',),
#  ('The Great Raid',),
#  ('The Greatest Game Ever Played',),
#  ('The Helix... Loaded',),
#  ("The Hitchhiker's Guide to the Galaxy",),
#  ('The Interpreter',),
#  ('The Island',),
#  ('The Island',),
#  ('The Jacket',),
#  ('The Legend of Zorro',),
#  ('The Longest Yard',),
#  ('The Lost City',),
#  ('The Man',),
#  ('The Matador',),
#  ('The Mongol King',),
#  ('The Motel',),
#  ('The New World',),
#  ('The Pacifier',),
#  ('The Perfect Man',),
#  ('The Producers',),
#  ('The Promise',),
#  ('The Proposition',),
#  ('The Protector',),
#  ('The Puffy Chair',),
#  ('The Quiet',),
#  ('The Ring Two',),
#  ('The Rocket: The Legend of Rocket Richard',),
#  ('The Salon',),
#  ('The Sisterhood of the Traveling Pants',),
#  ('The Skeleton Key',),
#  ('The Squid and the Whale',),
#  ('The Upside of Anger',),
#  ('The Weather Man',),
#  ('The Wedding Date',),
#  ('The Wendell Baker Story',),
#  ('The White Countess',),
#  ('The Work and the Glory II: American Zion',),
#  ("The World's Fastest Indian",),
#  ('Three Burials',),
#  ('Thumbsucker',),
#  ('Transamerica',),
#  ('Transporter 2',),
#  ('Tristram Shandy: A Cock and Bull Story',),
#  ('Trust the Man',),
#  ('Tsotsi',),
#  ('Underclassman',),
#  ('Undiscovered',),
#  ('Unleashed',),
#  ('V for Vendetta',),
#  ('Valiant',),
#  ('Wah-Wah',),
#  ('Waiting...',),
#  ('Wal-Mart: The High Cost of Low Price',),
#  ('Walk the Line',),
#  ('War of the Worlds',),
#  ('Water',),
#  ('Where the Truth Lies',),
#  ('White Noise',),
#  ('Winter Passing',),
#  ('xXx: State of the Union',),
#  ...]

# %% [markdown]
# ## 0.2.3 Using WHERE with numbers

# %%
# -- Select film_ids and imdb_score with an imdb_score over 7.0
cur.execute("""
            
            SELECT film_id, imdb_score 
            FROM reviews 
            WHERE imdb_score > 7.0;
            
            """).fetchall()
# Out:
# [(3934, 7.0999999),
#  (74, 7.5999999),
#  (1254, 8.0),
#  (4841, 8.10000038),
#  (3252, 7.19999981),
#  (1181, 7.30000019),
#  (3929, 7.0999999),
#  (3298, 7.4000001),
#  (2744, 7.4000001),
#  (4707, 7.4000001),
#  (3879, 7.30000019),
#  (3854, 7.5999999),
#  (1526, 7.5999999),
#  (1943, 8.19999981),
#  (2331, 7.30000019),
#  (2239, 7.4000001),
#  (3016, 7.4000001),
#  (2471, 7.0999999),
#  (1379, 7.30000019),
#  (4442, 7.9000001),
#  (2118, 7.9000001),
#  (4922, 7.30000019),
#  (2576, 7.0999999),
#  (788, 7.5),
#  (578, 7.5),
#  (368, 7.0999999),
#  (4516, 7.4000001),
#  (1354, 7.69999981),
#  (269, 8.39999962),
#  (613, 7.5999999),
#  (3098, 7.5),
#  (4314, 8.10000038),
#  (4954, 7.5999999),
#  (3318, 7.80000019),
#  (2179, 8.10000038),
#  (2470, 7.4000001),
#  (2863, 8.0),
#  (4150, 7.69999981),
#  (35, 7.5),
#  (1320, 7.30000019),
#  (4246, 7.5999999),
#  (4006, 7.30000019),
#  (3955, 7.0999999),
#  (600, 7.0999999),
#  (2144, 7.5999999),
#  (2049, 7.19999981),
#  (2444, 7.19999981),
#  (1443, 7.30000019),
#  (3642, 8.30000019),
#  (4542, 7.30000019),
#  (1226, 7.30000019),
#  (4144, 7.9000001),
#  (4746, 8.10000038),
#  (1806, 7.69999981),
#  (2804, 7.5),
#  (328, 7.9000001),
#  (524, 7.19999981),
#  (691, 8.0),
#  (535, 7.19999981),
#  (4448, 8.60000038),
#  (3082, 8.0),
#  (1547, 8.10000038),
#  (2578, 7.0999999),
#  (4502, 7.5),
#  (576, 7.5999999),
#  (1074, 7.5),
#  (2527, 7.5),
#  (971, 8.30000019),
#  (242, 8.19999981),
#  (3766, 7.0999999),
#  (1821, 7.30000019),
#  (1751, 7.4000001),
#  (2658, 7.30000019),
#  (3841, 7.30000019),
#  (723, 8.89999962),
#  (4767, 7.0999999),
#  (2489, 7.4000001),
#  (1902, 7.5999999),
#  (2624, 7.19999981),
#  (2089, 7.19999981),
#  ...]

# %%
# -- Select film_ids and facebook_likes for ten records with less than 1000 likes 
cur.execute("""
            
            SELECT film_id, facebook_likes 
            FROM reviews 
            WHERE facebook_likes < 1000 
            LIMIT 10;
            
            """).fetchall()
# Out:
# [(3405, 0.0),
#  (478, 491.0),
#  (74, 930.0),
#  (740, 0.0),
#  (2869, 689.0),
#  (1181, 0.0),
#  (2020, 0.0),
#  (2312, 912.0),
#  (1820, 872.0),
#  (831, 975.0)]

# %%
# -- Count the records with at least 100,000 votes
cur.execute("""
            
            SELECT COUNT (*) AS films_over_100K_votes 
            FROM reviews 
            WHERE num_votes > 100000;
            
            """).fetchall()
# Out:
# [(1211,)]

# %% [markdown]
# ## 0.2.4 Using WHERE with text

# %%
# -- Count the Spanish-language films
cur.execute("""
            
            SELECT COUNT(language) AS count_spanish 
            FROM films 
            WHERE language = 'Spanish';
            
            """).fetchall()
# Out:
# [(40,)]

# %% [markdown]
# ## 0.2.6 Using AND

# %%
# -- Select the title and release_year for all German-language films released before 2000
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE language = 'German' AND release_year < 2000;
            
            """).fetchall()
# Out:
# [('Metropolis', 1927),
#  ("Pandora's Box", 1929),
#  ('The Torture Chamber of Dr. Sadism', 1967),
#  ('Das Boot', 1981),
#  ('Run Lola Run', 1998),
#  ('Aimee & Jaguar', 1999)]

# %%
# -- Update the query to see all German-language films released after 2000
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year > 2000 AND language = 'German';
            
            """).fetchall()
# Out:
# [('Good Bye Lenin!', 2003),
#  ('Downfall', 2004),
#  ('Summer Storm', 2004),
#  ('The Lives of Others', 2006),
#  ('The Baader Meinhof Complex', 2008),
#  ('The Wave', 2008),
#  ('Cargo', 2009),
#  ('Soul Kitchen', 2009),
#  ('The White Ribbon', 2009),
#  (3, 2010),
#  ('Animals United', 2010),
#  ('Buen DÃ\xada, RamÃ³n', 2013)]

# %%
# -- Select all records for German-language films released after 2000 and before 2010
cur.execute("""
            
            SELECT * 
            FROM films 
            WHERE language = 'German' AND release_year > 2000 AND release_year < 2010;
            
            """).fetchall()
# Out:
# [(1952,
#   'Good Bye Lenin!',
#   2003,
#   'Germany',
#   121,
#   'German',
#   'R',
#   4063859.0,
#   4800000.0),
#  (2130,
#   'Downfall',
#   2004,
#   'Germany',
#   178,
#   'German',
#   'R',
#   5501940.0,
#   13500000.0),
#  (2224,
#   'Summer Storm',
#   2004,
#   'Germany',
#   98,
#   'German',
#   'R',
#   95016.0,
#   2700000.0),
#  (2709,
#   'The Lives of Others',
#   2006,
#   'Germany',
#   137,
#   'German',
#   'R',
#   11284657.0,
#   2000000.0),
#  (3100,
#   'The Baader Meinhof Complex',
#   2008,
#   'Germany',
#   184,
#   'German',
#   'R',
#   476270.0,
#   20000000.0),
#  (3143, 'The Wave', 2008, 'Germany', 107, 'German', None, None, 5000000.0),
#  (3220, 'Cargo', 2009, 'Switzerland', 112, 'German', None, None, 4500000.0),
#  (3346,
#   'Soul Kitchen',
#   2009,
#   'Germany',
#   99,
#   'German',
#   None,
#   274385.0,
#   4000000.0),
#  (3412,
#   'The White Ribbon',
#   2009,
#   'Germany',
#   144,
#   'German',
#   'R',
#   2222647.0,
#   12000000.0)]

# %% [markdown]
# ## 0.2.7 Using OR

# %%
# Find the title and year of films from the 1990 or 1999 
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year = 1990 OR release_year = 1999;
            
            """).fetchall()
# Out:
# [('Arachnophobia', 1990),
#  ('Back to the Future Part III', 1990),
#  ("Child's Play 2", 1990),
#  ('Dances with Wolves', 1990),
#  ('Days of Thunder', 1990),
#  ('Dick Tracy', 1990),
#  ('Die Hard 2', 1990),
#  ('Edward Scissorhands', 1990),
#  ('Flatliners', 1990),
#  ('Ghost', 1990),
#  ('Goodfellas', 1990),
#  ('Gremlins 2: The New Batch', 1990),
#  ('Home Alone', 1990),
#  ('Kindergarten Cop', 1990),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 1990),
#  ('Metropolitan', 1990),
#  ('Midnight Cabaret', 1990),
#  ("Mo' Better Blues", 1990),
#  ('Predator 2', 1990),
#  ('Pretty Woman', 1990),
#  ('Quigley Down Under', 1990),
#  ('Shipwrecked', 1990),
#  ('Spaced Invaders', 1990),
#  ('The Adventures of Ford Fairlane', 1990),
#  ('The Godfather: Part III', 1990),
#  ('The Hunt for Red October', 1990),
#  ('Total Recall', 1990),
#  ('Total Recall', 1990),
#  ('Tremors', 1990),
#  ('Two Evil Eyes', 1990),
#  ('10 Things I Hate About You', 1999),
#  ('200 Cigarettes', 1999),
#  ('8MM', 1999),
#  ('A Dog of Flanders', 1999),
#  ('A Room for Romeo Brass', 1999),
#  ('A Walk on the Moon', 1999),
#  ('Aimee & Jaguar', 1999),
#  ('American Beauty', 1999),
#  ('American Pie', 1999),
#  ('An Ideal Husband', 1999),
#  ('Analyze This', 1999),
#  ("Angela's Ashes", 1999),
#  ('Anna and the King', 1999),
#  ('Any Given Sunday', 1999),
#  ('Anywhere But Here', 1999),
#  ('Arlington Road', 1999),
#  ('At First Sight', 1999),
#  ('Austin Powers: The Spy Who Shagged Me', 1999),
#  ('Baby Geniuses', 1999),
#  ('Bats', 1999),
#  ('Being John Malkovich', 1999),
#  ('Beyond the Mat', 1999),
#  ('Bicentennial Man', 1999),
#  ('Big Daddy', 1999),
#  ('Blast from the Past', 1999),
#  ('Blue Streak', 1999),
#  ('Bowfinger', 1999),
#  ("Boys Don't Cry", 1999),
#  ('Breakfast of Champions', 1999),
#  ('Bringing Out the Dead', 1999),
#  ('Brokedown Palace', 1999),
#  ("But I'm a Cheerleader", 1999),
#  ('Chill Factor', 1999),
#  ('Cradle Will Rock', 1999),
#  ('Crazy in Alabama', 1999),
#  ('Cruel Intentions', 1999),
#  ('Deep Blue Sea', 1999),
#  ('Deterrence', 1999),
#  ('Detroit Rock City', 1999),
#  ('Deuce Bigalow: Male Gigolo', 1999),
#  ('Dick', 1999),
#  ('Dogma', 1999),
#  ('Double Jeopardy', 1999),
#  ("Doug's 1st Movie", 1999),
#  ('Dreaming of Joseph Lees', 1999),
#  ('Drive Me Crazy', 1999),
#  ('Drop Dead Gorgeous', 1999),
#  ('Dudley Do-Right', 1999),
#  ('East Is East', 1999),
#  ('Edtv', 1999),
#  ('Election', 1999),
#  ('End of Days', 1999),
#  ('Entrapment', 1999),
#  ('eXistenZ', 1999),
#  ('Eye of the Beholder', 1999),
#  ('Eyes Wide Shut', 1999),
#  ('Fantasia 2000', 1999),
#  ("Felicia's Journey", 1999),
#  ('Fight Club', 1999),
#  ('Flawless', 1999),
#  ('Foolish', 1999),
#  ('For Love of the Game', 1999),
#  ('Galaxy Quest', 1999),
#  ('Ghost Dog: The Way of the Samurai', 1999),
#  ('Girl, Interrupted', 1999),
#  ('Go', 1999),
#  ('Godzilla 2000', 1999),
#  ('Happy, Texas', 1999),
#  ('Held Up', 1999),
#  ('House on Haunted Hill', 1999),
#  ('Human Traffic', 1999),
#  ('Idle Hands', 1999),
#  ('In Dreams', 1999),
#  ('In Too Deep', 1999),
#  ('Inspector Gadget', 1999),
#  ('Instinct', 1999),
#  ('Jakob the Liar', 1999),
#  ('Jawbreaker', 1999),
#  ("Jesus' Son", 1999),
#  ('Just Looking', 1999),
#  ('Lake Placid', 1999),
#  ('Light It Up', 1999),
#  ('Limbo', 1999),
#  ('Love Stinks', 1999),
#  ('Magnolia', 1999),
#  ('Man on the Moon', 1999),
#  ('Message in a Bottle', 1999),
#  ('Mickey Blue Eyes', 1999),
#  ('Molly', 1999),
#  ('Mumford', 1999),
#  ('Muppets from Space', 1999),
#  ('My Favorite Martian', 1999),
#  ('Mystery Men', 1999),
#  ('Mystery, Alaska', 1999),
#  ('Notting Hill', 1999),
#  ('Office Space', 1999),
#  ("One Man's Hero", 1999),
#  ('Outside Providence', 1999),
#  ('Payback', 1999),
#  ('Play It to the Bone', 1999),
#  ('Pushing Tin', 1999),
#  ('Random Hearts', 1999),
#  ('Ravenous', 1999),
#  ('Ride with the Devil', 1999),
#  ('Runaway Bride', 1999),
#  ("She's All That", 1999),
#  ('Simply Irresistible', 1999),
#  ('Smiling Fish & Goat on Fire', 1999),
#  ('Snow Falling on Cedars', 1999),
#  ('South Park: Bigger Longer & Uncut', 1999),
#  ('Speedway Junky', 1999),
#  ('Star Wars: Episode I - The Phantom Menace', 1999),
#  ('Stigmata', 1999),
#  ('Stir of Echoes', 1999),
#  ('Stuart Little', 1999),
#  ('Sugar Town', 1999),
#  ('Summer of Sam', 1999),
#  ('Superstar', 1999),
#  ('Tea with Mussolini', 1999),
#  ('The 13th Warrior', 1999),
#  ('The Adventures of Elmo in Grouchland', 1999),
#  ("The Astronaut's Wife", 1999),
#  ("The Astronaut's Wife", 1999),
#  ('The Basket', 1999),
#  ('The Best Man', 1999),
#  ('The Big Tease', 1999),
#  ('The Blair Witch Project', 1999),
#  ('The Bone Collector', 1999),
#  ('The Boondock Saints', 1999),
#  ('The Corruptor', 1999),
#  ('The Deep End of the Ocean', 1999),
#  ('The End of the Affair', 1999),
#  ("The General's Daughter", 1999),
#  ('The Green Mile', 1999),
#  ('The Haunting', 1999),
#  ('The Hurricane', 1999),
#  ('The Insider', 1999),
#  ('The Iron Giant', 1999),
#  ('The Limey', 1999),
#  ('The Loss of Sexual Innocence', 1999),
#  ('The Matrix', 1999),
#  ('The Messenger: The Story of Joan of Arc', 1999),
#  ('The Muse', 1999),
#  ('The Ninth Gate', 1999),
#  ('The Omega Code', 1999),
#  ('The Out-of-Towners', 1999),
#  ('The Rage: Carrie 2', 1999),
#  ('The Sixth Sense', 1999),
#  ('The Story of Us', 1999),
#  ('The Straight Story', 1999),
#  ('The Talented Mr. Ripley', 1999),
#  ('The Thirteenth Floor', 1999),
#  ('The Thomas Crown Affair', 1999),
#  ('The Virgin Suicides', 1999),
#  ('The Woman Chaser', 1999),
#  ('The Wood', 1999),
#  ('The World Is Not Enough', 1999),
#  ('Three Kings', 1999),
#  ('Three to Tango', 1999),
#  ('Topsy-Turvy', 1999),
#  ('Toy Story 2', 1999),
#  ("Trippin'", 1999),
#  ('Tumbleweeds', 1999),
#  ('Twin Falls Idaho', 1999),
#  ('Universal Soldier: The Return', 1999),
#  ('Varsity Blues', 1999),
#  ('Wild Wild West', 1999),
#  ('Wing Commander', 1999)]

# %%
# Filter the records to only include English or Spanish-language films.
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE (release_year = 1990 OR release_year = 1999) AND (language = 'English' OR language = 'Spanish');
            
            """).fetchall()
# Out:
# [('Arachnophobia', 1990),
#  ('Back to the Future Part III', 1990),
#  ("Child's Play 2", 1990),
#  ('Dances with Wolves', 1990),
#  ('Days of Thunder', 1990),
#  ('Dick Tracy', 1990),
#  ('Die Hard 2', 1990),
#  ('Edward Scissorhands', 1990),
#  ('Flatliners', 1990),
#  ('Ghost', 1990),
#  ('Goodfellas', 1990),
#  ('Gremlins 2: The New Batch', 1990),
#  ('Home Alone', 1990),
#  ('Kindergarten Cop', 1990),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 1990),
#  ('Metropolitan', 1990),
#  ('Midnight Cabaret', 1990),
#  ("Mo' Better Blues", 1990),
#  ('Predator 2', 1990),
#  ('Pretty Woman', 1990),
#  ('Quigley Down Under', 1990),
#  ('Shipwrecked', 1990),
#  ('Spaced Invaders', 1990),
#  ('The Adventures of Ford Fairlane', 1990),
#  ('The Godfather: Part III', 1990),
#  ('The Hunt for Red October', 1990),
#  ('Total Recall', 1990),
#  ('Total Recall', 1990),
#  ('Tremors', 1990),
#  ('Two Evil Eyes', 1990),
#  ('10 Things I Hate About You', 1999),
#  ('200 Cigarettes', 1999),
#  ('8MM', 1999),
#  ('A Dog of Flanders', 1999),
#  ('A Room for Romeo Brass', 1999),
#  ('A Walk on the Moon', 1999),
#  ('American Beauty', 1999),
#  ('American Pie', 1999),
#  ('An Ideal Husband', 1999),
#  ('Analyze This', 1999),
#  ("Angela's Ashes", 1999),
#  ('Anna and the King', 1999),
#  ('Any Given Sunday', 1999),
#  ('Anywhere But Here', 1999),
#  ('Arlington Road', 1999),
#  ('At First Sight', 1999),
#  ('Austin Powers: The Spy Who Shagged Me', 1999),
#  ('Baby Geniuses', 1999),
#  ('Bats', 1999),
#  ('Being John Malkovich', 1999),
#  ('Beyond the Mat', 1999),
#  ('Bicentennial Man', 1999),
#  ('Big Daddy', 1999),
#  ('Blast from the Past', 1999),
#  ('Blue Streak', 1999),
#  ('Bowfinger', 1999),
#  ("Boys Don't Cry", 1999),
#  ('Breakfast of Champions', 1999),
#  ('Bringing Out the Dead', 1999),
#  ('Brokedown Palace', 1999),
#  ("But I'm a Cheerleader", 1999),
#  ('Chill Factor', 1999),
#  ('Cradle Will Rock', 1999),
#  ('Crazy in Alabama', 1999),
#  ('Cruel Intentions', 1999),
#  ('Deep Blue Sea', 1999),
#  ('Deterrence', 1999),
#  ('Detroit Rock City', 1999),
#  ('Deuce Bigalow: Male Gigolo', 1999),
#  ('Dick', 1999),
#  ('Dogma', 1999),
#  ('Double Jeopardy', 1999),
#  ("Doug's 1st Movie", 1999),
#  ('Dreaming of Joseph Lees', 1999),
#  ('Drive Me Crazy', 1999),
#  ('Drop Dead Gorgeous', 1999),
#  ('Dudley Do-Right', 1999),
#  ('East Is East', 1999),
#  ('Edtv', 1999),
#  ('Election', 1999),
#  ('End of Days', 1999),
#  ('Entrapment', 1999),
#  ('eXistenZ', 1999),
#  ('Eye of the Beholder', 1999),
#  ('Eyes Wide Shut', 1999),
#  ('Fantasia 2000', 1999),
#  ("Felicia's Journey", 1999),
#  ('Fight Club', 1999),
#  ('Flawless', 1999),
#  ('Foolish', 1999),
#  ('For Love of the Game', 1999),
#  ('Galaxy Quest', 1999),
#  ('Ghost Dog: The Way of the Samurai', 1999),
#  ('Girl, Interrupted', 1999),
#  ('Go', 1999),
#  ('Happy, Texas', 1999),
#  ('Held Up', 1999),
#  ('House on Haunted Hill', 1999),
#  ('Human Traffic', 1999),
#  ('Idle Hands', 1999),
#  ('In Dreams', 1999),
#  ('In Too Deep', 1999),
#  ('Inspector Gadget', 1999),
#  ('Instinct', 1999),
#  ('Jakob the Liar', 1999),
#  ('Jawbreaker', 1999),
#  ("Jesus' Son", 1999),
#  ('Just Looking', 1999),
#  ('Lake Placid', 1999),
#  ('Light It Up', 1999),
#  ('Limbo', 1999),
#  ('Love Stinks', 1999),
#  ('Magnolia', 1999),
#  ('Man on the Moon', 1999),
#  ('Message in a Bottle', 1999),
#  ('Mickey Blue Eyes', 1999),
#  ('Molly', 1999),
#  ('Mumford', 1999),
#  ('Muppets from Space', 1999),
#  ('My Favorite Martian', 1999),
#  ('Mystery Men', 1999),
#  ('Mystery, Alaska', 1999),
#  ('Notting Hill', 1999),
#  ('Office Space', 1999),
#  ("One Man's Hero", 1999),
#  ('Outside Providence', 1999),
#  ('Payback', 1999),
#  ('Play It to the Bone', 1999),
#  ('Pushing Tin', 1999),
#  ('Random Hearts', 1999),
#  ('Ravenous', 1999),
#  ('Ride with the Devil', 1999),
#  ('Runaway Bride', 1999),
#  ("She's All That", 1999),
#  ('Simply Irresistible', 1999),
#  ('Smiling Fish & Goat on Fire', 1999),
#  ('Snow Falling on Cedars', 1999),
#  ('South Park: Bigger Longer & Uncut', 1999),
#  ('Speedway Junky', 1999),
#  ('Star Wars: Episode I - The Phantom Menace', 1999),
#  ('Stigmata', 1999),
#  ('Stir of Echoes', 1999),
#  ('Stuart Little', 1999),
#  ('Sugar Town', 1999),
#  ('Summer of Sam', 1999),
#  ('Superstar', 1999),
#  ('Tea with Mussolini', 1999),
#  ('The 13th Warrior', 1999),
#  ('The Adventures of Elmo in Grouchland', 1999),
#  ("The Astronaut's Wife", 1999),
#  ("The Astronaut's Wife", 1999),
#  ('The Basket', 1999),
#  ('The Best Man', 1999),
#  ('The Big Tease', 1999),
#  ('The Blair Witch Project', 1999),
#  ('The Bone Collector', 1999),
#  ('The Boondock Saints', 1999),
#  ('The Corruptor', 1999),
#  ('The Deep End of the Ocean', 1999),
#  ('The End of the Affair', 1999),
#  ("The General's Daughter", 1999),
#  ('The Green Mile', 1999),
#  ('The Haunting', 1999),
#  ('The Hurricane', 1999),
#  ('The Insider', 1999),
#  ('The Iron Giant', 1999),
#  ('The Limey', 1999),
#  ('The Loss of Sexual Innocence', 1999),
#  ('The Matrix', 1999),
#  ('The Messenger: The Story of Joan of Arc', 1999),
#  ('The Muse', 1999),
#  ('The Ninth Gate', 1999),
#  ('The Omega Code', 1999),
#  ('The Out-of-Towners', 1999),
#  ('The Rage: Carrie 2', 1999),
#  ('The Sixth Sense', 1999),
#  ('The Story of Us', 1999),
#  ('The Straight Story', 1999),
#  ('The Talented Mr. Ripley', 1999),
#  ('The Thirteenth Floor', 1999),
#  ('The Thomas Crown Affair', 1999),
#  ('The Virgin Suicides', 1999),
#  ('The Woman Chaser', 1999),
#  ('The Wood', 1999),
#  ('The World Is Not Enough', 1999),
#  ('Three Kings', 1999),
#  ('Three to Tango', 1999),
#  ('Topsy-Turvy', 1999),
#  ('Toy Story 2', 1999),
#  ("Trippin'", 1999),
#  ('Tumbleweeds', 1999),
#  ('Twin Falls Idaho', 1999),
#  ('Universal Soldier: The Return', 1999),
#  ('Varsity Blues', 1999),
#  ('Wild Wild West', 1999),
#  ('Wing Commander', 1999)]

# %%
# Restrict the query to only return films worth more than $2,000,000 gross.
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE (release_year = 1990 OR release_year = 1999) AND (language = 'English' OR language = 'Spanish') AND gross >= 2000000;
            
            """).fetchall()
# Out:
# [('Arachnophobia', 1990),
#  ('Back to the Future Part III', 1990),
#  ("Child's Play 2", 1990),
#  ('Dances with Wolves', 1990),
#  ('Days of Thunder', 1990),
#  ('Dick Tracy', 1990),
#  ('Die Hard 2', 1990),
#  ('Edward Scissorhands', 1990),
#  ('Flatliners', 1990),
#  ('Ghost', 1990),
#  ('Goodfellas', 1990),
#  ('Gremlins 2: The New Batch', 1990),
#  ('Home Alone', 1990),
#  ('Kindergarten Cop', 1990),
#  ('Metropolitan', 1990),
#  ("Mo' Better Blues", 1990),
#  ('Predator 2', 1990),
#  ('Pretty Woman', 1990),
#  ('Quigley Down Under', 1990),
#  ('Spaced Invaders', 1990),
#  ('The Adventures of Ford Fairlane', 1990),
#  ('The Godfather: Part III', 1990),
#  ('The Hunt for Red October', 1990),
#  ('Total Recall', 1990),
#  ('Total Recall', 1990),
#  ('Tremors', 1990),
#  ('10 Things I Hate About You', 1999),
#  ('200 Cigarettes', 1999),
#  ('8MM', 1999),
#  ('A Dog of Flanders', 1999),
#  ('A Walk on the Moon', 1999),
#  ('American Beauty', 1999),
#  ('American Pie', 1999),
#  ('An Ideal Husband', 1999),
#  ('Analyze This', 1999),
#  ("Angela's Ashes", 1999),
#  ('Anna and the King', 1999),
#  ('Any Given Sunday', 1999),
#  ('Anywhere But Here', 1999),
#  ('Arlington Road', 1999),
#  ('At First Sight', 1999),
#  ('Austin Powers: The Spy Who Shagged Me', 1999),
#  ('Baby Geniuses', 1999),
#  ('Bats', 1999),
#  ('Being John Malkovich', 1999),
#  ('Beyond the Mat', 1999),
#  ('Bicentennial Man', 1999),
#  ('Big Daddy', 1999),
#  ('Blast from the Past', 1999),
#  ('Blue Streak', 1999),
#  ('Bowfinger', 1999),
#  ("Boys Don't Cry", 1999),
#  ('Bringing Out the Dead', 1999),
#  ('Brokedown Palace', 1999),
#  ("But I'm a Cheerleader", 1999),
#  ('Chill Factor', 1999),
#  ('Cradle Will Rock', 1999),
#  ('Cruel Intentions', 1999),
#  ('Deep Blue Sea', 1999),
#  ('Detroit Rock City', 1999),
#  ('Deuce Bigalow: Male Gigolo', 1999),
#  ('Dick', 1999),
#  ('Dogma', 1999),
#  ('Double Jeopardy', 1999),
#  ("Doug's 1st Movie", 1999),
#  ('Drive Me Crazy', 1999),
#  ('Drop Dead Gorgeous', 1999),
#  ('Dudley Do-Right', 1999),
#  ('East Is East', 1999),
#  ('Edtv', 1999),
#  ('Election', 1999),
#  ('End of Days', 1999),
#  ('Entrapment', 1999),
#  ('eXistenZ', 1999),
#  ('Eye of the Beholder', 1999),
#  ('Eyes Wide Shut', 1999),
#  ('Fantasia 2000', 1999),
#  ('Fight Club', 1999),
#  ('Flawless', 1999),
#  ('Foolish', 1999),
#  ('For Love of the Game', 1999),
#  ('Galaxy Quest', 1999),
#  ('Ghost Dog: The Way of the Samurai', 1999),
#  ('Girl, Interrupted', 1999),
#  ('Go', 1999),
#  ('Held Up', 1999),
#  ('House on Haunted Hill', 1999),
#  ('Idle Hands', 1999),
#  ('In Dreams', 1999),
#  ('In Too Deep', 1999),
#  ('Inspector Gadget', 1999),
#  ('Instinct', 1999),
#  ('Jakob the Liar', 1999),
#  ('Jawbreaker', 1999),
#  ('Lake Placid', 1999),
#  ('Light It Up', 1999),
#  ('Love Stinks', 1999),
#  ('Magnolia', 1999),
#  ('Man on the Moon', 1999),
#  ('Message in a Bottle', 1999),
#  ('Mickey Blue Eyes', 1999),
#  ('Mumford', 1999),
#  ('Muppets from Space', 1999),
#  ('My Favorite Martian', 1999),
#  ('Mystery Men', 1999),
#  ('Mystery, Alaska', 1999),
#  ('Notting Hill', 1999),
#  ('Office Space', 1999),
#  ('Outside Providence', 1999),
#  ('Payback', 1999),
#  ('Play It to the Bone', 1999),
#  ('Pushing Tin', 1999),
#  ('Random Hearts', 1999),
#  ('Ravenous', 1999),
#  ('Runaway Bride', 1999),
#  ("She's All That", 1999),
#  ('Simply Irresistible', 1999),
#  ('Snow Falling on Cedars', 1999),
#  ('South Park: Bigger Longer & Uncut', 1999),
#  ('Star Wars: Episode I - The Phantom Menace', 1999),
#  ('Stigmata', 1999),
#  ('Stir of Echoes', 1999),
#  ('Stuart Little', 1999),
#  ('Summer of Sam', 1999),
#  ('Superstar', 1999),
#  ('Tea with Mussolini', 1999),
#  ('The 13th Warrior', 1999),
#  ('The Adventures of Elmo in Grouchland', 1999),
#  ("The Astronaut's Wife", 1999),
#  ("The Astronaut's Wife", 1999),
#  ('The Best Man', 1999),
#  ('The Blair Witch Project', 1999),
#  ('The Bone Collector', 1999),
#  ('The Corruptor', 1999),
#  ('The Deep End of the Ocean', 1999),
#  ('The End of the Affair', 1999),
#  ("The General's Daughter", 1999),
#  ('The Green Mile', 1999),
#  ('The Haunting', 1999),
#  ('The Hurricane', 1999),
#  ('The Insider', 1999),
#  ('The Iron Giant', 1999),
#  ('The Limey', 1999),
#  ('The Matrix', 1999),
#  ('The Messenger: The Story of Joan of Arc', 1999),
#  ('The Muse', 1999),
#  ('The Ninth Gate', 1999),
#  ('The Omega Code', 1999),
#  ('The Out-of-Towners', 1999),
#  ('The Rage: Carrie 2', 1999),
#  ('The Sixth Sense', 1999),
#  ('The Story of Us', 1999),
#  ('The Straight Story', 1999),
#  ('The Talented Mr. Ripley', 1999),
#  ('The Thirteenth Floor', 1999),
#  ('The Thomas Crown Affair', 1999),
#  ('The Virgin Suicides', 1999),
#  ('The Wood', 1999),
#  ('The World Is Not Enough', 1999),
#  ('Three Kings', 1999),
#  ('Three to Tango', 1999),
#  ('Topsy-Turvy', 1999),
#  ('Toy Story 2', 1999),
#  ("Trippin'", 1999),
#  ('Universal Soldier: The Return', 1999),
#  ('Varsity Blues', 1999),
#  ('Wild Wild West', 1999),
#  ('Wing Commander', 1999)]

# %% [markdown]
# ## 0.2.8 Using BETWEEN

# %%
# Select the title and release_year for films released between 1990 and 2000
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year BETWEEN 1990 AND 2000;
            
            """).fetchall()
# Out:
# [('Arachnophobia', 1990),
#  ('Back to the Future Part III', 1990),
#  ("Child's Play 2", 1990),
#  ('Dances with Wolves', 1990),
#  ('Days of Thunder', 1990),
#  ('Dick Tracy', 1990),
#  ('Die Hard 2', 1990),
#  ('Edward Scissorhands', 1990),
#  ('Flatliners', 1990),
#  ('Ghost', 1990),
#  ('Goodfellas', 1990),
#  ('Gremlins 2: The New Batch', 1990),
#  ('Home Alone', 1990),
#  ('Kindergarten Cop', 1990),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 1990),
#  ('Metropolitan', 1990),
#  ('Midnight Cabaret', 1990),
#  ("Mo' Better Blues", 1990),
#  ('Predator 2', 1990),
#  ('Pretty Woman', 1990),
#  ('Quigley Down Under', 1990),
#  ('Shipwrecked', 1990),
#  ('Spaced Invaders', 1990),
#  ('The Adventures of Ford Fairlane', 1990),
#  ('The Godfather: Part III', 1990),
#  ('The Hunt for Red October', 1990),
#  ('Total Recall', 1990),
#  ('Total Recall', 1990),
#  ('Tremors', 1990),
#  ('Two Evil Eyes', 1990),
#  ('Beastmaster 2: Through the Portal of Time', 1991),
#  ("Bill & Ted's Bogus Journey", 1991),
#  ('Boyz n the Hood', 1991),
#  ('Cape Fear', 1991),
#  ('Double Impact', 1991),
#  ('Flight of the Intruder', 1991),
#  ("Freddy's Dead: The Final Nightmare", 1991),
#  ('Harley Davidson and the Marlboro Man', 1991),
#  ('Hook', 1991),
#  ('House Party 2', 1991),
#  ('Hudson Hawk', 1991),
#  ('JFK', 1991),
#  ('Johnny Suede', 1991),
#  ('My Girl', 1991),
#  ('My Own Private Idaho', 1991),
#  ('Return to the Blue Lagoon', 1991),
#  ('Robin Hood: Prince of Thieves', 1991),
#  ('Showdown in Little Tokyo', 1991),
#  ('Slacker', 1991),
#  ('Star Trek VI: The Undiscovered Country', 1991),
#  ('Stone Cold', 1991),
#  ('Straight Out of Brooklyn', 1991),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 1991),
#  ('Terminator 2: Judgment Day', 1991),
#  ('The Addams Family', 1991),
#  ('The Doors', 1991),
#  ('The Fisher King', 1991),
#  ('The Naked Gun 2Â½: The Smell of Fear', 1991),
#  ('The Prince of Tides', 1991),
#  ('The Silence of the Lambs', 1991),
#  ('White Fang', 1991),
#  ('A Few Good Men', 1992),
#  ('A League of Their Own', 1992),
#  ('Aladdin', 1992),
#  ('Alien 3', 1992),
#  ('Army of Darkness', 1992),
#  ('Batman Returns', 1992),
#  ('Boomerang', 1992),
#  ("Bram Stoker's Dracula", 1992),
#  ('Death Becomes Her', 1992),
#  ('El Mariachi', 1992),
#  ('Fortress', 1992),
#  ('Glengarry Glen Ross', 1992),
#  ('Hoffa', 1992),
#  ('Home Alone 2: Lost in New York', 1992),
#  ('Howards End', 1992),
#  ('Lethal Weapon 3', 1992),
#  ('Light Sleeper', 1992),
#  ('Malcolm X', 1992),
#  ('Medicine Man', 1992),
#  ('Memoirs of an Invisible Man', 1992),
#  ('My Cousin Vinny', 1992),
#  ('Patriot Games', 1992),
#  ('Radio Flyer', 1992),
#  ('Raising Cain', 1992),
#  ('Reservoir Dogs', 1992),
#  ('Split Second', 1992),
#  ('The Bodyguard', 1992),
#  ('The Crying Game', 1992),
#  ('The Last of the Mohicans', 1992),
#  ('The Lawnmower Man', 1992),
#  ('The Mighty Ducks', 1992),
#  ('The Muppet Christmas Carol', 1992),
#  ('Unforgiven', 1992),
#  ("Wayne's World", 1992),
#  ('Airborne', 1993),
#  ('Alive', 1993),
#  ('Blood In, Blood Out', 1993),
#  ('Cliffhanger', 1993),
#  ('Cool Runnings', 1993),
#  ('Dazed and Confused', 1993),
#  ('Ed and His Dead Mother', 1993),
#  ('Excessive Force', 1993),
#  ('Gettysburg', 1993),
#  ('Groundhog Day', 1993),
#  ('Hocus Pocus', 1993),
#  ('Jason Goes to Hell: The Final Friday', 1993),
#  ('Jurassic Park', 1993),
#  ('Killing Zoe', 1993),
#  ('Last Action Hero', 1993),
#  ('Les visiteurs', 1993),
#  ('Loaded Weapon 1', 1993),
#  ('Madadayo', 1993),
#  ('Menace II Society', 1993),
#  ('Mrs. Doubtfire', 1993),
#  ('Much Ado About Nothing', 1993),
#  ('Nowhere to Run', 1993),
#  ('Only the Strong', 1993),
#  ('Philadelphia', 1993),
#  ('Poetic Justice', 1993),
#  ('Return of the Living Dead III', 1993),
#  ('RoboCop 3', 1993),
#  ('Romeo Is Bleeding', 1993),
#  ('Ruby in Paradise', 1993),
#  ("Schindler's List", 1993),
#  ('Shadowlands', 1993),
#  ('Sugar Hill', 1993),
#  ('Super Mario Bros.', 1993),
#  ('Teenage Mutant Ninja Turtles III', 1993),
#  ('The Adventures of Huck Finn', 1993),
#  ('The Age of Innocence', 1993),
#  ('The Firm', 1993),
#  ('The Fugitive', 1993),
#  ('The Nutcracker', 1993),
#  ('The Pelican Brief', 1993),
#  ('The Piano', 1993),
#  ('The Princess and the Cobbler', 1993),
#  ('The Remains of the Day', 1993),
#  ('Tombstone', 1993),
#  ('True Romance', 1993),
#  ('Warlock: The Armageddon', 1993),
#  ("What's Eating Gilbert Grape", 1993),
#  ("What's Love Got to Do with It", 1993),
#  ('3 Ninjas Kick Back', 1994),
#  ('A Low Down Dirty Shame', 1994),
#  ('Ace Ventura: Pet Detective', 1994),
#  ("Baby's Day Out", 1994),
#  ('Beverly Hills Cop III', 1994),
#  ('Bullets Over Broadway', 1994),
#  ('Clear and Present Danger', 1994),
#  ('Clerks', 1994),
#  ('Crooklyn', 1994),
#  ('Disclosure', 1994),
#  ('Don Juan DeMarco', 1994),
#  ('Dumb & Dumber', 1994),
#  ('Ed Wood', 1994),
#  ('Exotica', 1994),
#  ('Forrest Gump', 1994),
#  ('Four Weddings and a Funeral', 1994),
#  ('Heavenly Creatures', 1994),
#  ('Highlander: The Final Dimension', 1994),
#  ('Hoop Dreams', 1994),
#  ('Interview with the Vampire: The Vampire Chronicles', 1994),
#  ('Legends of the Fall', 1994),
#  ('Little Women', 1994),
#  ('Men of War', 1994),
#  ('Naked Gun 33 1/3: The Final Insult', 1994),
#  ('New Nightmare', 1994),
#  ('On Deadly Ground', 1994),
#  ('PCU', 1994),
#  ('Police Academy: Mission to Moscow', 1994),
#  ('Pulp Fiction', 1994),
#  ('Rapa Nui', 1994),
#  ('Renaissance Man', 1994),
#  ('RiÂ¢hie RiÂ¢h', 1994),
#  ('Serial Mom', 1994),
#  ('Speed', 1994),
#  ('Star Trek: Generations', 1994),
#  ('Street Fighter', 1994),
#  ('The Client', 1994),
#  ('The Crow', 1994),
#  ('The Flintstones', 1994),
#  ('The Hudsucker Proxy', 1994),
#  ('The Inkwell', 1994),
#  ('The Legend of Drunken Master', 1994),
#  ('The Lion King', 1994),
#  ('The Mask', 1994),
#  ('The River Wild', 1994),
#  ('The Santa Clause', 1994),
#  ('The Shadow', 1994),
#  ('The Shawshank Redemption', 1994),
#  ('The Specialist', 1994),
#  ('There Goes My Baby', 1994),
#  ('Timecop', 1994),
#  ('True Lies', 1994),
#  ('Wolf', 1994),
#  ('Wyatt Earp', 1994),
#  ('Ace Ventura: When Nature Calls', 1995),
#  ('Apollo 13', 1995),
#  ('Assassins', 1995),
#  ('Babe', 1995),
#  ('Bad Boys', 1995),
#  ('Bang', 1995),
#  ('Batman Forever', 1995),
#  ('Before Sunrise', 1995),
#  ('Braveheart', 1995),
#  ('Casino', 1995),
#  ('Casper', 1995),
#  ('Clueless', 1995),
#  ('Congo', 1995),
#  ('Copycat', 1995),
#  ('Crimson Tide', 1995),
#  ('Cutthroat Island', 1995),
#  ('Dead Man Walking', 1995),
#  ('Desperado', 1995),
#  ('Die Hard with a Vengeance', 1995),
#  ('First Knight', 1995),
#  ('Four Rooms', 1995),
#  ('Friday', 1995),
#  ('Get Shorty', 1995),
#  ('GoldenEye', 1995),
#  ('Hackers', 1995),
#  ('Halloween: The Curse of Michael Myers', 1995),
#  ('Home for the Holidays', 1995),
#  ('Jade', 1995),
#  ('Jefferson in Paris', 1995),
#  ('Kids', 1995),
#  ('Kiss of Death', 1995),
#  ('Leaving Las Vegas', 1995),
#  ('Mallrats', 1995),
#  ('Money Train', 1995),
#  ('Mortal Kombat', 1995),
#  ("Mr. Holland's Opus", 1995),
#  ('Nixon', 1995),
#  ('Outbreak', 1995),
#  ('Pocahontas', 1995),
#  ('Richard III', 1995),
#  ('Rob Roy', 1995),
#  ('Rumble in the Bronx', 1995),
#  ('Se7en', 1995),
#  ('Sense and Sensibility', 1995),
#  ('Showgirls', 1995),
#  ('Species', 1995),
#  ('Tales from the Crypt: Demon Knight', 1995),
#  ('Tales from the Hood', 1995),
#  ('Tank Girl', 1995),
#  ('The American President', 1995),
#  ('The Bridges of Madison County', 1995),
#  ('The Brothers McMullen', 1995),
#  ('The Horseman on the Roof', 1995),
#  ('The Incredibly True Adventure of Two Girls in Love', 1995),
#  ('The Indian in the Cupboard', 1995),
#  ('The Jerky Boys', 1995),
#  ('The Net', 1995),
#  ('The Perez Family', 1995),
#  ('The Prophecy', 1995),
#  ('The Quick and the Dead', 1995),
#  ('The Scarlet Letter', 1995),
#  ('The Usual Suspects', 1995),
#  ("Things to Do in Denver When You're Dead", 1995),
#  ('To Die For', 1995),
#  ('Toy Story', 1995),
#  ('Under Siege 2: Dark Territory', 1995),
#  ('Vampire in Brooklyn', 1995),
#  ('Virtuosity', 1995),
#  ('Waterworld', 1995),
#  ('Welcome to the Dollhouse', 1995),
#  ('A Thin Line Between Love and Hate', 1996),
#  ('A Time to Kill', 1996),
#  ('Albino Alligator', 1996),
#  ('Basquiat', 1996),
#  ('Beavis and Butt-Head Do America', 1996),
#  ('Blood and Wine', 1996),
#  ('Bogus', 1996),
#  ('Bottle Rocket', 1996),
#  ('Bound', 1996),
#  ('Broken Arrow', 1996),
#  ('Chain Reaction', 1996),
#  ('City Hall', 1996),
#  ('Courage Under Fire', 1996),
#  ('Daylight', 1996),
#  ('DragonHeart', 1996),
#  ('Eraser', 1996),
#  ('Escape from L.A.', 1996),
#  ('Everyone Says I Love You', 1996),
#  ('Evita', 1996),
#  ('Executive Decision', 1996),
#  ('Extreme Measures', 1996),
#  ('Eye for an Eye', 1996),
#  ('Faithful', 1996),
#  ('Fled', 1996),
#  ('Flipper', 1996),
#  ('Flirting with Disaster', 1996),
#  ('Freeway', 1996),
#  ('From Dusk Till Dawn', 1996),
#  ('Get on the Bus', 1996),
#  ('Ghosts of Mississippi', 1996),
#  ('Girl 6', 1996),
#  ('Hamlet', 1996),
#  ('Hamlet', 1996),
#  ('Happy Gilmore', 1996),
#  ('Harriet the Spy', 1996),
#  ('Independence Day', 1996),
#  ('Jerry Maguire', 1996),
#  ('Jingle All the Way', 1996),
#  ('Kama Sutra: A Tale of Love', 1996),
#  ('Kansas City', 1996),
#  ('Kingpin', 1996),
#  ('Lone Star', 1996),
#  ('Love and Other Catastrophes', 1996),
#  ('Mars Attacks!', 1996),
#  ("Marvin's Room", 1996),
#  ('Mary Reilly', 1996),
#  ('Maximum Risk', 1996),
#  ('Michael Collins', 1996),
#  ('Mission: Impossible', 1996),
#  ('Mrs. Winterbourne', 1996),
#  ('Multiplicity', 1996),
#  ('My Fellow Americans', 1996),
#  ('Phenomenon', 1996),
#  ('Ransom', 1996),
#  ('Romeo + Juliet', 1996),
#  ('Scream', 1996),
#  ('Set It Off', 1996),
#  ('Sgt. Bilko', 1996),
#  ("She's the One", 1996),
#  ('Shine', 1996),
#  ('Silent Trigger', 1996),
#  ('Sleepers', 1996),
#  ('Sling Blade', 1996),
#  ('Space Jam', 1996),
#  ('Spy Hard', 1996),
#  ('Star Trek: First Contact', 1996),
#  ('Striptease', 1996),
#  ('Swingers', 1996),
#  ('That Thing You Do!', 1996),
#  ('The Adventures of Pinocchio', 1996),
#  ('The Cable Guy', 1996),
#  ('The Craft', 1996),
#  ('The Dress', 1996),
#  ('The English Patient', 1996),
#  ('The Fan', 1996),
#  ('The First Wives Club', 1996),
#  ('The Funeral', 1996),
#  ('The Ghost and the Darkness', 1996),
#  ('The Glimmer Man', 1996),
#  ('The Hunchback of Notre Dame', 1996),
#  ('The Island of Dr. Moreau', 1996),
#  ('The Juror', 1996),
#  ('The Last Big Thing', 1996),
#  ('The Long Kiss Goodnight', 1996),
#  ('The Mirror Has Two Faces', 1996),
#  ('The Nutty Professor', 1996),
#  ('The Pallbearer', 1996),
#  ('The Phantom', 1996),
#  ('The Rock', 1996),
#  ('Thinner', 1996),
#  ('Tin Cup', 1996),
#  ('Trainspotting', 1996),
#  ('Trees Lounge', 1996),
#  ('Twister', 1996),
#  ('Up Close & Personal', 1996),
#  ('Waiting for Guffman', 1996),
#  ('Walking and Talking', 1996),
#  ("When the Cat's Away", 1996),
#  ('White Squall', 1996),
#  ('24 7: Twenty Four Seven', 1997),
#  ('8 Heads in a Duffel Bag', 1997),
#  ('A Simple Wish', 1997),
#  ('Absolute Power', 1997),
#  ('Air Bud', 1997),
#  ('Air Force One', 1997),
#  ('Alien: Resurrection', 1997),
#  ('Amistad', 1997),
#  ('An Alan Smithee Film: Burn Hollywood Burn', 1997),
#  ('Anaconda', 1997),
#  ('Anastasia', 1997),
#  ('As Good as It Gets', 1997),
#  ('Austin Powers: International Man of Mystery', 1997),
#  ('Batman & Robin', 1997),
#  ('Boogie Nights', 1997),
#  ('Breakdown', 1997),
#  ("Cats Don't Dance", 1997),
#  ('Character', 1997),
#  ('Chasing Amy', 1997),
#  ('Children of Heaven', 1997),
#  ('Clockwatchers', 1997),
#  ('Con Air', 1997),
#  ('Conspiracy Theory', 1997),
#  ('Contact', 1997),
#  ('Cop Land', 1997),
#  ('Critical Care', 1997),
#  ('Cube', 1997),
#  ("Dante's Peak", 1997),
#  ('Deconstructing Harry', 1997),
#  ('DÃ©jÃ  Vu', 1997),
#  ('Donnie Brasco', 1997),
#  ('Dream with the Fishes', 1997),
#  ("Eve's Bayou", 1997),
#  ('Event Horizon', 1997),
#  ('Face/Off', 1997),
#  ('First Love, Last Rites', 1997),
#  ('Flubber', 1997),
#  ('G.I. Jane', 1997),
#  ('Gattaca', 1997),
#  ('George of the Jungle', 1997),
#  ('Good Will Hunting', 1997),
#  ('Grosse Pointe Blank', 1997),
#  ('Hav Plenty', 1997),
#  ('How to Be a Player', 1997),
#  ('Hurricane Streets', 1997),
#  ('I Know What You Did Last Summer', 1997),
#  ("I Love You, Don't Touch Me!", 1997),
#  ('I Married a Strange Person!', 1997),
#  ('In & Out', 1997),
#  ('In the Company of Men', 1997),
#  ('Jackie Brown', 1997),
#  ('Kiss the Girls', 1997),
#  ('Kundun', 1997),
#  ('L.A. Confidential', 1997),
#  ('Liar Liar', 1997),
#  ('Love and Death on Long Island', 1997),
#  ('Love Jones', 1997),
#  ('Mad City', 1997),
#  ('Men in Black', 1997),
#  ('Midnight in the Garden of Good and Evil', 1997),
#  ('Money Talks', 1997),
#  ('Mortal Kombat: Annihilation', 1997),
#  ('Mr. Nice Guy', 1997),
#  ("My Best Friend's Wedding", 1997),
#  ('Nothing to Lose', 1997),
#  ('Orgazmo', 1997),
#  ('Oscar and Lucinda', 1997),
#  ('Prefontaine', 1997),
#  ('Princess Mononoke', 1997),
#  ('Scream 2', 1997),
#  ('Selena', 1997),
#  ('Seven Years in Tibet', 1997),
#  ('Shadow Conspiracy', 1997),
#  ('Shooting Fish', 1997),
#  ("Smilla's Sense of Snow", 1997),
#  ('Snow White: A Tale of Terror', 1997),
#  ('Soul Food', 1997),
#  ('Sparkler', 1997),
#  ('Spawn', 1997),
#  ('Speed 2: Cruise Control', 1997),
#  ('Spice World', 1997),
#  ('Starship Troopers', 1997),
#  ('Steel', 1997),
#  ('Switchback', 1997),
#  ('The Apostle', 1997),
#  ('The Borrowers', 1997),
#  ('The Chambermaid on the Titanic', 1997),
#  ('The Cure', 1997),
#  ("The Devil's Advocate", 1997),
#  ("The Devil's Own", 1997),
#  ('The Edge', 1997),
#  ('The Fifth Element', 1997),
#  ('The Full Monty', 1997),
#  ('The Full Monty', 1997),
#  ('The Game', 1997),
#  ('The Ice Storm', 1997),
#  ('The Jackal', 1997),
#  ('The Last Time I Committed Suicide', 1997),
#  ('The Lost World: Jurassic Park', 1997),
#  ('The Man Who Knew Too Little', 1997),
#  ('The Peacemaker', 1997),
#  ('The Postman', 1997),
#  ('The Rainmaker', 1997),
#  ('The Relic', 1997),
#  ('The Saint', 1997),
#  ('The Spanish Prisoner', 1997),
#  ('The Sticky Fingers of Time', 1997),
#  ('The Sweet Hereafter', 1997),
#  ('The Swindle', 1997),
#  ('Titanic', 1997),
#  ('Tomorrow Never Dies', 1997),
#  ('Trekkies', 1997),
#  ('Turbulence', 1997),
#  ('Two Girls and a Guy', 1997),
#  ("Ulee's Gold", 1997),
#  ('Volcano', 1997),
#  ('Wag the Dog', 1997),
#  ('Warriors of Virtue', 1997),
#  ('20 Dates', 1998),
#  (54, 1998),
#  ("A Bug's Life", 1998),
#  ('A Civil Action', 1998),
#  ('A Night at the Roxbury', 1998),
#  ('A Simple Plan', 1998),
#  ('American History X', 1998),
#  ('Among Giants', 1998),
#  ('Antz', 1998),
#  ('Armageddon', 1998),
#  ('Babe: Pig in the City', 1998),
#  ("Barney's Great Adventure", 1998),
#  ('Beloved', 1998),
#  ('Blade', 1998),
#  ('Bride of Chucky', 1998),
#  ('Broken Vessels', 1998),
#  ("Buffalo '66", 1998),
#  ('Bulworth', 1998),
#  ("Can't Hardly Wait", 1998),
#  ('Celebrity', 1998),
#  ('Central Station', 1998),
#  ('Chairman of the Board', 1998),
#  ('City of Angels', 1998),
#  ('Clay Pigeons', 1998),
#  ('Dancer, Texas Pop. 81', 1998),
#  ('Dark City', 1998),
#  ('Dead Man on Campus', 1998),
#  ('Deep Impact', 1998),
#  ('Deep Rising', 1998),
#  ('Desert Blue', 1998),
#  ('Dirty Work', 1998),
#  ('Disturbing Behavior', 1998),
#  ('Doctor Dolittle', 1998),
#  ('Earth', 1998),
#  ('Elizabeth', 1998),
#  ('Enemy of the State', 1998),
#  ('Ever After: A Cinderella Story', 1998),
#  ('Fear and Loathing in Las Vegas', 1998),
#  ('Gods and Monsters', 1998),
#  ('Half Baked', 1998),
#  ('Happiness', 1998),
#  ('Hard Rain', 1998),
#  ('He Got Game', 1998),
#  ('Holy Man', 1998),
#  ('Home Fries', 1998),
#  ('Hope Floats', 1998),
#  ('How Stella Got Her Groove Back', 1998),
#  ('I Got the Hook Up', 1998),
#  ('I Still Know What You Did Last Summer', 1998),
#  ('Illuminata', 1998),
#  ('Knock Off', 1998),
#  ('La otra conquista', 1998),
#  ('Les couloirs du temps: Les visiteurs II', 1998),
#  ('Lethal Weapon 4', 1998),
#  ('Little Voice', 1998),
#  ('Living Out Loud', 1998),
#  ('Lock, Stock and Two Smoking Barrels', 1998),
#  ('Lost in Space', 1998),
#  ('Meet Joe Black', 1998),
#  ('Meet the Deedles', 1998),
#  ('Mercury Rising', 1998),
#  ('Mercury Rising', 1998),
#  ('Mighty Joe Young', 1998),
#  ('Mulan', 1998),
#  ('Naturally Native', 1998),
#  ('Next Stop Wonderland', 1998),
#  ('One True Thing', 1998),
#  ('Out of Sight', 1998),
#  ('Patch Adams', 1998),
#  ('Pi', 1998),
#  ('Practical Magic', 1998),
#  ('Primary Colors', 1998),
#  ('Ronin', 1998),
#  ('Rounders', 1998),
#  ('Run Lola Run', 1998),
#  ('Rushmore', 1998),
#  ('Safe Men', 1998),
#  ('Saving Private Ryan', 1998),
#  ('Shakespeare in Love', 1998),
#  ('Simon Birch', 1998),
#  ('Six Days Seven Nights', 1998),
#  ('Six-String Samurai', 1998),
#  ('Slam', 1998),
#  ('Sliding Doors', 1998),
#  ('Slums of Beverly Hills', 1998),
#  ('Small Soldiers', 1998),
#  ('Smoke Signals', 1998),
#  ('Snake Eyes', 1998),
#  ('Soldier', 1998),
#  ('Sphere', 1998),
#  ('Star Trek: Insurrection', 1998),
#  ('Stepmom', 1998),
#  ('Stiff Upper Lips', 1998),
#  ('Tango', 1998),
#  ('Taxman', 1998),
#  ('The Big Hit', 1998),
#  ('The Big Lebowski', 1998),
#  ('The Big Swap', 1998),
#  ('The Celebration', 1998),
#  ('The Faculty', 1998),
#  ('The Horse Whisperer', 1998),
#  ('The Land Girls', 1998),
#  ('The Love Letter', 1998),
#  ('The Love Letter', 1998),
#  ('The Magic Sword: Quest for Camelot', 1998),
#  ('The Man in the Iron Mask', 1998),
#  ('The Mask of Zorro', 1998),
#  ('The Mighty', 1998),
#  ('The Negotiator', 1998),
#  ('The Newton Boys', 1998),
#  ('The Object of My Affection', 1998),
#  ('The Players Club', 1998),
#  ('The Prince of Egypt', 1998),
#  ('The Red Violin', 1998),
#  ('The Replacement Killers', 1998),
#  ('The Rugrats Movie', 1998),
#  ('The Siege', 1998),
#  ('The Thin Red Line', 1998),
#  ('The Truman Show', 1998),
#  ('The Velocity of Gary', 1998),
#  ('The Waterboy', 1998),
#  ('The X Files', 1998),
#  ("There's Something About Mary", 1998),
#  ('Urban Legend', 1998),
#  ('Vampires', 1998),
#  ('Velvet Goldmine', 1998),
#  ('Very Bad Things', 1998),
#  ('Waking Ned Devine', 1998),
#  ('What Dreams May Come', 1998),
#  ('Wild Things', 1998),
#  ('Without Limits', 1998),
#  ('Woo', 1998),
#  ("You've Got Mail", 1998),
#  ('Zero Effect', 1998),
#  ('10 Things I Hate About You', 1999),
#  ('200 Cigarettes', 1999),
#  ('8MM', 1999),
#  ('A Dog of Flanders', 1999),
#  ('A Room for Romeo Brass', 1999),
#  ('A Walk on the Moon', 1999),
#  ('Aimee & Jaguar', 1999),
#  ('American Beauty', 1999),
#  ('American Pie', 1999),
#  ('An Ideal Husband', 1999),
#  ('Analyze This', 1999),
#  ("Angela's Ashes", 1999),
#  ('Anna and the King', 1999),
#  ('Any Given Sunday', 1999),
#  ('Anywhere But Here', 1999),
#  ('Arlington Road', 1999),
#  ('At First Sight', 1999),
#  ('Austin Powers: The Spy Who Shagged Me', 1999),
#  ('Baby Geniuses', 1999),
#  ('Bats', 1999),
#  ('Being John Malkovich', 1999),
#  ('Beyond the Mat', 1999),
#  ('Bicentennial Man', 1999),
#  ('Big Daddy', 1999),
#  ('Blast from the Past', 1999),
#  ('Blue Streak', 1999),
#  ('Bowfinger', 1999),
#  ("Boys Don't Cry", 1999),
#  ('Breakfast of Champions', 1999),
#  ('Bringing Out the Dead', 1999),
#  ('Brokedown Palace', 1999),
#  ("But I'm a Cheerleader", 1999),
#  ('Chill Factor', 1999),
#  ('Cradle Will Rock', 1999),
#  ('Crazy in Alabama', 1999),
#  ('Cruel Intentions', 1999),
#  ('Deep Blue Sea', 1999),
#  ('Deterrence', 1999),
#  ('Detroit Rock City', 1999),
#  ('Deuce Bigalow: Male Gigolo', 1999),
#  ('Dick', 1999),
#  ('Dogma', 1999),
#  ('Double Jeopardy', 1999),
#  ("Doug's 1st Movie", 1999),
#  ('Dreaming of Joseph Lees', 1999),
#  ('Drive Me Crazy', 1999),
#  ('Drop Dead Gorgeous', 1999),
#  ('Dudley Do-Right', 1999),
#  ('East Is East', 1999),
#  ('Edtv', 1999),
#  ('Election', 1999),
#  ('End of Days', 1999),
#  ('Entrapment', 1999),
#  ('eXistenZ', 1999),
#  ('Eye of the Beholder', 1999),
#  ('Eyes Wide Shut', 1999),
#  ('Fantasia 2000', 1999),
#  ("Felicia's Journey", 1999),
#  ('Fight Club', 1999),
#  ('Flawless', 1999),
#  ('Foolish', 1999),
#  ('For Love of the Game', 1999),
#  ('Galaxy Quest', 1999),
#  ('Ghost Dog: The Way of the Samurai', 1999),
#  ('Girl, Interrupted', 1999),
#  ('Go', 1999),
#  ('Godzilla 2000', 1999),
#  ('Happy, Texas', 1999),
#  ('Held Up', 1999),
#  ('House on Haunted Hill', 1999),
#  ('Human Traffic', 1999),
#  ('Idle Hands', 1999),
#  ('In Dreams', 1999),
#  ('In Too Deep', 1999),
#  ('Inspector Gadget', 1999),
#  ('Instinct', 1999),
#  ('Jakob the Liar', 1999),
#  ('Jawbreaker', 1999),
#  ("Jesus' Son", 1999),
#  ('Just Looking', 1999),
#  ('Lake Placid', 1999),
#  ('Light It Up', 1999),
#  ('Limbo', 1999),
#  ('Love Stinks', 1999),
#  ('Magnolia', 1999),
#  ('Man on the Moon', 1999),
#  ('Message in a Bottle', 1999),
#  ('Mickey Blue Eyes', 1999),
#  ('Molly', 1999),
#  ('Mumford', 1999),
#  ('Muppets from Space', 1999),
#  ('My Favorite Martian', 1999),
#  ('Mystery Men', 1999),
#  ('Mystery, Alaska', 1999),
#  ('Notting Hill', 1999),
#  ('Office Space', 1999),
#  ("One Man's Hero", 1999),
#  ('Outside Providence', 1999),
#  ('Payback', 1999),
#  ('Play It to the Bone', 1999),
#  ('Pushing Tin', 1999),
#  ('Random Hearts', 1999),
#  ('Ravenous', 1999),
#  ('Ride with the Devil', 1999),
#  ('Runaway Bride', 1999),
#  ("She's All That", 1999),
#  ('Simply Irresistible', 1999),
#  ('Smiling Fish & Goat on Fire', 1999),
#  ('Snow Falling on Cedars', 1999),
#  ('South Park: Bigger Longer & Uncut', 1999),
#  ('Speedway Junky', 1999),
#  ('Star Wars: Episode I - The Phantom Menace', 1999),
#  ('Stigmata', 1999),
#  ('Stir of Echoes', 1999),
#  ('Stuart Little', 1999),
#  ('Sugar Town', 1999),
#  ('Summer of Sam', 1999),
#  ('Superstar', 1999),
#  ('Tea with Mussolini', 1999),
#  ('The 13th Warrior', 1999),
#  ('The Adventures of Elmo in Grouchland', 1999),
#  ("The Astronaut's Wife", 1999),
#  ("The Astronaut's Wife", 1999),
#  ('The Basket', 1999),
#  ('The Best Man', 1999),
#  ('The Big Tease', 1999),
#  ('The Blair Witch Project', 1999),
#  ('The Bone Collector', 1999),
#  ('The Boondock Saints', 1999),
#  ('The Corruptor', 1999),
#  ('The Deep End of the Ocean', 1999),
#  ('The End of the Affair', 1999),
#  ("The General's Daughter", 1999),
#  ('The Green Mile', 1999),
#  ('The Haunting', 1999),
#  ('The Hurricane', 1999),
#  ('The Insider', 1999),
#  ('The Iron Giant', 1999),
#  ('The Limey', 1999),
#  ('The Loss of Sexual Innocence', 1999),
#  ('The Matrix', 1999),
#  ('The Messenger: The Story of Joan of Arc', 1999),
#  ('The Muse', 1999),
#  ('The Ninth Gate', 1999),
#  ('The Omega Code', 1999),
#  ('The Out-of-Towners', 1999),
#  ('The Rage: Carrie 2', 1999),
#  ('The Sixth Sense', 1999),
#  ('The Story of Us', 1999),
#  ('The Straight Story', 1999),
#  ('The Talented Mr. Ripley', 1999),
#  ('The Thirteenth Floor', 1999),
#  ('The Thomas Crown Affair', 1999),
#  ('The Virgin Suicides', 1999),
#  ('The Woman Chaser', 1999),
#  ('The Wood', 1999),
#  ('The World Is Not Enough', 1999),
#  ('Three Kings', 1999),
#  ('Three to Tango', 1999),
#  ('Topsy-Turvy', 1999),
#  ('Toy Story 2', 1999),
#  ("Trippin'", 1999),
#  ('Tumbleweeds', 1999),
#  ('Twin Falls Idaho', 1999),
#  ('Universal Soldier: The Return', 1999),
#  ('Varsity Blues', 1999),
#  ('Wild Wild West', 1999),
#  ('Wing Commander', 1999),
#  ('102 Dalmatians', 2000),
#  ('28 Days', 2000),
#  ('3 Strikes', 2000),
#  ('Aberdeen', 2000),
#  ('All the Pretty Horses', 2000),
#  ('Almost Famous', 2000),
#  ('American Psycho', 2000),
#  ('Amores Perros', 2000),
#  ('An Everlasting Piece', 2000),
#  ('Anatomy', 2000),
#  ('Autumn in New York', 2000),
#  ('Bamboozled', 2000),
#  ('Battlefield Earth', 2000),
#  ('Bedazzled', 2000),
#  ('Best in Show', 2000),
#  ("Big Momma's House", 2000),
#  ('Billy Elliot', 2000),
#  ('Bless the Child', 2000),
#  ('Boiler Room', 2000),
#  ('Book of Shadows: Blair Witch 2', 2000),
#  ('Boys and Girls', 2000),
#  ('Bring It On', 2000),
#  ('Brother', 2000),
#  ('Cast Away', 2000),
#  ('Cecil B. DeMented', 2000),
#  ('Center Stage', 2000),
#  ("Charlie's Angels", 2000),
#  ('Chicken Run', 2000),
#  ('Chocolat', 2000),
#  ('Chuck & Buck', 2000),
#  ('Coyote Ugly', 2000),
#  ('Crouching Tiger, Hidden Dragon', 2000),
#  ('Dancer in the Dark', 2000),
#  ('Digimon: The Movie', 2000),
#  ('Dinner Rush', 2000),
#  ('Dinosaur', 2000),
#  ('Down to You', 2000),
#  ('Dracula 2000', 2000),
#  ('Drowning Mona', 2000),
#  ("Dude, Where's My Car?", 2000),
#  ('Duets', 2000),
#  ('Erin Brockovich', 2000),
#  ('Everything Put Together', 2000),
#  ('Final Destination', 2000),
#  ('Finding Forrester', 2000),
#  ('Fiza', 2000),
#  ('Frequency', 2000),
#  ('George Washington', 2000),
#  ('Get Carter', 2000),
#  ('Gladiator', 2000),
#  ('Gone in Sixty Seconds', 2000),
#  ('Gossip', 2000),
#  ('Groove', 2000),
#  ('Gun Shy', 2000),
#  ('Hanging Up', 2000),
#  ('Here on Earth', 2000),
#  ('High Fidelity', 2000),
#  ('Highlander: Endgame', 2000),
#  ('Hollow Man', 2000),
#  ('How the Grinch Stole Christmas', 2000),
#  ('Hum To Mohabbat Karega', 2000),
#  ('I Dreamed of Africa', 2000),
#  ("Isn't She Great", 2000),
#  ('Keeping the Faith', 2000),
#  ('Lisa Picard Is Famous', 2000),
#  ('Little Nicky', 2000),
#  ('Loser', 2000),
#  ('Lost Souls', 2000),
#  ('Love & Basketball', 2000),
#  ('Lucky Numbers', 2000),
#  ('Luminarias', 2000),
#  ('Me, Myself & Irene', 2000),
#  ('Meet the Parents', 2000),
#  ('Memento', 2000),
#  ('Men of Honor', 2000),
#  ('Mercy Streets', 2000),
#  ('Michael Jordan to the Max', 2000),
#  ('Miss Congeniality', 2000),
#  ('Mission to Mars', 2000),
#  ('Mission: Impossible II', 2000),
#  ('My Dog Skip', 2000),
#  ('Next Friday', 2000),
#  ('Nine Queens', 2000),
#  ('Nurse Betty', 2000),
#  ('Nutty Professor II: The Klumps', 2000),
#  ('O Brother, Where Art Thou?', 2000),
#  ('Pandaemonium', 2000),
#  ('Pay It Forward', 2000),
#  ('Pitch Black', 2000),
#  ('PokÃ©mon 3: The Movie', 2000),
#  ('Pollock', 2000),
#  ('Proof of Life', 2000),
#  ('Psycho Beach Party', 2000),
#  ('Quills', 2000),
#  ('Ready to Rumble', 2000),
#  ('Red Planet', 2000),
#  ('Reindeer Games', 2000),
#  ('Remember the Titans', 2000),
#  ('Requiem for a Dream', 2000),
#  ('Return to Me', 2000),
#  ('Road Trip', 2000),
#  ('Romeo Must Die', 2000),
#  ('Rugrats in Paris: The Movie', 2000),
#  ('Scream 3', 2000),
#  ('Screwed', 2000),
#  ('Sexy Beast', 2000),
#  ('Shadow of the Vampire', 2000),
#  ('Shaft', 2000),
#  ('Shanghai Noon', 2000),
#  ('Small Time Crooks', 2000),
#  ('Snatch', 2000),
#  ('Snatch', 2000),
#  ('Snow Day', 2000),
#  ('Songcatcher', 2000),
#  ('Space Cowboys', 2000),
#  ('Supernova', 2000),
#  ('Tadpole', 2000),
#  ('The 6th Day', 2000),
#  ('The Adventures of Rocky & Bullwinkle', 2000),
#  ('The Art of War', 2000),
#  ('The Beach', 2000),
#  ('The Broken Hearts Club: A Romantic Comedy', 2000),
#  ('The Cell', 2000),
#  ('The Circle', 2000),
#  ('The Claim', 2000),
#  ('The Claim', 2000),
#  ('The Contender', 2000),
#  ('The Crew', 2000),
#  ("The Emperor's New Groove", 2000),
#  ('The Family Man', 2000),
#  ('The Flintstones in Viva Rock Vegas', 2000),
#  ('The House of Mirth', 2000),
#  ('The In Crowd', 2000),
#  ('The Kid', 2000),
#  ('The Ladies Man', 2000),
#  ('The Legend of Bagger Vance', 2000),
#  ('The Little Vampire', 2000),
#  ('The Next Best Thing', 2000),
#  ('The Original Kings of Comedy', 2000),
#  ('The Patriot', 2000),
#  ('The Perfect Storm', 2000),
#  ('The Replacements', 2000),
#  ('The Road to El Dorado', 2000),
#  ('The Skulls', 2000),
#  ('The Specials', 2000),
#  ('The Tigger Movie', 2000),
#  ('The Watcher', 2000),
#  ('The Way of the Gun', 2000),
#  ('The Whole Nine Yards', 2000),
#  ('The Widow of Saint-Pierre', 2000),
#  ('The Yards', 2000),
#  ('The Young Unknowns', 2000),
#  ('Thirteen Days', 2000),
#  ('Thomas and the Magic Railroad', 2000),
#  ('Titan A.E.', 2000),
#  ('Traffic', 2000),
#  ('U-571', 2000),
#  ('Unbreakable', 2000),
#  ('Urban Legends: Final Cut', 2000),
#  ('Urbania', 2000),
#  ('Vertical Limit', 2000),
#  ('What Lies Beneath', 2000),
#  ('What Planet Are You From?', 2000),
#  ('What Women Want', 2000),
#  ('Whatever It Takes', 2000),
#  ('Where the Heart Is', 2000),
#  ('Whipped', 2000),
#  ('Woman on Top', 2000),
#  ('Wonder Boys', 2000),
#  ('X-Men', 2000),
#  ('You Can Count on Me', 2000)]

# %%
# Build on your previous query to select only films with a budget over $100 million.
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000;
            
            """).fetchall()
# Out:
# [('Terminator 2: Judgment Day', 1991),
#  ('True Lies', 1994),
#  ('Waterworld', 1995),
#  ('Batman & Robin', 1997),
#  ("Dante's Peak", 1997),
#  ('Princess Mononoke', 1997),
#  ('Speed 2: Cruise Control', 1997),
#  ('Starship Troopers', 1997),
#  ('Titanic', 1997),
#  ('Tomorrow Never Dies', 1997),
#  ("A Bug's Life", 1998),
#  ('Antz', 1998),
#  ('Armageddon', 1998),
#  ('Les couloirs du temps: Les visiteurs II', 1998),
#  ('Lethal Weapon 4', 1998),
#  ('Tango', 1998),
#  ('Godzilla 2000', 1999),
#  ('Star Wars: Episode I - The Phantom Menace', 1999),
#  ('Stuart Little', 1999),
#  ('The Messenger: The Story of Joan of Arc', 1999),
#  ('The World Is Not Enough', 1999),
#  ('Wild Wild West', 1999),
#  ('Dinosaur', 2000),
#  ('Gladiator', 2000),
#  ('How the Grinch Stole Christmas', 2000),
#  ('Mission: Impossible II', 2000),
#  ('The Patriot', 2000),
#  ('The Perfect Storm', 2000)]

# %%
# Now, restrict the query to only return Spanish-language films.
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000 AND language = 'Spanish';
            
            """).fetchall()
# Out:
# [('Tango', 1998)]

# %%
# Now, restrict the query to only return Spanish-language films.
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year BETWEEN 1990 AND 2000 AND budget > 100000000 AND (language = 'Spanish' OR language = 'French');
            
            """).fetchall()
# Out:
# [('Les couloirs du temps: Les visiteurs II', 1998), ('Tango', 1998)]

# %% [markdown]
# ## 0.2.9 LIKE and NOT LIKE

# %%
# Select the names that start with B
cur.execute("""
            
            SELECT name 
            FROM people 
            WHERE name LIKE 'B%';
            
            """).fetchall()
# Out:
# [('B.J. Novak',),
#  ('Babak Najafi',),
#  ('Babar Ahmed',),
#  ('Bahare Seddiqi',),
#  ('Bai Ling',),
#  ('Bailee Madison',),
#  ('Balinese Tari Legong Dancers',),
#  ('BÃ¡lint PÃ©ntek',),
#  ('Baltasar KormÃ¡kur',),
#  ('Balthazar Getty',),
#  ('Bam Margera',),
#  ('Barack Obama',),
#  ('Barbara Bach',),
#  ('Barbara Billingsley',),
#  ('Barbara Carrera',),
#  ('BÃ¡rbara Goenaga',),
#  ('Barbara Hershey',),
#  ('Barbara Kowalcyk',),
#  ('BÃ¡rbara Mori',),
#  ('Barbet Schroeder',),
#  ('Barbie Castro',),
#  ('Barbra Streisand',),
#  ('Bari Hyman',),
#  ('Barnard Hughes',),
#  ('Barney Clark',),
#  ('Barney Frank',),
#  ('Barret Oliver',),
#  ('Barrett Esposito',),
#  ('Barry Bostwick',),
#  ('Barry Cook',),
#  ('Barry Corbin',),
#  ('Barry Dennen',),
#  ('Barry Fitzgerald',),
#  ('Barry Levinson',),
#  ('Barry Lynch',),
#  ('Barry Shabaka Henley',),
#  ('Barry Skolnick',),
#  ('Barry Sonnenfeld',),
#  ('Barry W. Blaustein',),
#  ('Barry Watson',),
#  ('Bart Freundlich',),
#  ('Bart Shatto',),
#  ('Bart the Bear',),
#  ('Bashar Rahal',),
#  ('Basher Savage',),
#  ('Basil Rathbone',),
#  ('Baz Luhrmann',),
#  ('BÃ©atrice Bonifassi',),
#  ('BÃ©atrice Dalle',),
#  ('Beatrice Ntuba',),
#  ('Beatrice Straight',),
#  ('Beau Bridges',),
#  ('Beau Garrett',),
#  ('Beau Knapp',),
#  ('Beau Mirchoff',),
#  ('Bebe Neuwirth',),
#  ('Becky Smith',),
#  ('Beeban Kidron',),
#  ('Behrouz Vossoughi',),
#  ('BelÃ©n Rueda',),
#  ('Bella Heathcote',),
#  ('Bella Thorne',),
#  ('Ben Affleck',),
#  ('Ben Browder',),
#  ('Ben Chaplin',),
#  ('Ben Crompton',),
#  ('Ben Cross',),
#  ('Ben Daniels',),
#  ('Ben Davies',),
#  ('Ben Diskin',),
#  ('Ben Falcone',),
#  ('Ben Feldman',),
#  ('Ben Gazzara',),
#  ('Ben Johnson',),
#  ('Ben Lewin',),
#  ('Ben Mendelsohn',),
#  ('Ben Miles',),
#  ('Ben Miller',),
#  ('Ben Platt',),
#  ('Ben Schwartz',),
#  ('Ben Stassen',),
#  ('Ben Stein',),
#  ('Ben Stiller',),
#  ('Ben Vereen',),
#  ('Ben Wheatley',),
#  ('Ben Youcef',),
#  ('Ben Younger',),
#  ('Benedek Fliegauf',),
#  ('Benedict Cumberbatch',),
#  ('Benedict Wong',),
#  ('Benedikt Erlingsson',),
#  ('Benh Zeitlin',),
#  ('Benjamin A. Onyango',),
#  ('Benjamin Dickinson',),
#  ('Benjamin Fletcher',),
#  ('Benjamin J. Cain Jr.',),
#  ('Benjamin Roberds',),
#  ('Benjamin Walker',),
#  ('Bennett Miller',),
#  ('Benni Diez',),
#  ('Benno FÃ¼rmann',),
#  ('Benny Boom',),
#  ('BenoÃ®t Magimel',),
#  ('BenoÃ®t Poelvoorde',),
#  ('Benson Lee',),
#  ('BÃ©rÃ©nice Bejo',),
#  ('BergÃ¼zar Korel',),
#  ('Bern Cohen',),
#  ('Bernadette Peters',),
#  ('Bernard Cribbins',),
#  ('Bernard Fox',),
#  ('Bernard Hill',),
#  ('Bernardo Bertolucci',),
#  ('Bernardo Saracino',),
#  ('Bernie Casey',),
#  ('Bernie Mac',),
#  ('Bernie Sanders',),
#  ('Bertrand Cantat',),
#  ('Bess Armstrong',),
#  ('Bessie Love',),
#  ('Beth Broderick',),
#  ('Beth Grant',),
#  ('Beth Riesgraf',),
#  ('Bethany Blakey',),
#  ('Bethany Joy Lenz',),
#  ('Beto GÃ³mez',),
#  ('Betsy Baker',),
#  ('Betsy Palmer',),
#  ('Betsy Russell',),
#  ('Betty Hutton',),
#  ('Betty Thomas',),
#  ("Beverly D'Angelo",),
#  ('Beverly Randolph',),
#  ('Bhama',),
#  ('Bhavkhandan Singh Rakhra',),
#  ('Bhole Baba',),
#  ('Bhoomika Chawla',),
#  ('Bianca Brigitte VanDamme',),
#  ('Bianca Collins',),
#  ('Bianca Kajlich',),
#  ('Bibo Bergeron',),
#  ('Big Budah',),
#  ('Bigas Luna',),
#  ('Bill Allen',),
#  ('Bill Bailey',),
#  ('Bill Baird',),
#  ('Bill Benenson',),
#  ('Bill Clinton',),
#  ('Bill Cobbs',),
#  ('Bill Condon',),
#  ('Bill Duke',),
#  ('Bill Erwin',),
#  ('Bill Fagerbakke',),
#  ('Bill Farmer',),
#  ('Bill Hickman',),
#  ('Bill Hunter',),
#  ('Bill Irwin',),
#  ('Bill Johnson',),
#  ('Bill Lake',),
#  ('Bill Maher',),
#  ('Bill Martone',),
#  ('Bill Melendez',),
#  ('Bill Muir',),
#  ('Bill Murray',),
#  ('Bill Nunn',),
#  ('Bill Paterson',),
#  ('Bill Paxton',),
#  ('Bill Plympton',),
#  ('Bille August',),
#  ('Bille Woodruff',),
#  ('Billie Burke',),
#  ('Billie Whitelaw',),
#  ('Billy Aaron Brown',),
#  ('Billy Barty',),
#  ('Billy Blair',),
#  ('Billy Bob Thornton',),
#  ('Billy Boyd',),
#  ('Billy Brown',),
#  ('Billy Burke',),
#  ('Billy Campbell',),
#  ('Billy Crudup',),
#  ('Billy Drago',),
#  ('Billy Gardell',),
#  ('Billy Gilbert',),
#  ('Billy Kent',),
#  ('Billy Ray',),
#  ('Billy West',),
#  ('Billy Wilder',),
#  ('Bin Won',),
#  ('Bingbing Fan',),
#  ('Bingbing Li',),
#  ('Bipasha Basu',),
#  ('Birgitte Hjort SÃ¸rensen',),
#  ('Birol Ãœnel',),
#  ('BjÃ¶rk',),
#  ('BjÃ¶rn Hlynur Haraldsson',),
#  ('BjÃ¸rn Sundquist',),
#  ('Black Thomas',),
#  ('Blaine Anderson',),
#  ('Blair Brown',),
#  ('Blair Erickson',),
#  ('Blair Hayes',),
#  ('Blair Underwood',),
#  ('Blake Edwards',),
#  ('Blake Lindsley',),
#  ('Blake Ritson',),
#  ('Blanchard Ryan',),
#  ('Blaz Zavrsnik',),
#  ('Blythe Auffarth',),
#  ('Blythe Danner',),
#  ('Bo Huang',),
#  ('Bo Welch',),
#  ('Bo Zenga',),
#  ('Boaz Yakin',),
#  ('Bob Balaban',),
#  ('Bob Clark',),
#  ('Bob Clendenin',),
#  ('Bob Costas',),
#  ('Bob Dole',),
#  ('Bob Dolman',),
#  ('Bob Dylan',),
#  ('Bob Eubanks',),
#  ('Bob Fosse',),
#  ('Bob Giraldi',),
#  ('Bob Gosse',),
#  ('Bob Gunton',),
#  ('Bob Hoskins',),
#  ('Bob Marley',),
#  ('Bob Neill',),
#  ('Bob Newhart',),
#  ('Bob Odenkirk',),
#  ('Bob Peck',),
#  ('Bob Proctor',),
#  ('Bob Rafelson',),
#  ('Bob Ross',),
#  ('Bob Saget',),
#  ('Bob Spiers',),
#  ("Bobb'e J. Thompson",),
#  ('Bobbie Phillips',),
#  ('Bobby Batson',),
#  ('Bobby Block',),
#  ('Bobby Brown',),
#  ('Bobby Coleman',),
#  ('Bobby Deol',),
#  ('Bobby Farrelly',),
#  ('Bobby Kendall',),
#  ('Bobby Lee',),
#  ('Bobby Moynihan',),
#  ('Bobby Roth',),
#  ('Bobcat Goldthwait',),
#  ('Bojana Novakovic',),
#  ('Bokeem Woodbine',),
#  ('Bolaji Badejo',),
#  ('Bolo Yeung',),
#  ('Boman Irani',),
#  ('Bonnie Henna',),
#  ('Bonnie Hunt',),
#  ('Bonnie Lee Bouman',),
#  ('Bonnie Somerville',),
#  ('Bono',),
#  ('Bonz Malone',),
#  ('Boris Kodjoe',),
#  ('Boris Rodriguez',),
#  ('Boyd Banks',),
#  ('Boyd Holbrook',),
#  ('Boys II Men',),
#  ('Brad Anderson',),
#  ('Brad Bird',),
#  ('Brad Copeland',),
#  ('Brad Furman',),
#  ('Brad Garrett',),
#  ('Brad J. Silverman',),
#  ('Brad James',),
#  ('Brad Lee Wind',),
#  ('Brad Leland',),
#  ('Brad Peyton',),
#  ('Brad Pitt',),
#  ('Brad Renfro',),
#  ('Brad Schmidt',),
#  ('Brad Silberling',),
#  ('Brad William Henke',),
#  ('Bradley Cooper',),
#  ('Bradley Parker',),
#  ('Bradley Pierce',),
#  ('Bradley Rust Gray',),
#  ('Bradley Whitford',),
#  ('Brady Corbet',),
#  ('Braeden Lemasters',),
#  ('Brahim Achabbakhe',),
#  ('Brahmanandam',),
#  ('Brandon Camp',),
#  ('Brandon Cronenberg',),
#  ('Brandon Landers',),
#  ('Brandon Middleton',),
#  ('Brandon Molale',),
#  ('Brandon Smith',),
#  ('Brandon T. Jackson',),
#  ('Brandon Trost',),
#  ('Brandy Norwood',),
#  ('Branko Djuric',),
#  ('Breck Eisner',),
#  ('Bree Turner',),
#  ('Bree Williamson',),
#  ('Brenda Bakke',),
#  ('Brenda Blethyn',),
#  ('Brenda Chapman',),
#  ('Brenda Fricker',),
#  ('Brenda Song',),
#  ('Brenda Strong',),
#  ('Brenda Vaccaro',),
#  ('Brendan Coyle',),
#  ('Brendan Doogie Milewski',),
#  ('Brendan Fehr',),
#  ('Brendan Fraser',),
#  ('Brendan Mackey',),
#  ('Brendan Malloy',),
#  ('Brendan Sexton III',),
#  ('Brendon Eggertsen',),
#  ('Brent Anderson',),
#  ('Brent David Fraser',),
#  ('Brent Neale',),
#  ('Brent Sexton',),
#  ('Brenton Spencer',),
#  ('Brett Cullen',),
#  ('Brett Leonard',),
#  ('Brett Piper',),
#  ('Brett Ratner',),
#  ('Brett Wagner',),
#  ('Brian A Miller',),
#  ('Brian Anthony Wilson',),
#  ('Brian Austin Green',),
#  ('Brian Baugh',),
#  ('Brian Blessed',),
#  ('Brian Bosworth',),
#  ('Brian Caunter',),
#  ("Brian d'Arcy James",),
#  ('Brian Dannelly',),
#  ('Brian De Palma',),
#  ('Brian Dennehy',),
#  ('Brian Dietzen',),
#  ('Brian Dorton',),
#  ('Brian Doyle-Murray',),
#  ('Brian Eno',),
#  ("BrÃ\xadan F. O'Byrne",),
#  ('Brian Geraghty',),
#  ('Brian Gibson',),
#  ('Brian Helgeland',),
#  ('Brian Henson',),
#  ('Brian Herzlinger',),
#  ('Brian Howe',),
#  ('Brian Johnson',),
#  ('Brian Keith',),
#  ('Brian Klugman',),
#  ('Brian Koppelman',),
#  ('Brian Lee Franklin',),
#  ('Brian Levant',),
#  ('Brian McNamara',),
#  ("Brian O'Halloran",),
#  ('Brian Percival',),
#  ('Brian Robbins',),
#  ('Brian Steele',),
#  ('Brian Stepanek',),
#  ('Brian Thompson',),
#  ('Brian Trenchard-Smith',),
#  ('Brian Van Holt',),
#  ('Brian Whitaker',),
#  ('Brian Yuzna',),
#  ('Brianna Brown',),
#  ('Brianne Brozey',),
#  ('Bridget Fonda',),
#  ('Bridgette Wilson-Sampras',),
#  ('Bridgit Mendler',),
#  ('Brighton Sharbino',),
#  ('Brigitte Bardot',),
#  ('Brigitte Helm',),
#  ('Brigitte Nielsen',),
#  ('Brion James',),
#  ('Brit Morgan',),
#  ('Britney Spears',),
#  ('Britt Allcroft',),
#  ('Britt Ekland',),
#  ('Brittany Curran',),
#  ('Brittany Daniel',),
#  ('Brittney Powell',),
#  ('Brock Baker',),
#  ('Brock Peters',),
#  ('Bronagh Gallagher',),
#  ('Bronwen Hughes',),
#  ('Brooke Bundy',),
#  ('Brooke Newton',),
#  ('Brooke Shields',),
#  ('Brooke Smith',),
#  ('Brooklynn Proulx',),
#  ('Bruce Alexander',),
#  ('Bruce Altman',),
#  ('Bruce Beresford',),
#  ('Bruce Boxleitner',),
#  ('Bruce Campbell',),
#  ('Bruce Davison',),
#  ('Bruce Dellis',),
#  ('Bruce Dern',),
#  ('Bruce Gooch',),
#  ('Bruce Goodchild',),
#  ('Bruce Green',),
#  ('Bruce Greenwood',),
#  ('Bruce Hopkins',),
#  ('Bruce Hunt',),
#  ('Bruce Kerr',),
#  ('Bruce Macdonald',),
#  ('Bruce Malmuth',),
#  ('Bruce McCulloch',),
#  ('Bruce McDonald',),
#  ('Bruce McGill',),
#  ('Bruce Newbold',),
#  ('Bruce Paltrow',),
#  ('Bruce Payne',),
#  ('Bruce Spence',),
#  ('Bruce Thomas',),
#  ('Bruce Vilanch',),
#  ('Bruce Willis',),
#  ('Bruno Barreto',),
#  ('Bruno Campos',),
#  ('Bruno Ganz',),
#  ('Bruno Kirby',),
#  ('Bryan Barber',),
#  ('Bryan Brown',),
#  ('Bryan Callen',),
#  ('Bryan Dick',),
#  ('Bryan Singer',),
#  ('Bryce Dallas Howard',),
#  ('Bubba Smith',),
#  ('Bud Cort',),
#  ('Bunta Sugawara',),
#  ('Burgess Meredith',),
#  ('Burghart KlauÃŸner',),
#  ('Burl Ives',),
#  ('Burr Steers',),
#  ('Burt Kwouk',),
#  ('Burt Ward',),
#  ('Burt Young',),
#  ('Buster Keaton',),
#  ('Busy Philipps',),
#  ('Buzz Aldrin',),
#  ('Byron Howard',),
#  ('Byron Mann',)]

# %%
# Select the names that have r as the second letter
cur.execute("""
            
            SELECT name 
            FROM people 
            WHERE name LIKE '_r%';
            
            """).fetchall()
# Out:
# [('Ara Celi',),
#  ('Aramis Knight',),
#  ('Arben Bajraktaraj',),
#  ('Arcelia RamÃ\xadrez',),
#  ('Archie Kao',),
#  ('Archie Panjabi',),
#  ('Aretha Franklin',),
#  ('Ari Folman',),
#  ('Ari Gold',),
#  ('Ari Graynor',),
#  ('Ari Kirschenbaum',),
#  ('Ari Sandel',),
#  ('Aria Noelle Curzon',),
#  ('Ariana Neal',),
#  ('Ariana Richards',),
#  ('Ariane Labed',),
#  ('Ariane Schluter',),
#  ('Arie Posin',),
#  ('Ariel Gade',),
#  ('Ariel Hsing',),
#  ('Ariel Vromen',),
#  ('Aries Spears',),
#  ('Arik Ascherman',),
#  ('Arjun Rampal',),
#  ('Arjun Sablok',),
#  ('Arliss Howard',),
#  ('Arly Jover',),
#  ('Armando Riesco',),
#  ('Armin Mueller-Stahl',),
#  ('Armin Rohde',),
#  ('Armin Shimerman',),
#  ('Art Carney',),
#  ('Art Hindle',),
#  ('Art Malik',),
#  ('Arthur Agee',),
#  ('Arthur Hiller',),
#  ("Arthur O'Connell",),
#  ('Arturo Castro',),
#  ('Artyom Bogucharskiy',),
#  ('Aryana Engineer',),
#  ('Brad Anderson',),
#  ('Brad Bird',),
#  ('Brad Copeland',),
#  ('Brad Furman',),
#  ('Brad Garrett',),
#  ('Brad J. Silverman',),
#  ('Brad James',),
#  ('Brad Lee Wind',),
#  ('Brad Leland',),
#  ('Brad Peyton',),
#  ('Brad Pitt',),
#  ('Brad Renfro',),
#  ('Brad Schmidt',),
#  ('Brad Silberling',),
#  ('Brad William Henke',),
#  ('Bradley Cooper',),
#  ('Bradley Parker',),
#  ('Bradley Pierce',),
#  ('Bradley Rust Gray',),
#  ('Bradley Whitford',),
#  ('Brady Corbet',),
#  ('Braeden Lemasters',),
#  ('Brahim Achabbakhe',),
#  ('Brahmanandam',),
#  ('Brandon Camp',),
#  ('Brandon Cronenberg',),
#  ('Brandon Landers',),
#  ('Brandon Middleton',),
#  ('Brandon Molale',),
#  ('Brandon Smith',),
#  ('Brandon T. Jackson',),
#  ('Brandon Trost',),
#  ('Brandy Norwood',),
#  ('Branko Djuric',),
#  ('Breck Eisner',),
#  ('Bree Turner',),
#  ('Bree Williamson',),
#  ('Brenda Bakke',),
#  ('Brenda Blethyn',),
#  ('Brenda Chapman',),
#  ('Brenda Fricker',),
#  ('Brenda Song',),
#  ('Brenda Strong',),
#  ('Brenda Vaccaro',),
#  ('Brendan Coyle',),
#  ('Brendan Doogie Milewski',),
#  ('Brendan Fehr',),
#  ('Brendan Fraser',),
#  ('Brendan Mackey',),
#  ('Brendan Malloy',),
#  ('Brendan Sexton III',),
#  ('Brendon Eggertsen',),
#  ('Brent Anderson',),
#  ('Brent David Fraser',),
#  ('Brent Neale',),
#  ('Brent Sexton',),
#  ('Brenton Spencer',),
#  ('Brett Cullen',),
#  ('Brett Leonard',),
#  ('Brett Piper',),
#  ('Brett Ratner',),
#  ('Brett Wagner',),
#  ('Brian A Miller',),
#  ('Brian Anthony Wilson',),
#  ('Brian Austin Green',),
#  ('Brian Baugh',),
#  ('Brian Blessed',),
#  ('Brian Bosworth',),
#  ('Brian Caunter',),
#  ("Brian d'Arcy James",),
#  ('Brian Dannelly',),
#  ('Brian De Palma',),
#  ('Brian Dennehy',),
#  ('Brian Dietzen',),
#  ('Brian Dorton',),
#  ('Brian Doyle-Murray',),
#  ('Brian Eno',),
#  ("BrÃ\xadan F. O'Byrne",),
#  ('Brian Geraghty',),
#  ('Brian Gibson',),
#  ('Brian Helgeland',),
#  ('Brian Henson',),
#  ('Brian Herzlinger',),
#  ('Brian Howe',),
#  ('Brian Johnson',),
#  ('Brian Keith',),
#  ('Brian Klugman',),
#  ('Brian Koppelman',),
#  ('Brian Lee Franklin',),
#  ('Brian Levant',),
#  ('Brian McNamara',),
#  ("Brian O'Halloran",),
#  ('Brian Percival',),
#  ('Brian Robbins',),
#  ('Brian Steele',),
#  ('Brian Stepanek',),
#  ('Brian Thompson',),
#  ('Brian Trenchard-Smith',),
#  ('Brian Van Holt',),
#  ('Brian Whitaker',),
#  ('Brian Yuzna',),
#  ('Brianna Brown',),
#  ('Brianne Brozey',),
#  ('Bridget Fonda',),
#  ('Bridgette Wilson-Sampras',),
#  ('Bridgit Mendler',),
#  ('Brighton Sharbino',),
#  ('Brigitte Bardot',),
#  ('Brigitte Helm',),
#  ('Brigitte Nielsen',),
#  ('Brion James',),
#  ('Brit Morgan',),
#  ('Britney Spears',),
#  ('Britt Allcroft',),
#  ('Britt Ekland',),
#  ('Brittany Curran',),
#  ('Brittany Daniel',),
#  ('Brittney Powell',),
#  ('Brock Baker',),
#  ('Brock Peters',),
#  ('Bronagh Gallagher',),
#  ('Bronwen Hughes',),
#  ('Brooke Bundy',),
#  ('Brooke Newton',),
#  ('Brooke Shields',),
#  ('Brooke Smith',),
#  ('Brooklynn Proulx',),
#  ('Bruce Alexander',),
#  ('Bruce Altman',),
#  ('Bruce Beresford',),
#  ('Bruce Boxleitner',),
#  ('Bruce Campbell',),
#  ('Bruce Davison',),
#  ('Bruce Dellis',),
#  ('Bruce Dern',),
#  ('Bruce Gooch',),
#  ('Bruce Goodchild',),
#  ('Bruce Green',),
#  ('Bruce Greenwood',),
#  ('Bruce Hopkins',),
#  ('Bruce Hunt',),
#  ('Bruce Kerr',),
#  ('Bruce Macdonald',),
#  ('Bruce Malmuth',),
#  ('Bruce McCulloch',),
#  ('Bruce McDonald',),
#  ('Bruce McGill',),
#  ('Bruce Newbold',),
#  ('Bruce Paltrow',),
#  ('Bruce Payne',),
#  ('Bruce Spence',),
#  ('Bruce Thomas',),
#  ('Bruce Vilanch',),
#  ('Bruce Willis',),
#  ('Bruno Barreto',),
#  ('Bruno Campos',),
#  ('Bruno Ganz',),
#  ('Bruno Kirby',),
#  ('Bryan Barber',),
#  ('Bryan Brown',),
#  ('Bryan Callen',),
#  ('Bryan Dick',),
#  ('Bryan Singer',),
#  ('Bryce Dallas Howard',),
#  ('Craig Bierko',),
#  ('Craig Bolotin',),
#  ('Craig Brewer',),
#  ('Craig Conway',),
#  ('Craig Dougherty',),
#  ('Craig Fairbrass',),
#  ('Craig Ferguson',),
#  ('Craig Gillespie',),
#  ('Craig Hall',),
#  ('Craig Johnson',),
#  ('Craig Mazin',),
#  ('Craig Moss',),
#  ('Craig Parker',),
#  ('Craig R. Baxley',),
#  ('Craig Roberts',),
#  ('Craig Sheffer',),
#  ('Craig Stark',),
#  ('Craig T. Nelson',),
#  ('Craig Zobel',),
#  ('Cree Kelly',),
#  ('Cree Summer',),
#  ('CristiÃ¡n de la Fuente',),
#  ('Cristian Mungiu',),
#  ('Crystal Lowe',),
#  ('Crystal R. Fox',),
#  ('Dr. Dre',),
#  ('Drake',),
#  ('Drake Bell',),
#  ('Drake Doremus',),
#  ('Drea de Matteo',),
#  ('Dreama Walker',),
#  ('Dree Hemingway',),
#  ('Drew Barrymore',),
#  ('Drew Carey',),
#  ('Drew Fuller',),
#  ('Drew Goddard',),
#  ('Drew Powell',),
#  ('Drew Sidora',),
#  ('Drew Waters',),
#  ('Dror Moreh',),
#  ('Eric Ambriz',),
#  ('Eric Blakeney',),
#  ('Eric Blore',),
#  ('Eric Bress',),
#  ('Eric Brevig',),
#  ('Eric Bross',),
#  ('Eric Bugbee',),
#  ('Eric Cantona',),
#  ('Eric Christmas',),
#  ('Eric Dane',),
#  ('Eric Darnell',),
#  ('Eric Eason',),
#  ('Eric Elmosnino',),
#  ('Eric England',),
#  ('Eric Godon',),
#  ('Eric Idle',),
#  ('Eric Jacobson',),
#  ('Eric Johnson',),
#  ('Eric Lange',),
#  ('Eric Lartigau',),
#  ('Eric Lavaine',),
#  ('Eric Leighton',),
#  ('Eric Lloyd',),
#  ('Eric Mabius',),
#  ('Eric McCormack',),
#  ('Eric Mendelsohn',),
#  ('Eric Mendenhall',),
#  ('Eric Nicholas',),
#  ('Eric Peterson',),
#  ('Eric Schaeffer',),
#  ('Eric Schlosser',),
#  ('Eric Schweig',),
#  ('Eric Sheffer Stevens',),
#  ('Eric Stoltz',),
#  ('Eric Stonestreet',),
#  ('Eric Stuart',),
#  ('Eric Styles',),
#  ('Eric Sykes',),
#  ('Eric Valette',),
#  ('Eric Winter',),
#  ('Eric Worre',),
#  ('Erica Leerhsen',),
#  ('Erica Linz',),
#  ('Erick Avari',),
#  ('Erick Elias',),
#  ('Ericson Core',),
#  ('Erik Canuel',),
#  ('Erik Estrada',),
#  ('Erik Knudsen',),
#  ('Erik Palladino',),
#  ('Erik Per Sullivan',),
#  ('Erik White',),
#  ('Erika Christensen',),
#  ('Erin Bethea',),
#  ('Erin Boyes',),
#  ('Erin Cipolletti',),
#  ('Erin Daniels',),
#  ('Erin Fitzgerald',),
#  ('Erin Gray',),
#  ("Erin O'Brien",),
#  ('Erin Pitt',),
#  ('Erin Wasson',),
#  ('Erland Josephson',),
#  ('Ernest R. Dickerson',),
#  ('Ernie Barbarash',),
#  ('Ernie Reyes Jr.',),
#  ('Eros Vlahos',),
#  ('Errol Flynn',),
#  ('Errol Morris',),
#  ('Fran Drescher',),
#  ('Fran Kranz',),
#  ('Frances Bavier',),
#  ('Frances Bay',),
#  ('Frances Conroy',),
#  ('Frances Fisher',),
#  ('Frances Lee McCain',),
#  ("Frances O'Connor",),
#  ('Francesc PagÃ¨s',),
#  ('Francesca Capaldi',),
#  ('Francesca Gregorini',),
#  ('Francesca Rettondini',),
#  ('Francine Blake',),
#  ('Francis Capra',),
#  ('Francis Ford Coppola',),
#  ('Francis Lawrence',),
#  ('Francis Lederer',),
#  ('Franck Khalfoun',),
#  ('Franco Nero',),
#  ('Franco Zeffirelli',),
#  ('FranÃ§ois BÃ©gaudeau',),
#  ('FranÃ§ois BerlÃ©and',),
#  ('FranÃ§ois Chau',),
#  ('FranÃ§ois Cluzet',),
#  ('FranÃ§ois Damiens',),
#  ('FranÃ§ois Girard',),
#  ('FranÃ§ois Ozon',),
#  ('FranÃ§ois Truffaut',),
#  ('FranÃ§oise Yip',),
#  ('Frank Borzage',),
#  ('Frank Capra',),
#  ('Frank Coraci',),
#  ('Frank Darabont',),
#  ('Frank Dillane',),
#  ('Frank Faylen',),
#  ('Frank Finlay',),
#  ('Frank Gerrish',),
#  ('Frank Grillo',),
#  ('Frank Hvam',),
#  ('Frank LaLoggia',),
#  ('Frank Langella',),
#  ('Frank Lotito',),
#  ('Frank Marshall',),
#  ('Frank McHugh',),
#  ('Frank Miller',),
#  ('Frank Nissen',),
#  ('Frank Oz',),
#  ('Frank Perry',),
#  ('Frank Rautenbach',),
#  ('Frank Sebastiano',),
#  ('Frank Vincent',),
#  ('Frank Welker',),
#  ('Frank Whaley',),
#  ('Frankie Muniz',),
#  ('Frankie Valli',),
#  ('Franklin J. Schaffner',),
#  ('Franky G',),
#  ('Fred Armisen',),
#  ('Fred Dekker',),
#  ('Fred Durst',),
#  ('Fred Gwynne',),
#  ('Fred MacMurray',),
#  ('Fred Malatesta',),
#  ('Fred Melamed',),
#  ('Fred Rogers',),
#  ('Fred Savage',),
#  ('Fred Schepisi',),
#  ('Fred Tatasciore',),
#  ('Fred Walton',),
#  ('Fred Ward',),
#  ('Fred Willard',),
#  ('Fred Williamson',),
#  ('Fred Wolf',),
#  ('Fred Zinnemann',),
#  ('Freddie Jones',),
#  ('Freddy RodrÃ\xadguez',),
#  ('FrÃ©dÃ©ric Auburtin',),
#  ('FrÃ©dÃ©ric Forestier',),
#  ('Frederic Forrest',),
#  ('Frederick Weller',),
#  ('Frederik Du Chau',),
#  ('Fredro Starr',),
#  ('French Stewart',),
#  ('Frida Hallgren',),
#  ('Fritz Kortner',),
#  ('Fritz Lang',),
#  ('Grace Gummer',),
#  ('Grace Jones',),
#  ('Grace Phipps',),
#  ('Graham Annable',),
#  ('Graham Beckel',),
#  ('Graham McTavish',),
#  ('Grant Bowler',),
#  ('Grant Heslov',),
#  ('Grasie Mercedes',),
#  ('Graziella Galvani',),
#  ('Greer Garson',),
#  ('Greg Aronowitz',),
#  ('Greg Ayres',),
#  ('Greg Berlanti',),
#  ('Greg Collins',),
#  ('Greg Coolidge',),
#  ('Greg Crowe',),
#  ("Greg D'Agostino",),
#  ('Greg Germann',),
#  ('Greg Grunberg',),
#  ('Greg Harrison',),
#  ('Greg Jackson',),
#  ('Greg Marcks',),
#  ('Greg Mottola',),
#  ('Greg Nicotero',),
#  ('Greg Speirs',),
#  ('Greg Tiernan',),
#  ('Gregg Henry',),
#  ('Gregor Jordan',),
#  ('Gregory Alan Williams',),
#  ('Gregory Cruz',),
#  ('Gregory Hoblit',),
#  ('Gregory Itzin',),
#  ('Gregory Jacobs',),
#  ('Gregory Nava',),
#  ('Gregory Poirier',),
#  ('Gregory Scott Cummins',),
#  ('Gregory Sierra',),
#  ('Gregory Smith',),
#  ('Gregory Widen',),
#  ('Greta Gerwig',),
#  ('Gretchen Mol',),
#  ('Gretchen Palmer',),
#  ('Grey Damon',),
#  ('Grey Griffin',),
#  ('Griffin Cleveland',),
#  ('Griffin Dunne',),
#  ('Griffin Kane',),
#  ('Grigoriy Dobrygin',),
#  ('Hristo Shopov',),
#  ('Ira Sachs',),
#  ('Irene Bedard',),
#  ('Irene Dunne',),
#  ('IrÃ¨ne Jacob',),
#  ('Irene Papas',),
#  ('Irvin Kershner',),
#  ('Irwin Winkler',),
#  ('JR Bourne',),
#  ('Kris Isacsson',),
#  ('Kris Marshall',),
#  ('Kris Sommerville',),
#  ('Krista Allen',),
#  ('Kristen Cloke',),
#  ('Kristen Connolly',),
#  ('Kristen Johnston',),
#  ('Kristen Quintrall',),
#  ('Kristen Seavey',),
#  ('Kristen Stewart',),
#  ('Kristi Clainos',),
#  ('Kristian Bruun',),
#  ('Kristin Booth',),
#  ('Kristin Davis',),
#  ('Kristin Lehman',),
#  ('Kristin Rizzo',),
#  ('Kristin Scott Thomas',),
#  ('Kristoffer Polaha',),
#  ('Kristy Swanson',),
#  ('Kriv Stenders',),
#  ('Krysta Rodriguez',),
#  ('Oren Moverman',),
#  ('Oren Peli',),
#  ('Orla Fitzgerald',),
#  ('Orlando Bloom',),
#  ('Ornella Muti',),
#  ('Orson Bean',),
#  ('Orson Welles',),
#  ('Prabhas',),
#  ('Prabhudheva',),
#  ('Prachya Pinkaew',),
#  ('Prateik',),
#  ('Preity Zinta',),
#  ('Preston A. Whitmore II',),
#  ('Priscilla Presley',),
#  ('Pruitt Taylor Vince',),
#  ('Tracey Walter',),
#  ('Traci Dinwiddie',),
#  ('Traci Lords',),
#  ('Tracie Thoms',),
#  ('Tracy Camilla Johns',),
#  ('Tracy Letts',),
#  ('Tracy Middendorf',),
#  ('Tracy Morgan',),
#  ('Tran Anh Hung',),
#  ('Travis Aaron Wade',),
#  ('Travis Betz',),
#  ('Travis Cluff',),
#  ('Travis Legge',),
#  ('Travis Myers',),
#  ('Travis Romero',),
#  ('Travis Smith',),
#  ('Travis Zariwny',),
#  ('Traylor Howard',),
#  ('Treat Williams',),
#  ('Trent Cooper',),
#  ('Trent Ford',),
#  ('Trenton Rostedt',),
#  ('Trevor Blumas',),
#  ('Trevor Howard',),
#  ('Trevor Morgan',),
#  ('Trey Loney',),
#  ('Trey Parker',),
#  ('Trieu Tran',),
#  ('Trine Dyrholm',),
#  ('Trish Basinger',),
#  ('Tristan Mack Wilds',),
#  ('Troy Duffy',),
#  ('Troy Evans',),
#  ('Troy Garity',),
#  ('Troy Miller',),
#  ('Troy Nixey',),
#  ('Ursula Andress',),
#  ('Wray Crawford',)]

# %%
# Select names that don't start with A
cur.execute("""
            
            SELECT name 
            FROM people WHERE name NOT LIKE 'A%';
            
            """).fetchall()
# Out:
# [('50 Cent',),
#  ('Ã\x81lex Angulo',),
#  ('Ã\x81lex de la Iglesia',),
#  ('Ã\x81ngela Molina',),
#  ('B.J. Novak',),
#  ('Babak Najafi',),
#  ('Babar Ahmed',),
#  ('Bahare Seddiqi',),
#  ('Bai Ling',),
#  ('Bailee Madison',),
#  ('Balinese Tari Legong Dancers',),
#  ('BÃ¡lint PÃ©ntek',),
#  ('Baltasar KormÃ¡kur',),
#  ('Balthazar Getty',),
#  ('Bam Margera',),
#  ('Barack Obama',),
#  ('Barbara Bach',),
#  ('Barbara Billingsley',),
#  ('Barbara Carrera',),
#  ('BÃ¡rbara Goenaga',),
#  ('Barbara Hershey',),
#  ('Barbara Kowalcyk',),
#  ('BÃ¡rbara Mori',),
#  ('Barbet Schroeder',),
#  ('Barbie Castro',),
#  ('Barbra Streisand',),
#  ('Bari Hyman',),
#  ('Barnard Hughes',),
#  ('Barney Clark',),
#  ('Barney Frank',),
#  ('Barret Oliver',),
#  ('Barrett Esposito',),
#  ('Barry Bostwick',),
#  ('Barry Cook',),
#  ('Barry Corbin',),
#  ('Barry Dennen',),
#  ('Barry Fitzgerald',),
#  ('Barry Levinson',),
#  ('Barry Lynch',),
#  ('Barry Shabaka Henley',),
#  ('Barry Skolnick',),
#  ('Barry Sonnenfeld',),
#  ('Barry W. Blaustein',),
#  ('Barry Watson',),
#  ('Bart Freundlich',),
#  ('Bart Shatto',),
#  ('Bart the Bear',),
#  ('Bashar Rahal',),
#  ('Basher Savage',),
#  ('Basil Rathbone',),
#  ('Baz Luhrmann',),
#  ('BÃ©atrice Bonifassi',),
#  ('BÃ©atrice Dalle',),
#  ('Beatrice Ntuba',),
#  ('Beatrice Straight',),
#  ('Beau Bridges',),
#  ('Beau Garrett',),
#  ('Beau Knapp',),
#  ('Beau Mirchoff',),
#  ('Bebe Neuwirth',),
#  ('Becky Smith',),
#  ('Beeban Kidron',),
#  ('Behrouz Vossoughi',),
#  ('BelÃ©n Rueda',),
#  ('Bella Heathcote',),
#  ('Bella Thorne',),
#  ('Ben Affleck',),
#  ('Ben Browder',),
#  ('Ben Chaplin',),
#  ('Ben Crompton',),
#  ('Ben Cross',),
#  ('Ben Daniels',),
#  ('Ben Davies',),
#  ('Ben Diskin',),
#  ('Ben Falcone',),
#  ('Ben Feldman',),
#  ('Ben Gazzara',),
#  ('Ben Johnson',),
#  ('Ben Lewin',),
#  ('Ben Mendelsohn',),
#  ('Ben Miles',),
#  ('Ben Miller',),
#  ('Ben Platt',),
#  ('Ben Schwartz',),
#  ('Ben Stassen',),
#  ('Ben Stein',),
#  ('Ben Stiller',),
#  ('Ben Vereen',),
#  ('Ben Wheatley',),
#  ('Ben Youcef',),
#  ('Ben Younger',),
#  ('Benedek Fliegauf',),
#  ('Benedict Cumberbatch',),
#  ('Benedict Wong',),
#  ('Benedikt Erlingsson',),
#  ('Benh Zeitlin',),
#  ('Benjamin A. Onyango',),
#  ('Benjamin Dickinson',),
#  ('Benjamin Fletcher',),
#  ('Benjamin J. Cain Jr.',),
#  ('Benjamin Roberds',),
#  ('Benjamin Walker',),
#  ('Bennett Miller',),
#  ('Benni Diez',),
#  ('Benno FÃ¼rmann',),
#  ('Benny Boom',),
#  ('BenoÃ®t Magimel',),
#  ('BenoÃ®t Poelvoorde',),
#  ('Benson Lee',),
#  ('BÃ©rÃ©nice Bejo',),
#  ('BergÃ¼zar Korel',),
#  ('Bern Cohen',),
#  ('Bernadette Peters',),
#  ('Bernard Cribbins',),
#  ('Bernard Fox',),
#  ('Bernard Hill',),
#  ('Bernardo Bertolucci',),
#  ('Bernardo Saracino',),
#  ('Bernie Casey',),
#  ('Bernie Mac',),
#  ('Bernie Sanders',),
#  ('Bertrand Cantat',),
#  ('Bess Armstrong',),
#  ('Bessie Love',),
#  ('Beth Broderick',),
#  ('Beth Grant',),
#  ('Beth Riesgraf',),
#  ('Bethany Blakey',),
#  ('Bethany Joy Lenz',),
#  ('Beto GÃ³mez',),
#  ('Betsy Baker',),
#  ('Betsy Palmer',),
#  ('Betsy Russell',),
#  ('Betty Hutton',),
#  ('Betty Thomas',),
#  ("Beverly D'Angelo",),
#  ('Beverly Randolph',),
#  ('Bhama',),
#  ('Bhavkhandan Singh Rakhra',),
#  ('Bhole Baba',),
#  ('Bhoomika Chawla',),
#  ('Bianca Brigitte VanDamme',),
#  ('Bianca Collins',),
#  ('Bianca Kajlich',),
#  ('Bibo Bergeron',),
#  ('Big Budah',),
#  ('Bigas Luna',),
#  ('Bill Allen',),
#  ('Bill Bailey',),
#  ('Bill Baird',),
#  ('Bill Benenson',),
#  ('Bill Clinton',),
#  ('Bill Cobbs',),
#  ('Bill Condon',),
#  ('Bill Duke',),
#  ('Bill Erwin',),
#  ('Bill Fagerbakke',),
#  ('Bill Farmer',),
#  ('Bill Hickman',),
#  ('Bill Hunter',),
#  ('Bill Irwin',),
#  ('Bill Johnson',),
#  ('Bill Lake',),
#  ('Bill Maher',),
#  ('Bill Martone',),
#  ('Bill Melendez',),
#  ('Bill Muir',),
#  ('Bill Murray',),
#  ('Bill Nunn',),
#  ('Bill Paterson',),
#  ('Bill Paxton',),
#  ('Bill Plympton',),
#  ('Bille August',),
#  ('Bille Woodruff',),
#  ('Billie Burke',),
#  ('Billie Whitelaw',),
#  ('Billy Aaron Brown',),
#  ('Billy Barty',),
#  ('Billy Blair',),
#  ('Billy Bob Thornton',),
#  ('Billy Boyd',),
#  ('Billy Brown',),
#  ('Billy Burke',),
#  ('Billy Campbell',),
#  ('Billy Crudup',),
#  ('Billy Drago',),
#  ('Billy Gardell',),
#  ('Billy Gilbert',),
#  ('Billy Kent',),
#  ('Billy Ray',),
#  ('Billy West',),
#  ('Billy Wilder',),
#  ('Bin Won',),
#  ('Bingbing Fan',),
#  ('Bingbing Li',),
#  ('Bipasha Basu',),
#  ('Birgitte Hjort SÃ¸rensen',),
#  ('Birol Ãœnel',),
#  ('BjÃ¶rk',),
#  ('BjÃ¶rn Hlynur Haraldsson',),
#  ('BjÃ¸rn Sundquist',),
#  ('Black Thomas',),
#  ('Blaine Anderson',),
#  ('Blair Brown',),
#  ('Blair Erickson',),
#  ('Blair Hayes',),
#  ('Blair Underwood',),
#  ('Blake Edwards',),
#  ('Blake Lindsley',),
#  ('Blake Ritson',),
#  ('Blanchard Ryan',),
#  ('Blaz Zavrsnik',),
#  ('Blythe Auffarth',),
#  ('Blythe Danner',),
#  ('Bo Huang',),
#  ('Bo Welch',),
#  ('Bo Zenga',),
#  ('Boaz Yakin',),
#  ('Bob Balaban',),
#  ('Bob Clark',),
#  ('Bob Clendenin',),
#  ('Bob Costas',),
#  ('Bob Dole',),
#  ('Bob Dolman',),
#  ('Bob Dylan',),
#  ('Bob Eubanks',),
#  ('Bob Fosse',),
#  ('Bob Giraldi',),
#  ('Bob Gosse',),
#  ('Bob Gunton',),
#  ('Bob Hoskins',),
#  ('Bob Marley',),
#  ('Bob Neill',),
#  ('Bob Newhart',),
#  ('Bob Odenkirk',),
#  ('Bob Peck',),
#  ('Bob Proctor',),
#  ('Bob Rafelson',),
#  ('Bob Ross',),
#  ('Bob Saget',),
#  ('Bob Spiers',),
#  ("Bobb'e J. Thompson",),
#  ('Bobbie Phillips',),
#  ('Bobby Batson',),
#  ('Bobby Block',),
#  ('Bobby Brown',),
#  ('Bobby Coleman',),
#  ('Bobby Deol',),
#  ('Bobby Farrelly',),
#  ('Bobby Kendall',),
#  ('Bobby Lee',),
#  ('Bobby Moynihan',),
#  ('Bobby Roth',),
#  ('Bobcat Goldthwait',),
#  ('Bojana Novakovic',),
#  ('Bokeem Woodbine',),
#  ('Bolaji Badejo',),
#  ('Bolo Yeung',),
#  ('Boman Irani',),
#  ('Bonnie Henna',),
#  ('Bonnie Hunt',),
#  ('Bonnie Lee Bouman',),
#  ('Bonnie Somerville',),
#  ('Bono',),
#  ('Bonz Malone',),
#  ('Boris Kodjoe',),
#  ('Boris Rodriguez',),
#  ('Boyd Banks',),
#  ('Boyd Holbrook',),
#  ('Boys II Men',),
#  ('Brad Anderson',),
#  ('Brad Bird',),
#  ('Brad Copeland',),
#  ('Brad Furman',),
#  ('Brad Garrett',),
#  ('Brad J. Silverman',),
#  ('Brad James',),
#  ('Brad Lee Wind',),
#  ('Brad Leland',),
#  ('Brad Peyton',),
#  ('Brad Pitt',),
#  ('Brad Renfro',),
#  ('Brad Schmidt',),
#  ('Brad Silberling',),
#  ('Brad William Henke',),
#  ('Bradley Cooper',),
#  ('Bradley Parker',),
#  ('Bradley Pierce',),
#  ('Bradley Rust Gray',),
#  ('Bradley Whitford',),
#  ('Brady Corbet',),
#  ('Braeden Lemasters',),
#  ('Brahim Achabbakhe',),
#  ('Brahmanandam',),
#  ('Brandon Camp',),
#  ('Brandon Cronenberg',),
#  ('Brandon Landers',),
#  ('Brandon Middleton',),
#  ('Brandon Molale',),
#  ('Brandon Smith',),
#  ('Brandon T. Jackson',),
#  ('Brandon Trost',),
#  ('Brandy Norwood',),
#  ('Branko Djuric',),
#  ('Breck Eisner',),
#  ('Bree Turner',),
#  ('Bree Williamson',),
#  ('Brenda Bakke',),
#  ('Brenda Blethyn',),
#  ('Brenda Chapman',),
#  ('Brenda Fricker',),
#  ('Brenda Song',),
#  ('Brenda Strong',),
#  ('Brenda Vaccaro',),
#  ('Brendan Coyle',),
#  ('Brendan Doogie Milewski',),
#  ('Brendan Fehr',),
#  ('Brendan Fraser',),
#  ('Brendan Mackey',),
#  ('Brendan Malloy',),
#  ('Brendan Sexton III',),
#  ('Brendon Eggertsen',),
#  ('Brent Anderson',),
#  ('Brent David Fraser',),
#  ('Brent Neale',),
#  ('Brent Sexton',),
#  ('Brenton Spencer',),
#  ('Brett Cullen',),
#  ('Brett Leonard',),
#  ('Brett Piper',),
#  ('Brett Ratner',),
#  ('Brett Wagner',),
#  ('Brian A Miller',),
#  ('Brian Anthony Wilson',),
#  ('Brian Austin Green',),
#  ('Brian Baugh',),
#  ('Brian Blessed',),
#  ('Brian Bosworth',),
#  ('Brian Caunter',),
#  ("Brian d'Arcy James",),
#  ('Brian Dannelly',),
#  ('Brian De Palma',),
#  ('Brian Dennehy',),
#  ('Brian Dietzen',),
#  ('Brian Dorton',),
#  ('Brian Doyle-Murray',),
#  ('Brian Eno',),
#  ("BrÃ\xadan F. O'Byrne",),
#  ('Brian Geraghty',),
#  ('Brian Gibson',),
#  ('Brian Helgeland',),
#  ('Brian Henson',),
#  ('Brian Herzlinger',),
#  ('Brian Howe',),
#  ('Brian Johnson',),
#  ('Brian Keith',),
#  ('Brian Klugman',),
#  ('Brian Koppelman',),
#  ('Brian Lee Franklin',),
#  ('Brian Levant',),
#  ('Brian McNamara',),
#  ("Brian O'Halloran",),
#  ('Brian Percival',),
#  ('Brian Robbins',),
#  ('Brian Steele',),
#  ('Brian Stepanek',),
#  ('Brian Thompson',),
#  ('Brian Trenchard-Smith',),
#  ('Brian Van Holt',),
#  ('Brian Whitaker',),
#  ('Brian Yuzna',),
#  ('Brianna Brown',),
#  ('Brianne Brozey',),
#  ('Bridget Fonda',),
#  ('Bridgette Wilson-Sampras',),
#  ('Bridgit Mendler',),
#  ('Brighton Sharbino',),
#  ('Brigitte Bardot',),
#  ('Brigitte Helm',),
#  ('Brigitte Nielsen',),
#  ('Brion James',),
#  ('Brit Morgan',),
#  ('Britney Spears',),
#  ('Britt Allcroft',),
#  ('Britt Ekland',),
#  ('Brittany Curran',),
#  ('Brittany Daniel',),
#  ('Brittney Powell',),
#  ('Brock Baker',),
#  ('Brock Peters',),
#  ('Bronagh Gallagher',),
#  ('Bronwen Hughes',),
#  ('Brooke Bundy',),
#  ('Brooke Newton',),
#  ('Brooke Shields',),
#  ('Brooke Smith',),
#  ('Brooklynn Proulx',),
#  ('Bruce Alexander',),
#  ('Bruce Altman',),
#  ('Bruce Beresford',),
#  ('Bruce Boxleitner',),
#  ('Bruce Campbell',),
#  ('Bruce Davison',),
#  ('Bruce Dellis',),
#  ('Bruce Dern',),
#  ('Bruce Gooch',),
#  ('Bruce Goodchild',),
#  ('Bruce Green',),
#  ('Bruce Greenwood',),
#  ('Bruce Hopkins',),
#  ('Bruce Hunt',),
#  ('Bruce Kerr',),
#  ('Bruce Macdonald',),
#  ('Bruce Malmuth',),
#  ('Bruce McCulloch',),
#  ('Bruce McDonald',),
#  ('Bruce McGill',),
#  ('Bruce Newbold',),
#  ('Bruce Paltrow',),
#  ('Bruce Payne',),
#  ('Bruce Spence',),
#  ('Bruce Thomas',),
#  ('Bruce Vilanch',),
#  ('Bruce Willis',),
#  ('Bruno Barreto',),
#  ('Bruno Campos',),
#  ('Bruno Ganz',),
#  ('Bruno Kirby',),
#  ('Bryan Barber',),
#  ('Bryan Brown',),
#  ('Bryan Callen',),
#  ('Bryan Dick',),
#  ('Bryan Singer',),
#  ('Bryce Dallas Howard',),
#  ('Bubba Smith',),
#  ('Bud Cort',),
#  ('Bunta Sugawara',),
#  ('Burgess Meredith',),
#  ('Burghart KlauÃŸner',),
#  ('Burl Ives',),
#  ('Burr Steers',),
#  ('Burt Kwouk',),
#  ('Burt Ward',),
#  ('Burt Young',),
#  ('Buster Keaton',),
#  ('Busy Philipps',),
#  ('Buzz Aldrin',),
#  ('Byron Howard',),
#  ('Byron Mann',),
#  ('C. Fraser Press',),
#  ('C. Jay Cox',),
#  ('Cabrina Collesides',),
#  ('Caitlin FitzGerald',),
#  ('Caitlin Stasey',),
#  ('Caitlyn Jenner',),
#  ('Caity Lotz',),
#  ('Cal Brunker',),
#  ('Caleb Landry Jones',),
#  ('Callie Khouri',),
#  ('Callie Thorne',),
#  ('Callum Blue',),
#  ('Callum Rennie',),
#  ('Calvin Lockhart',),
#  ('Cam Clarke',),
#  ('Cameron Boyce',),
#  ('Cameron Bright',),
#  ('Cameron Crowe',),
#  ('Cameron Mills',),
#  ('Cameron Monaghan',),
#  ('Cameron Rhodes',),
#  ('Camille Delamarre',),
#  ('Campbell Scott',),
#  ('Camren Bicondova',),
#  ('Camryn Manheim',),
#  ('Candace Kroslak',),
#  ('Candice Bergen',),
#  ('Cara Delevingne',),
#  ('Cara Horgan',),
#  ('Cara Seymour',),
#  ('Carel Struycken',),
#  ('Cariba Heine',),
#  ('Carl Franklin',),
#  ('Carl Gilliard',),
#  ('Carl Rinsch',),
#  ('Carl Theodor Dreyer',),
#  ('Carl Weathers',),
#  ('Carla Gallo',),
#  ('Carlease Burke',),
#  ('Carlo Cecchi',),
#  ('Carlos Alazraqui',),
#  ('Carlos Bardem',),
#  ('Carlos Carrera',),
#  ('Carlos Gallardo',),
#  ('Carlos Lasarte',),
#  ('Carlos Ponce',),
#  ('Carlos Saldanha',),
#  ('Carlos Saura',),
#  ('Carly Schroeder',),
#  ('Carmen Argenziano',),
#  ('Carmen Ejogo',),
#  ('Carmen Electra',),
#  ('Carmen Marron',),
#  ('Carmen Maura',),
#  ('Carmen Perez',),
#  ('Carmine Giovinazzo',),
#  ('Carol Ann Susi',),
#  ('Carol Block',),
#  ('Carol Channing',),
#  ('Carol Kane',),
#  ('Carol Reed',),
#  ('Carol Sutton',),
#  ('Carole Bouquet',),
#  ('Caroline Dhavernas',),
#  ('Caroline Goodall',),
#  ('Caroline Link',),
#  ('Caroline Munro',),
#  ('Caroll Spinney',),
#  ('Carolyn Hennesy',),
#  ('Carrie Bradstreet',),
#  ('Carrie Henn',),
#  ('Carrie Preston',),
#  ('Carroll Baker',),
#  ('Carroll Ballard',),
#  ("Carroll O'Connor",),
#  ('Carter Jenkins',),
#  ('Carter Smith',),
#  ('Cary Bell',),
#  ('Cary-Hiroyuki Tagawa',),
#  ('Caryn Waechter',),
#  ('Cas Anvar',),
#  ('Casey Affleck',),
#  ('Casey Gooden',),
#  ('Casey Kasem',),
#  ('Casey Siemaszko',),
#  ('Casper Christensen',),
#  ('Casper Crump',),
#  ('Casper Martinez',),
#  ('Cassandra Nicolaou',),
#  ('Cassandra Peterson',),
#  ('Cassidy Gifford',),
#  ('Cassie Ventura',),
#  ('Cat Ly',),
#  ('Catalina Sandino Moreno',),
#  ('Catherine Bell',),
#  ('Catherine Deneuve',),
#  ('Catherine Dent',),
#  ('Catherine Dyer',),
#  ('Catherine Gund',),
#  ('Catherine Hardwicke',),
#  ('Catherine Hicks',),
#  ('Catherine Jelski',),
#  ('Catherine Lambert',),
#  ('Catherine Lough Haggquist',),
#  ('Catherine McCormack',),
#  ("Catherine O'Hara",),
#  ('Catherine Owens',),
#  ('Catherine Parks',),
#  ('Catherine Schell',),
#  ('Catherine Tate',),
#  ('Cathryn de Prume',),
#  ('Cathy Malkasian',),
#  ('Cathy Moriarty',),
#  ('Catriona MacColl',),
#  ('CCH Pounder',),
#  ('Cecelia Antoinette',),
#  ('Cecil B. DeMille',),
#  ('Cecil Kellaway',),
#  ('CÃ©cile De France',),
#  ('Cecilia Pillado',),
#  ('CÃ©dric Klapisch',),
#  ('Cedric Nicolas-Troyan',),
#  ('Cedric the Entertainer',),
#  ('Celeste Holm',),
#  ('Celia Imrie',),
#  ('Celia Weston',),
#  ('Celina Beach',),
#  ('Celina Jade',),
#  ('Cem Yilmaz',),
#  ('Cesar Romero',),
#  ('Chad Allen',),
#  ('Chad Bishop',),
#  ('Chad Hartigan',),
#  ('Chad Kapper',),
#  ('Chad L. Coleman',),
#  ('Chad Lindberg',),
#  ('Chad Lowe',),
#  ('Chan-wook Park',),
#  ('Chandler Canterbury',),
#  ('Channing Tatum',),
#  ('Chao-Bin Su',),
#  ('Charice',),
#  ('Charis Michelsen',),
#  ('Charla Cochran',),
#  ('Charles Adelman',),
#  ('Charles Aidman',),
#  ('Charles Aznavour',),
#  ('Charles Baker',),
#  ('Charles BinamÃ©',),
#  ('Charles Chaplin',),
#  ('Charles Ferguson',),
#  ('Charles Grodin',),
#  ('Charles Herman-Wurmfeld',),
#  ('Charles Irving Beale',),
#  ('Charles Keating',),
#  ('Charles King',),
#  ('Charles Linton',),
#  ('Charles Martin Smith',),
#  ('Charles Martinet',),
#  ('Charles Matthau',),
#  ('Charles Mesure',),
#  ('Charles Napier',),
#  ('Charles Robert Carner',),
#  ('Charles S. Dutton',),
#  ('Charles Shyer',),
#  ('Charles Stone III',),
#  ('Charles T. Kanganis',),
#  ('Charlie Bewley',),
#  ('Charlie Hunnam',),
#  ('Charlie Kaufman',),
#  ('Charlie Korsmo',),
#  ('Charlie Levi',),
#  ('Charlie McDermott',),
#  ('Charlie Murphy',),
#  ('Charlie Rowe',),
#  ('Charlie Saxton',),
#  ('Charlie Tahan',),
#  ('Charlie Talbert',),
#  ('Charlie Yeung',),
#  ('Charlize Theron',),
#  ('Charlotte BÃ¸ving',),
#  ('Charlotte Le Bon',),
#  ('Charlotte Lewis',),
#  ('Charlotte Rae',),
#  ('Charlotte Rampling',),
#  ('Charlotte Stewart',),
#  ('Charlotte Sullivan',),
#  ('Charly Bivona',),
#  ('Charlyne Yi',),
#  ('Chase Armitage',),
#  ('Chase Ellison',),
#  ('Chase Masterson',),
#  ('Chasty Ballesteros',),
#  ('Chatchai Plengpanich',),
#  ('Chatrichalerm Yukol',),
#  ('Chazz Palminteri',),
#  ('Cheech Marin',),
#  ('Chelan Simmons',),
#  ('Chelcie Ross',),
#  ('Chelse Swain',),
#  ('Chelsea Bond',),
#  ('Chelsea Field',),
#  ('Chelsea Handler',),
#  ('Chelsey Reist',),
#  ('Chemeeka Walker',),
#  ('Chen Chang',),
#  ('Chenoa Maxwell',),
#  ('Cherami Leigh',),
#  ('Cheri Oteri',),
#  ('Cherry Jones',),
#  ('Cheryl Dunye',),
#  ('Cheryl Hines',),
#  ('Cheryl Ladd',),
#  ('Cheryl Penland',),
#  ('Cheryl Tiegs',),
#  ('Chester',),
#  ('Cheyenne Jackson',),
#  ('Chi Chung Lam',),
#  ('Chi Ling Chiu',),
#  ('Chi McBride',),
#  ('Chi Muoi Lo',),
#  ('Chia-Liang Liu',),
#  ('Chiaki Kuriyama',),
#  ('Chiara Caselli',),
#  ('Chin-Chien Chang',),
#  ('China Chow',),
#  ('Ching Wan Lau',),
#  ('Chita Rivera',),
#  ('Chloe Bridges',),
#  ('ChloÃ« Grace Moretz',),
#  ('Chloe Hollings',),
#  ('Chloe Rose',),
#  ("Chris 'Wonder' Schoeck",),
#  ('Chris Andrew Ciulla',),
#  ('Chris Atkins',),
#  ('Chris Barrie',),
#  ('Chris Bauer',),
#  ('Chris Brochu',),
#  ('Chris Brown',),
#  ('Chris Buck',),
#  ('Chris Butler',),
#  ('Chris Carter',),
#  ('Chris Cleveland',),
#  ('Chris Columbus',),
#  ('Chris Cox',),
#  ("Chris D'Arienzo",),
#  ('Chris Eigeman',),
#  ('Chris Elliott',),
#  ('Chris Ellis',),
#  ('Chris Evans',),
#  ('Chris Eyre',),
#  ('Chris Gauthier',),
#  ('Chris Geere',),
#  ('Chris Gorak',),
#  ('Chris Harrison',),
#  ('Chris Hemsworth',),
#  ('Chris Kattan',),
#  ('Chris Kentis',),
#  ('Chris Klein',),
#  ('Chris Koch',),
#  ('Chris Lowell',),
#  ('Chris Marker',),
#  ('Chris Marquette',),
#  ('Chris Miller',),
#  ('Chris Moss',),
#  ('Chris Mulkey',),
#  ('Chris Nahon',),
#  ('Chris New',),
#  ('Chris Noonan',),
#  ('Chris Noth',),
#  ('Chris Owen',),
#  ('Chris Paine',),
#  ('Chris Parnell',),
#  ('Chris Penn',),
#  ('Chris Pontius',),
#  ('Chris Roberts',),
#  ('Chris Robinson',),
#  ('Chris Rock',),
#  ('Chris Shadley',),
#  ('Chris Stokes',),
#  ('Chris Thomas',),
#  ('Chris Wedge',),
#  ('Chris Weitz',),
#  ('Chris Young',),
#  ('Chris Zylka',),
#  ('Chriss Anglin',),
#  ('Christa B. Allen',),
#  ('Christa Miller',),
#  ('Christel Khalil',),
#  ('Christian Alvarez',),
#  ('Christian Alvart',),
#  ('Christian Anderson',),
#  ('Christian Bale',),
#  ('Christian Berkel',),
#  ('Christian Camargo',),
#  ('Christian Campbell',),
#  ('Christian Carion',),
#  ('Christian Clavier',),
#  ('Christian Clemenson',),
#  ('Christian Ditter',),
#  ('Christian Duguay',),
#  ('Christian E. Christiansen',),
#  ('Christian Kapper',),
#  ('Christian Keyes',),
#  ('Christian Monzon',),
#  ('Christian Sesma',),
#  ('Christian Stolte',),
#  ('Christian Volckman',),
#  ('Christiana Leucas',),
#  ('Christie Burke',),
#  ('Christina Chambers',),
#  ('Christina Cox',),
#  ('Christina Hart',),
#  ('Christina Milian',),
#  ('Christina Moore',),
#  ('Christina Vidal',),
#  ('Christine Cavanaugh',),
#  ('Christine Jeffs',),
#  ('Christine Lakin',),
#  ('Christine Taylor',),
#  ('Christo Jivkov',),
#  ('Christoph Waltz',),
#  ('Christophe Ali',),
#  ('Christophe Barratier',),
#  ('Christophe Cherki',),
#  ('Christophe Gans',),
#  ('Christopher Abbott',),
#  ('Christopher Atkins',),
#  ('Christopher B. Duncan',),
#  ('Christopher Barnard',),
#  ('Christopher Berry',),
#  ('Christopher Cain',),
#  ('Christopher Cousins',),
#  ('Christopher Denham',),
#  ('Christopher Erskin',),
#  ('Christopher Evan Welch',),
#  ('Christopher Guest',),
#  ('Christopher Heyerdahl',),
#  ('Christopher Hutson',),
#  ('Christopher James Baker',),
#  ('Christopher Judge',),
#  ('Christopher Lambert',),
#  ('Christopher Landon',),
#  ('Christopher Lee',),
#  ('Christopher Leitch',),
#  ('Christopher M. Bessette',),
#  ('Christopher Masterson',),
#  ('Christopher McQuarrie',),
#  ('Christopher Meloni',),
#  ('Christopher Morris',),
#  ('Christopher Nicholas Smith',),
#  ('Christopher Nolan',),
#  ('Christopher Rich',),
#  ('Christopher Robin Miller',),
#  ('Christopher Schmidt',),
#  ('Christopher Scott Cherot',),
#  ('Christopher Simpson',),
#  ('Christopher Smith',),
#  ('Christopher Sommers',),
#  ('Christopher Spencer',),
#  ('Christopher Toler',),
#  ('Christopher Webster',),
#  ('Chrystale Wilson',),
#  ('Chrystee Pharris',),
#  ('Chuan Lu',),
#  ('Chuck Bowman',),
#  ('Chuck Mitchell',),
#  ('Chuck Russell',),
#  ('Chuck Sheetz',),
#  ('Chuck Zito',),
#  ('Chulpan Khamatova',),
#  ('CiarÃ¡n Foy',),
#  ('Cicely Tyson',),
#  ('Cinda McCain',),
#  ('Cindy Robinson',),
#  ('Cindy Williams',),
#  ('CindyMarie Small',),
#  ('Circus-Szalewski',),
#  ('CJ Adams',),
#  ('Cjon Saulsberry',),
#  ('Claire Adams',),
#  ('Claire Bloom',),
#  ('Claire Foy',),
#  ('Claire Geare',),
#  ('Claire Gordon-Harper',),
#  ('Clare Higgins',),
#  ('Clare Kilner',),
#  ('Clare Kramer',),
#  ('Clarence Williams III',),
#  ('Clark Baker',),
#  ('Clark Gregg',),
#  ('Clark Johnson',),
#  ('Clarke Peters',),
#  ('Claude Akins',),
#  ('Claude Chabrol',),
#  ('Claude Miller',),
#  ('Claude Rains',),
#  ('Claude-Oliver Rudolph',),
#  ('Claudette Colbert',),
#  ('Claudette LalÃ\xad',),
#  ('Claudia Cardinale',),
#  ('Claudia Christian',),
#  ('Claudia Ferri',),
#  ('Claudia LapacÃ³',),
#  ('Claudia Llosa',),
#  ('Claudia Sainte-Luce',),
#  ('Claudia Stedelin',),
#  ('Claudiu Trandafir',),
#  ('Clay Kaytis',),
#  ('Clayne Crawford',),
#  ('Clayton Rohner',),
#  ('Clayton Snyder',),
#  ('ClÃ© Bennett',),
#  ('Clea DuVall',),
#  ('Cleavon Little',),
#  ('Clemens Schick',),
#  ('Cliff Edwards',),
#  ('Cliff Robertson',),
#  ('Clifton Collins Jr.',),
#  ('Clifton James',),
#  ('Clifton Powell',),
#  ('Clint Eastwood',),
#  ('Clint Howard',),
#  ('Clint Jordan',),
#  ('Clint Jung',),
#  ('Clint Mansell',),
#  ('Clive Barker',),
#  ('Clive Revill',),
#  ('Clive Russell',),
#  ('Clive Standen',),
#  ('Clive Swift',),
#  ('Clotilde Mollet',),
#  ('Clovis Fouin',),
#  ('Clu Gulager',),
#  ('Clyde Kusatsu',),
#  ('Cody Cameron',),
#  ('Cody Howard',),
#  ('Cody Linley',),
#  ('Cole Hauser',),
#  ('Colette Divine',),
#  ('Colin Andrews',),
#  ('Colin Farrell',),
#  ('Colin Ferguson',),
#  ('Colin Firth',),
#  ('Colin Higgins',),
#  ('Colin Minihan',),
#  ("Colin O'Donoghue",),
#  ('Colin Salmon',),
#  ('Colin Stinton',),
#  ('Colin Strause',),
#  ('Colin Trevorrow',),
#  ('Colleen Dewhurst',),
#  ('Colleen Haskell',),
#  ("Colleen O'Shaughnessey",),
#  ('Collette Wolfe',),
#  ('Collin Alfredo St. Dic',),
#  ('Collin Chou',),
#  ('Collin Joseph Neal',),
#  ('Collin Kahey',),
#  ('Collin Schiffli',),
#  ('Collins Pennie',),
#  ('Colm Feore',),
#  ('Common',),
#  ('Conchata Ferrell',),
#  ('Conleth Hill',),
#  ('Connie Nielsen',),
#  ('Connie Ray',),
#  ('Connor Corum',),
#  ('Connor Paolo',),
#  ('Conor McMahon',),
#  ('Conor McPherson',),
#  ('Conrad Coates',),
#  ('Conrad Dunn',),
#  ('Conrad Goode',),
#  ('Conrad Kemp',),
#  ('Conrad Veidt',),
#  ('Conrad Vernon',),
#  ('Constance Marie',),
#  ('Constance Shulman',),
#  ('Constance Wu',),
#  ('Consuelo GÃ³mez',),
#  ('Corbin Allred',),
#  ('Corbin Bernsen',),
#  ('Corbin Bleu',),
#  ('Corey Grant',),
#  ('Corey Johnson',),
#  ('Corey Sevier',),
#  ('Corey Yuen',),
#  ('Corinna Harney',),
#  ('Corlandos Scott',),
#  ('Cornel Wilde',),
#  ('Cory Edwards',),
#  ('Cory Hardrict',),
#  ('Costa-Gavras',),
#  ('Costas Mandylor',),
#  ('Countess Vaughn',),
#  ('Courtney B. Vance',),
#  ('Courtney Bell',),
#  ('Courtney Gains',),
#  ('Courtney Hunt',),
#  ('Courtney Love',),
#  ('Courtney Solomon',),
#  ('Coyote Shivers',),
#  ('Craig Bierko',),
#  ('Craig Bolotin',),
#  ('Craig Brewer',),
#  ('Craig Conway',),
#  ('Craig Dougherty',),
#  ('Craig Fairbrass',),
#  ('Craig Ferguson',),
#  ('Craig Gillespie',),
#  ('Craig Hall',),
#  ('Craig Johnson',),
#  ('Craig Mazin',),
#  ('Craig Moss',),
#  ('Craig Parker',),
#  ('Craig R. Baxley',),
#  ('Craig Roberts',),
#  ('Craig Sheffer',),
#  ('Craig Stark',),
#  ('Craig T. Nelson',),
#  ('Craig Zobel',),
#  ('Cree Kelly',),
#  ('Cree Summer',),
#  ('CristiÃ¡n de la Fuente',),
#  ('Cristian Mungiu',),
#  ('Crystal Lowe',),
#  ('Crystal R. Fox',),
#  ('Cullen Douglas',),
#  ('Currie Graham',),
#  ('Curt Doussett',),
#  ('Curtis Armstrong',),
#  ('Curtis Hanson',),
#  ('Curtiss Cook',),
#  ('Cybill Shepherd',),
#  ('Cyd Charisse',),
#  ('Cyndi Lauper',),
#  ('Cynthia Barrett',),
#  ('Cynthia Geary',),
#  ('Cynthia Myers',),
#  ('Cynthia Nixon',),
#  ('Cynthia Rhodes',),
#  ('Cynthia Stevenson',),
#  ('Cynthia Watros',),
#  ('Cyril Raffaelli',),
#  ('Cyrus Nowrasteh',),
#  ('D. David Morin',),
#  ('D. Stevens',),
#  ('D.B. Sweeney',),
#  ('D.B. Woodside',),
#  ('D.J. Caruso',),
#  ...]

# %% [markdown]
# ## 0.2.10 WHERE IN

# %%
# -- Find the title and release_year for all films over two hours in length released in 1990 and 2000
cur.execute("""
            
            SELECT title, release_year 
            FROM films 
            WHERE release_year IN (1990, 2000) AND duration > 120;
            
            """).fetchall()
# Out:
# [('Dances with Wolves', 1990),
#  ('Die Hard 2', 1990),
#  ('Ghost', 1990),
#  ('Goodfellas', 1990),
#  ("Mo' Better Blues", 1990),
#  ('Pretty Woman', 1990),
#  ('The Godfather: Part III', 1990),
#  ('The Hunt for Red October', 1990),
#  ('All the Pretty Horses', 2000),
#  ('Almost Famous', 2000),
#  ('Bamboozled', 2000),
#  ('Cast Away', 2000),
#  ('Chocolat', 2000),
#  ('Dancer in the Dark', 2000),
#  ('Erin Brockovich', 2000),
#  ('Finding Forrester', 2000),
#  ('Fiza', 2000),
#  ('Gladiator', 2000),
#  ('Gone in Sixty Seconds', 2000),
#  ('Keeping the Faith', 2000),
#  ('Love & Basketball', 2000),
#  ('Men of Honor', 2000),
#  ('Mission: Impossible II', 2000),
#  ('Pandaemonium', 2000),
#  ('Pay It Forward', 2000),
#  ('Pollock', 2000),
#  ('Proof of Life', 2000),
#  ('Quills', 2000),
#  ('Reindeer Games', 2000),
#  ('Space Cowboys', 2000),
#  ('The 6th Day', 2000),
#  ('The Contender', 2000),
#  ('The Family Man', 2000),
#  ('The House of Mirth', 2000),
#  ('The Legend of Bagger Vance', 2000),
#  ('The Patriot', 2000),
#  ('The Perfect Storm', 2000),
#  ('Thirteen Days', 2000),
#  ('Traffic', 2000),
#  ('Vertical Limit', 2000),
#  ('What Lies Beneath', 2000),
#  ('What Women Want', 2000)]

# %%
# -- Find the title and language of all films in English, Spanish, and French
cur.execute("""
            
            SELECT title, language 
            FROM films 
            WHERE language IN ('English', 'Spanish', 'French');
            
            """).fetchall()
# Out:
# [('The Broadway Melody', 'English'),
#  ("Hell's Angels", 'English'),
#  ('A Farewell to Arms', 'English'),
#  ('42nd Street', 'English'),
#  ('She Done Him Wrong', 'English'),
#  ('It Happened One Night', 'English'),
#  ('Top Hat', 'English'),
#  ('Modern Times', 'English'),
#  ('The Charge of the Light Brigade', 'English'),
#  ('Snow White and the Seven Dwarfs', 'English'),
#  ('The Prisoner of Zenda', 'English'),
#  ("Alexander's Ragtime Band", 'English'),
#  ("You Can't Take It with You", 'English'),
#  ('Gone with the Wind', 'English'),
#  ('Mr. Smith Goes to Washington', 'English'),
#  ('The Wizard of Oz', 'English'),
#  ('Boom Town', 'English'),
#  ('Fantasia', 'English'),
#  ('Pinocchio', 'English'),
#  ('Rebecca', 'English'),
#  ('The Blue Bird', 'English'),
#  ('How Green Was My Valley', 'English'),
#  ('Bambi', 'English'),
#  ('Casablanca', 'English'),
#  ('A Guy Named Joe', 'English'),
#  ('Bathing Beauty', 'English'),
#  ('Spellbound', 'English'),
#  ('State Fair', 'English'),
#  ('The Lost Weekend', 'English'),
#  ('The Valley of Decision', 'English'),
#  ('Duel in the Sun', 'English'),
#  ("It's a Wonderful Life", 'English'),
#  ('The Best Years of Our Lives', 'English'),
#  ("Gentleman's Agreement", 'English'),
#  ('The Lady from Shanghai', 'English'),
#  ('Tycoon', 'English'),
#  ('Open Secret', 'English'),
#  ('Red River', 'English'),
#  ('The Pirate', 'English'),
#  ('Sands of Iwo Jima', 'English'),
#  ('She Wore a Yellow Ribbon', 'English'),
#  ('Annie Get Your Gun', 'English'),
#  ('A Streetcar Named Desire', 'English'),
#  ('Quo Vadis', 'English'),
#  ('Show Boat', 'English'),
#  ('Deadline - U.S.A.', 'English'),
#  ('High Noon', 'English'),
#  ("Singin' in the Rain", 'English'),
#  ('The Greatest Show on Earth', 'English'),
#  ('From Here to Eternity', 'English'),
#  ('Niagara', 'English'),
#  ('The Beast from 20,000 Fathoms', 'English'),
#  ('The Robe', 'English'),
#  ('20,000 Leagues Under the Sea', 'English'),
#  ('20,000 Leagues Under the Sea', 'English'),
#  ('On the Waterfront', 'English'),
#  ('The Egyptian', 'English'),
#  ('The Trouble with Harry', 'English'),
#  ('Love Me Tender', 'English'),
#  ('Moby Dick', 'English'),
#  ('Trapeze', 'English'),
#  ('12 Angry Men', 'English'),
#  ('The Bridge on the River Kwai', 'English'),
#  ('Cat on a Hot Tin Roof', 'English'),
#  ('Solomon and Sheba', 'English'),
#  ('Some Like It Hot', 'English'),
#  ("The Nun's Story", 'English'),
#  ('Elmer Gantry', 'English'),
#  ('Psycho', 'English'),
#  ('The Apartment', 'English'),
#  ('Judgment at Nuremberg', 'English'),
#  ('Pocketful of Miracles', 'English'),
#  ('The Hustler', 'English'),
#  ('The Misfits', 'English'),
#  ('West Side Story', 'English'),
#  ('Dr. No', 'English'),
#  ('Lawrence of Arabia', 'English'),
#  ('Lolita', 'English'),
#  ('Lolita', 'English'),
#  ("The Brain That Wouldn't Die", 'English'),
#  ('The Longest Day', 'English'),
#  ('The Man Who Shot Liberty Valance', 'English'),
#  ('To Kill a Mockingbird', 'English'),
#  ('55 Days at Peking', 'English'),
#  ('Cleopatra', 'English'),
#  ("Donovan's Reef", 'English'),
#  ('From Russia with Love', 'English'),
#  ('Hud', 'English'),
#  ("It's a Mad, Mad, Mad, Mad World", 'English'),
#  ('The Great Escape', 'English'),
#  ('Tom Jones', 'English'),
#  ("A Hard Day's Night", 'English'),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   'English'),
#  ('Goldfinger', 'English'),
#  ('Mary Poppins', 'English'),
#  ('My Fair Lady', 'English'),
#  ('Nothing But a Man', 'English'),
#  ('The Fall of the Roman Empire', 'English'),
#  ('The Train', 'English'),
#  ('Une Femme MariÃ©e', 'French'),
#  ('Doctor Zhivago', 'English'),
#  ('Major Dundee', 'English'),
#  ('Pierrot le Fou', 'French'),
#  ('The Greatest Story Ever Told', 'English'),
#  ("The Party's Over", 'English'),
#  ('The Sound of Music', 'English'),
#  ('Thunderball', 'English'),
#  ('A Funny Thing Happened on the Way to the Forum', 'English'),
#  ('A Man for All Seasons', 'English'),
#  ('Batman: The Movie', 'English'),
#  ('Harper', 'English'),
#  ('Torn Curtain', 'English'),
#  ('In Cold Blood', 'English'),
#  ('Point Blank', 'English'),
#  ('You Only Live Twice', 'English'),
#  ('2001: A Space Odyssey', 'English'),
#  ('Barbarella', 'English'),
#  ('Charly', 'English'),
#  ("Hang 'Em High", 'English'),
#  ('Night of the Living Dead', 'English'),
#  ('Night of the Living Dead', 'English'),
#  ('Oliver!', 'English'),
#  ('Once Upon a Time in the West', 'English'),
#  ("Rosemary's Baby", 'English'),
#  ('Shalako', 'English'),
#  ('Yours, Mine and Ours', 'English'),
#  ('Butch Cassidy and the Sundance Kid', 'English'),
#  ('Machine Gun McCain', 'English'),
#  ('Midnight Cowboy', 'English'),
#  ('Mississippi Mermaid', 'French'),
#  ("On Her Majesty's Secret Service", 'English'),
#  ('Paint Your Wagon', 'English'),
#  ('Sweet Charity', 'English'),
#  ('The Stewardesses', 'English'),
#  ('The Wild Bunch', 'English'),
#  ('Topaz', 'English'),
#  ('Beneath the Planet of the Apes', 'English'),
#  ('Beyond the Valley of the Dolls', 'English'),
#  ('Catch-22', 'English'),
#  ('Cotton Comes to Harlem', 'English'),
#  ('Darling Lili', 'English'),
#  ('Patton', 'English'),
#  ('The Ballad of Cable Hogue', 'English'),
#  ('The Molly Maguires', 'English'),
#  ('Tora! Tora! Tora!', 'English'),
#  ('Waterloo', 'English'),
#  ('Woodstock', 'English'),
#  ('Bananas', 'English'),
#  ('Diamonds Are Forever', 'English'),
#  ('Escape from the Planet of the Apes', 'English'),
#  ('Fiddler on the Roof', 'English'),
#  ('Pink Narcissus', 'English'),
#  ("Sweet Sweetback's Baadasssss Song", 'English'),
#  ('The Andromeda Strain', 'English'),
#  ('The French Connection', 'English'),
#  ('The French Connection', 'English'),
#  ('The Night Visitor', 'English'),
#  ('Willy Wonka & the Chocolate Factory', 'English'),
#  (1776, 'English'),
#  ('Conquest of the Planet of the Apes', 'English'),
#  ('Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#   'English'),
#  ('Frenzy', 'English'),
#  ('Pink Flamingos', 'English'),
#  ('Silent Running', 'English'),
#  ('The Godfather', 'English'),
#  ('American Graffiti', 'English'),
#  ('Battle for the Planet of the Apes', 'English'),
#  ('High Plains Drifter', 'English'),
#  ('Live and Let Die', 'English'),
#  ('Mean Streets', 'English'),
#  ('Pat Garrett & Billy the Kid', 'English'),
#  ('Sleeper', 'English'),
#  ('The Exorcist', 'English'),
#  ('The Sting', 'English'),
#  ('Benji', 'English'),
#  ('Blazing Saddles', 'English'),
#  ('The Conversation', 'English'),
#  ('The Front Page', 'English'),
#  ('The Godfather: Part II', 'English'),
#  ('The Man with the Golden Gun', 'English'),
#  ('The Texas Chain Saw Massacre', 'English'),
#  ('The Texas Chain Saw Massacre', 'English'),
#  ('Young Frankenstein', 'English'),
#  ('Barry Lyndon', 'English'),
#  ('Death Race 2000', 'English'),
#  ('Jaws', 'English'),
#  ('Monty Python and the Holy Grail', 'English'),
#  ("One Flew Over the Cuckoo's Nest", 'English'),
#  ('The Return of the Pink Panther', 'English'),
#  ('Family Plot', 'English'),
#  ("Logan's Run", 'English'),
#  ('Network', 'English'),
#  ('Robin and Marian', 'English'),
#  ('Rocky', 'English'),
#  ('Taxi Driver', 'English'),
#  ('The Bad News Bears', 'English'),
#  ('The Omen', 'English'),
#  ('The Omen', 'English'),
#  ('A Bridge Too Far', 'English'),
#  ('Annie Hall', 'English'),
#  ('Capricorn One', 'English'),
#  ('Close Encounters of the Third Kind', 'English'),
#  ('Damnation Alley', 'English'),
#  ('Eraserhead', 'English'),
#  ('Exorcist II: The Heretic', 'English'),
#  ('High Anxiety', 'English'),
#  ('Julia', 'English'),
#  ('Kingdom of the Spiders', 'English'),
#  ('March or Die', 'English'),
#  ('New York, New York', 'English'),
#  ('Sorcerer', 'English'),
#  ('Star Wars: Episode IV - A New Hope', 'English'),
#  ('The Kentucky Fried Movie', 'English'),
#  ('The Spy Who Loved Me', 'English'),
#  ('Alien Zone', 'English'),
#  ('Animal House', 'English'),
#  ('Caravans', 'English'),
#  ('Days of Heaven', 'English'),
#  ('F.I.S.T.', 'English'),
#  ('Force 10 from Navarone', 'English'),
#  ('Grease', 'English'),
#  ('Halloween', 'English'),
#  ('Halloween', 'English'),
#  ('Halloween', 'English'),
#  ('Jaws 2', 'English'),
#  ('Superman', 'English'),
#  ('The Boys from Brazil', 'English'),
#  ('The Deer Hunter', 'English'),
#  ('The Last Waltz', 'English'),
#  ('The Wiz', 'English'),
#  (1941, 'English'),
#  ('Alien', 'English'),
#  ('All That Jazz', 'English'),
#  ('Apocalypse Now', 'English'),
#  ('Escape from Alcatraz', 'English'),
#  ('Mad Max', 'English'),
#  ('Meteor', 'English'),
#  ('Moonraker', 'English'),
#  ('Penitentiary', 'English'),
#  ('Prophecy', 'English'),
#  ('Star Trek: The Motion Picture', 'English'),
#  ('The Black Hole', 'English'),
#  ('The Black Stallion', 'English'),
#  ('The Great Train Robbery', 'English'),
#  ('The Muppet Movie', 'English'),
#  ('The Rose', 'English'),
#  ('Airplane!', 'English'),
#  ('Caddyshack', 'English'),
#  ("Can't Stop the Music", 'English'),
#  ("Coal Miner's Daughter", 'English'),
#  ('Dressed to Kill', 'English'),
#  ('Flash Gordon', 'English'),
#  ('Galaxina', 'English'),
#  ("Heaven's Gate", 'English'),
#  ('Lion of the Desert', 'English'),
#  ('Ordinary People', 'English'),
#  ('Out of the Blue', 'English'),
#  ('Private Benjamin', 'English'),
#  ('Raging Bull', 'English'),
#  ('Raise the Titanic', 'English'),
#  ('Somewhere in Time', 'English'),
#  ('Star Wars: Episode V - The Empire Strikes Back', 'English'),
#  ('Superman II', 'English'),
#  ('The Blue Lagoon', 'English'),
#  ('The Blues Brothers', 'English'),
#  ('The Elephant Man', 'English'),
#  ('The Fog', 'English'),
#  ('The Fog', 'English'),
#  ('The Long Riders', 'English'),
#  ('The Shining', 'English'),
#  ('Blow Out', 'English'),
#  ('Chariots of Fire', 'English'),
#  ('Dragonslayer', 'English'),
#  ('Escape from New York', 'English'),
#  ('For Your Eyes Only', 'English'),
#  ('Friday the 13th Part 2', 'English'),
#  ('Graduation Day', 'English'),
#  ('Heartbeeps', 'English'),
#  ('Heavy Metal', 'English'),
#  ('History of the World: Part I', 'English'),
#  ('History of the World: Part I', 'English'),
#  ('Inchon', 'English'),
#  ('Mad Max 2: The Road Warrior', 'English'),
#  ('Modern Problems', 'English'),
#  ('Mommie Dearest', 'English'),
#  ('Nighthawks', 'English'),
#  ("Porky's", 'English'),
#  ('Raiders of the Lost Ark', 'English'),
#  ('Reds', 'English'),
#  ('Roar', 'English'),
#  ('Sphinx', 'English'),
#  ('Stripes', 'English'),
#  ('The Evil Dead', 'English'),
#  ('The Four Seasons', 'English'),
#  ('The Howling', 'English'),
#  ('The Legend of the Lone Ranger', 'English'),
#  ('The Postman Always Rings Twice', 'English'),
#  ('The Pursuit of D.B. Cooper', 'English'),
#  ('Time Bandits', 'English'),
#  ('Under the Rainbow', 'English'),
#  ('Blade Runner', 'English'),
#  ('Butterfly', 'English'),
#  ('Cat People', 'English'),
#  ('Cat People', 'English'),
#  ('Class of 1984', 'English'),
#  ('Conan the Barbarian', 'English'),
#  ('Conan the Barbarian', 'English'),
#  ('Creepshow', 'English'),
#  ('Creepshow', 'English'),
#  ('Diner', 'English'),
#  ('E.T. the Extra-Terrestrial', 'English'),
#  ('Fast Times at Ridgemont High', 'English'),
#  ('Firefox', 'English'),
#  ('First Blood', 'English'),
#  ('First Blood', 'English'),
#  ('Friday the 13th Part III', 'English'),
#  ('Gandhi', 'English'),
#  ('Halloween III: Season of the Witch', 'English'),
#  ('Jekyll and Hyde... Together Again', 'English'),
#  ('Megaforce', 'English'),
#  ('Poltergeist', 'English'),
#  ('Poltergeist', 'English'),
#  ('Star Trek II: The Wrath of Khan', 'English'),
#  ('The Ballad of Gregorio Cortez', 'English'),
#  ('The Beastmaster', 'English'),
#  ('The Best Little Whorehouse in Texas', 'English'),
#  ('The Man from Snowy River', 'English'),
#  ('The Thing', 'English'),
#  ('The Verdict', 'English'),
#  ('Tootsie', 'English'),
#  ('A Christmas Story', 'English'),
#  ('Flashdance', 'English'),
#  ('Krull', 'English'),
#  ('Lone Wolf McQuade', 'English'),
#  ("Losin' It", 'English'),
#  ('Love Letters', 'English'),
#  ("National Lampoon's Vacation", 'English'),
#  ('Never Say Never Again', 'English'),
#  ('Octopussy', 'English'),
#  ('Scarface', 'English'),
#  ('Star Wars: Episode VI - Return of the Jedi', 'English'),
#  ('Superman III', 'English'),
#  ('The Dead Zone', 'English'),
#  ('The Outsiders', 'English'),
#  ('The Right Stuff', 'English'),
#  ('The Wicked Lady', 'English'),
#  ('Trading Places', 'English'),
#  ('Twilight Zone: The Movie', 'English'),
#  ('Videodrome', 'English'),
#  ('WarGames', 'English'),
#  ('Yentl', 'English'),
#  ('A Nightmare on Elm Street', 'English'),
#  ('A Nightmare on Elm Street', 'English'),
#  ('A Passage to India', 'English'),
#  ('Amadeus', 'English'),
#  ('Beverly Hills Cop', 'English'),
#  ('Body Double', 'English'),
#  ('C.H.U.D.', 'English'),
#  ('Conan the Destroyer', 'English'),
#  ('Dune', 'English'),
#  ('Firestarter', 'English'),
#  ('Footloose', 'English'),
#  ('Footloose', 'English'),
#  ('Friday the 13th: The Final Chapter', 'English'),
#  ('Gremlins', 'English'),
#  ('Indiana Jones and the Temple of Doom', 'English'),
#  ('Once Upon a Time in America', 'English'),
#  ('Police Academy', 'English'),
#  ('Red Dawn', 'English'),
#  ('Repo Man', 'English'),
#  ('Sheena', 'English'),
#  ('Splash', 'English'),
#  ('Star Trek III: The Search for Spock', 'English'),
#  ('The Bounty', 'English'),
#  ('The Cotton Club', 'English'),
#  ('The Hotel New Hampshire', 'English'),
#  ('The Ice Pirates', 'English'),
#  ('The Karate Kid', 'English'),
#  ('The Karate Kid', 'English'),
#  ('The NeverEnding Story', 'English'),
#  ('The Terminator', 'English'),
#  ('The Toxic Avenger', 'English'),
#  ("A Nightmare on Elm Street 2: Freddy's Revenge", 'English'),
#  ('A Room with a View', 'English'),
#  ('A View to a Kill', 'English'),
#  ('Back to the Future', 'English'),
#  ('Brazil', 'English'),
#  ('Commando', 'English'),
#  ('Day of the Dead', 'English'),
#  ('Day of the Dead', 'English'),
#  ('Def-Con 4', 'English'),
#  ('Friday the 13th: A New Beginning', 'English'),
#  ('Invasion U.S.A.', 'English'),
#  ('Krush Groove', 'English'),
#  ('Ladyhawke', 'English'),
#  ('Lifeforce', 'English'),
#  ('Mad Max Beyond Thunderdome', 'English'),
#  ('My Beautiful Laundrette', 'English'),
#  ('Out of Africa', 'English'),
#  ('Friday the 13th Part VII: The New Blood', 'English'),
#  ('Halloween 4: The Return of Michael Myers', 'English'),
#  ('Iguana', 'English'),
#  ('Lady in White', 'English'),
#  ('Midnight Run', 'English'),
#  ('My Stepmother Is an Alien', 'English'),
#  ('Mystic Pizza', 'English'),
#  ('Phantasm II', 'English'),
#  ('Poltergeist III', 'English'),
#  ('Rain Man', 'English'),
#  ('Rambo III', 'English'),
#  ('School Daze', 'English'),
#  ('Scrooged', 'English'),
#  ('Talk Radio', 'English'),
#  ('The Land Before Time', 'English'),
#  ('The Last Temptation of Christ', 'English'),
#  ('They Live', 'English'),
#  ('Twins', 'English'),
#  ('Young Guns', 'English'),
#  ('A Nightmare on Elm Street 5: The Dream Child', 'English'),
#  ('Back to the Future Part II', 'English'),
#  ('Batman', 'English'),
#  ("Bill & Ted's Excellent Adventure", 'English'),
#  ('Black Rain', 'English'),
#  ('Born on the Fourth of July', 'English'),
#  ('Dead Poets Society', 'English'),
#  ('Do the Right Thing', 'English'),
#  ('Driving Miss Daisy', 'English'),
#  ('Friday the 13th Part VIII: Jason Takes Manhattan', 'English'),
#  ('Glory', 'English'),
#  ('Glory', 'English'),
#  ('Halloween 5', 'English'),
#  ('Henry V', 'English'),
#  ('Indiana Jones and the Last Crusade', 'English'),
#  ('Licence to Kill', 'English'),
#  ('Major League', 'English'),
#  ('New York Stories', 'English'),
#  ('Pet Sematary', 'English'),
#  ('Road House', 'English'),
#  ('Roger & Me', 'English'),
#  ('Sea of Love', 'English'),
#  ('Sex, Lies, and Videotape', 'English'),
#  ('Star Trek V: The Final Frontier', 'English'),
#  ('Tango & Cash', 'English'),
#  ('The Abyss', 'English'),
#  ('The Blood of Heroes', 'English'),
#  ('The Toxic Avenger Part II', 'English'),
#  ('Troop Beverly Hills', 'English'),
#  ('UHF', 'English'),
#  ('Warlock', 'English'),
#  ("We're No Angels", 'English'),
#  ('When Harry Met Sally...', 'English'),
#  ('Arachnophobia', 'English'),
#  ('Back to the Future Part III', 'English'),
#  ("Child's Play 2", 'English'),
#  ('Dances with Wolves', 'English'),
#  ('Days of Thunder', 'English'),
#  ('Dick Tracy', 'English'),
#  ('Die Hard 2', 'English'),
#  ('Edward Scissorhands', 'English'),
#  ('Flatliners', 'English'),
#  ('Ghost', 'English'),
#  ('Goodfellas', 'English'),
#  ('Gremlins 2: The New Batch', 'English'),
#  ('Home Alone', 'English'),
#  ('Kindergarten Cop', 'English'),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 'English'),
#  ('Metropolitan', 'English'),
#  ('Midnight Cabaret', 'English'),
#  ("Mo' Better Blues", 'English'),
#  ('Predator 2', 'English'),
#  ('Pretty Woman', 'English'),
#  ('Quigley Down Under', 'English'),
#  ('Shipwrecked', 'English'),
#  ('Spaced Invaders', 'English'),
#  ('The Adventures of Ford Fairlane', 'English'),
#  ('The Godfather: Part III', 'English'),
#  ('The Hunt for Red October', 'English'),
#  ('Total Recall', 'English'),
#  ('Total Recall', 'English'),
#  ('Tremors', 'English'),
#  ('Two Evil Eyes', 'English'),
#  ('Beastmaster 2: Through the Portal of Time', 'English'),
#  ("Bill & Ted's Bogus Journey", 'English'),
#  ('Boyz n the Hood', 'English'),
#  ('Cape Fear', 'English'),
#  ('Double Impact', 'English'),
#  ('Flight of the Intruder', 'English'),
#  ("Freddy's Dead: The Final Nightmare", 'English'),
#  ('Harley Davidson and the Marlboro Man', 'English'),
#  ('Hook', 'English'),
#  ('House Party 2', 'English'),
#  ('Hudson Hawk', 'English'),
#  ('JFK', 'English'),
#  ('Johnny Suede', 'English'),
#  ('My Girl', 'English'),
#  ('My Own Private Idaho', 'English'),
#  ('Return to the Blue Lagoon', 'English'),
#  ('Robin Hood: Prince of Thieves', 'English'),
#  ('Showdown in Little Tokyo', 'English'),
#  ('Slacker', 'English'),
#  ('Star Trek VI: The Undiscovered Country', 'English'),
#  ('Stone Cold', 'English'),
#  ('Straight Out of Brooklyn', 'English'),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 'English'),
#  ('Terminator 2: Judgment Day', 'English'),
#  ('The Addams Family', 'English'),
#  ('The Doors', 'English'),
#  ('The Fisher King', 'English'),
#  ('The Naked Gun 2Â½: The Smell of Fear', 'English'),
#  ('The Prince of Tides', 'English'),
#  ('The Silence of the Lambs', 'English'),
#  ('White Fang', 'English'),
#  ('A Few Good Men', 'English'),
#  ('A League of Their Own', 'English'),
#  ('Aladdin', 'English'),
#  ('Alien 3', 'English'),
#  ('Army of Darkness', 'English'),
#  ('Batman Returns', 'English'),
#  ('Boomerang', 'English'),
#  ("Bram Stoker's Dracula", 'English'),
#  ('Death Becomes Her', 'English'),
#  ('El Mariachi', 'Spanish'),
#  ('Fortress', 'English'),
#  ('Glengarry Glen Ross', 'English'),
#  ('Hoffa', 'English'),
#  ('Home Alone 2: Lost in New York', 'English'),
#  ('Howards End', 'English'),
#  ('Lethal Weapon 3', 'English'),
#  ('Light Sleeper', 'English'),
#  ('Malcolm X', 'English'),
#  ('Medicine Man', 'English'),
#  ('Memoirs of an Invisible Man', 'English'),
#  ('My Cousin Vinny', 'English'),
#  ('Patriot Games', 'English'),
#  ('Radio Flyer', 'English'),
#  ('Raising Cain', 'English'),
#  ('Reservoir Dogs', 'English'),
#  ('Split Second', 'English'),
#  ('The Bodyguard', 'English'),
#  ('The Crying Game', 'English'),
#  ('The Last of the Mohicans', 'English'),
#  ('The Lawnmower Man', 'English'),
#  ('The Mighty Ducks', 'English'),
#  ('The Muppet Christmas Carol', 'English'),
#  ('Unforgiven', 'English'),
#  ("Wayne's World", 'English'),
#  ('Airborne', 'English'),
#  ('Alive', 'English'),
#  ('Blood In, Blood Out', 'English'),
#  ('Cliffhanger', 'English'),
#  ('Cool Runnings', 'English'),
#  ('Dazed and Confused', 'English'),
#  ('Ed and His Dead Mother', 'English'),
#  ('Excessive Force', 'English'),
#  ('Gettysburg', 'English'),
#  ('Groundhog Day', 'English'),
#  ('Hocus Pocus', 'English'),
#  ('Jason Goes to Hell: The Final Friday', 'English'),
#  ('Jurassic Park', 'English'),
#  ('Killing Zoe', 'English'),
#  ('Last Action Hero', 'English'),
#  ('Les visiteurs', 'French'),
#  ('Loaded Weapon 1', 'English'),
#  ('Menace II Society', 'English'),
#  ('Mrs. Doubtfire', 'English'),
#  ('Much Ado About Nothing', 'English'),
#  ('Nowhere to Run', 'English'),
#  ('Only the Strong', 'English'),
#  ('Philadelphia', 'English'),
#  ('Poetic Justice', 'English'),
#  ('Return of the Living Dead III', 'English'),
#  ('RoboCop 3', 'English'),
#  ('Romeo Is Bleeding', 'English'),
#  ('Ruby in Paradise', 'English'),
#  ("Schindler's List", 'English'),
#  ('Shadowlands', 'English'),
#  ('Sugar Hill', 'English'),
#  ('Super Mario Bros.', 'English'),
#  ('Teenage Mutant Ninja Turtles III', 'English'),
#  ('The Adventures of Huck Finn', 'English'),
#  ('The Age of Innocence', 'English'),
#  ('The Firm', 'English'),
#  ('The Fugitive', 'English'),
#  ('The Nutcracker', 'English'),
#  ('The Pelican Brief', 'English'),
#  ('The Piano', 'English'),
#  ('The Princess and the Cobbler', 'English'),
#  ('The Remains of the Day', 'English'),
#  ('Tombstone', 'English'),
#  ('True Romance', 'English'),
#  ('Warlock: The Armageddon', 'English'),
#  ("What's Eating Gilbert Grape", 'English'),
#  ("What's Love Got to Do with It", 'English'),
#  ('3 Ninjas Kick Back', 'English'),
#  ('A Low Down Dirty Shame', 'English'),
#  ('Ace Ventura: Pet Detective', 'English'),
#  ("Baby's Day Out", 'English'),
#  ('Beverly Hills Cop III', 'English'),
#  ('Bullets Over Broadway', 'English'),
#  ('Clear and Present Danger', 'English'),
#  ('Clerks', 'English'),
#  ('Crooklyn', 'English'),
#  ('Disclosure', 'English'),
#  ('Don Juan DeMarco', 'English'),
#  ('Dumb & Dumber', 'English'),
#  ('Ed Wood', 'English'),
#  ('Exotica', 'English'),
#  ('Forrest Gump', 'English'),
#  ('Four Weddings and a Funeral', 'English'),
#  ('Heavenly Creatures', 'English'),
#  ('Highlander: The Final Dimension', 'English'),
#  ('Hoop Dreams', 'English'),
#  ('Interview with the Vampire: The Vampire Chronicles', 'English'),
#  ('Legends of the Fall', 'English'),
#  ('Little Women', 'English'),
#  ('Men of War', 'English'),
#  ('Naked Gun 33 1/3: The Final Insult', 'English'),
#  ('New Nightmare', 'English'),
#  ('On Deadly Ground', 'English'),
#  ('PCU', 'English'),
#  ('Police Academy: Mission to Moscow', 'English'),
#  ('Pulp Fiction', 'English'),
#  ('Rapa Nui', 'English'),
#  ('Renaissance Man', 'English'),
#  ('RiÂ¢hie RiÂ¢h', 'English'),
#  ('Serial Mom', 'English'),
#  ('Speed', 'English'),
#  ('Star Trek: Generations', 'English'),
#  ('Street Fighter', 'English'),
#  ('The Client', 'English'),
#  ('The Crow', 'English'),
#  ('The Flintstones', 'English'),
#  ('The Hudsucker Proxy', 'English'),
#  ('The Inkwell', 'English'),
#  ('The Lion King', 'English'),
#  ('The Mask', 'English'),
#  ('The River Wild', 'English'),
#  ('The Santa Clause', 'English'),
#  ('The Shadow', 'English'),
#  ('The Shawshank Redemption', 'English'),
#  ('The Specialist', 'English'),
#  ('There Goes My Baby', 'English'),
#  ('Timecop', 'English'),
#  ('True Lies', 'English'),
#  ('Wolf', 'English'),
#  ('Wyatt Earp', 'English'),
#  ('Ace Ventura: When Nature Calls', 'English'),
#  ('Apollo 13', 'English'),
#  ('Assassins', 'English'),
#  ('Babe', 'English'),
#  ('Bad Boys', 'English'),
#  ('Bang', 'English'),
#  ('Batman Forever', 'English'),
#  ('Before Sunrise', 'English'),
#  ('Braveheart', 'English'),
#  ('Casino', 'English'),
#  ('Casper', 'English'),
#  ('Clueless', 'English'),
#  ('Congo', 'English'),
#  ('Copycat', 'English'),
#  ('Crimson Tide', 'English'),
#  ('Cutthroat Island', 'English'),
#  ('Dead Man Walking', 'English'),
#  ('Desperado', 'English'),
#  ('Die Hard with a Vengeance', 'English'),
#  ('First Knight', 'English'),
#  ('Four Rooms', 'English'),
#  ('Friday', 'English'),
#  ('Get Shorty', 'English'),
#  ('GoldenEye', 'English'),
#  ('Hackers', 'English'),
#  ('Halloween: The Curse of Michael Myers', 'English'),
#  ('Home for the Holidays', 'English'),
#  ('Jade', 'English'),
#  ('Jefferson in Paris', 'English'),
#  ('Kids', 'English'),
#  ('Kiss of Death', 'English'),
#  ('Leaving Las Vegas', 'English'),
#  ('Mallrats', 'English'),
#  ('Money Train', 'English'),
#  ('Mortal Kombat', 'English'),
#  ("Mr. Holland's Opus", 'English'),
#  ('Nixon', 'English'),
#  ('Outbreak', 'English'),
#  ('Pocahontas', 'English'),
#  ('Richard III', 'English'),
#  ('Rob Roy', 'English'),
#  ('Se7en', 'English'),
#  ('Sense and Sensibility', 'English'),
#  ('Showgirls', 'English'),
#  ('Species', 'English'),
#  ('Tales from the Crypt: Demon Knight', 'English'),
#  ('Tales from the Hood', 'English'),
#  ('Tank Girl', 'English'),
#  ('The American President', 'English'),
#  ('The Bridges of Madison County', 'English'),
#  ('The Brothers McMullen', 'English'),
#  ('The Horseman on the Roof', 'French'),
#  ('The Incredibly True Adventure of Two Girls in Love', 'English'),
#  ('The Indian in the Cupboard', 'English'),
#  ('The Jerky Boys', 'English'),
#  ('The Net', 'English'),
#  ('The Perez Family', 'English'),
#  ('The Prophecy', 'English'),
#  ('The Quick and the Dead', 'English'),
#  ('The Scarlet Letter', 'English'),
#  ('The Usual Suspects', 'English'),
#  ("Things to Do in Denver When You're Dead", 'English'),
#  ('To Die For', 'English'),
#  ('Toy Story', 'English'),
#  ('Under Siege 2: Dark Territory', 'English'),
#  ('Vampire in Brooklyn', 'English'),
#  ('Virtuosity', 'English'),
#  ('Waterworld', 'English'),
#  ('Welcome to the Dollhouse', 'English'),
#  ('A Thin Line Between Love and Hate', 'English'),
#  ('A Time to Kill', 'English'),
#  ('Albino Alligator', 'English'),
#  ('Basquiat', 'English'),
#  ('Beavis and Butt-Head Do America', 'English'),
#  ('Blood and Wine', 'English'),
#  ('Bogus', 'English'),
#  ('Bottle Rocket', 'English'),
#  ('Bound', 'English'),
#  ('Broken Arrow', 'English'),
#  ('Chain Reaction', 'English'),
#  ('City Hall', 'English'),
#  ('Courage Under Fire', 'English'),
#  ('Daylight', 'English'),
#  ('DragonHeart', 'English'),
#  ('Eraser', 'English'),
#  ('Escape from L.A.', 'English'),
#  ('Everyone Says I Love You', 'English'),
#  ('Evita', 'English'),
#  ('Executive Decision', 'English'),
#  ('Extreme Measures', 'English'),
#  ('Eye for an Eye', 'English'),
#  ('Faithful', 'English'),
#  ('Fled', 'English'),
#  ('Flipper', 'English'),
#  ('Flirting with Disaster', 'English'),
#  ('Freeway', 'English'),
#  ('From Dusk Till Dawn', 'English'),
#  ('Get on the Bus', 'English'),
#  ('Ghosts of Mississippi', 'English'),
#  ('Girl 6', 'English'),
#  ('Hamlet', 'English'),
#  ('Hamlet', 'English'),
#  ('Happy Gilmore', 'English'),
#  ('Harriet the Spy', 'English'),
#  ('Independence Day', 'English'),
#  ('Jerry Maguire', 'English'),
#  ('Jingle All the Way', 'English'),
#  ('Kama Sutra: A Tale of Love', 'English'),
#  ('Kansas City', 'English'),
#  ('Kingpin', 'English'),
#  ('Lone Star', 'English'),
#  ('Love and Other Catastrophes', 'English'),
#  ('Mars Attacks!', 'English'),
#  ("Marvin's Room", 'English'),
#  ('Mary Reilly', 'English'),
#  ('Maximum Risk', 'English'),
#  ('Michael Collins', 'English'),
#  ('Mission: Impossible', 'English'),
#  ('Mrs. Winterbourne', 'English'),
#  ('Multiplicity', 'English'),
#  ('My Fellow Americans', 'English'),
#  ('Phenomenon', 'English'),
#  ('Ransom', 'English'),
#  ('Romeo + Juliet', 'English'),
#  ('Scream', 'English'),
#  ('Set It Off', 'English'),
#  ('Sgt. Bilko', 'English'),
#  ("She's the One", 'English'),
#  ('Shine', 'English'),
#  ('Silent Trigger', 'English'),
#  ('Sleepers', 'English'),
#  ('Sling Blade', 'English'),
#  ('Space Jam', 'English'),
#  ('Spy Hard', 'English'),
#  ('Star Trek: First Contact', 'English'),
#  ('Striptease', 'English'),
#  ('Swingers', 'English'),
#  ('That Thing You Do!', 'English'),
#  ('The Cable Guy', 'English'),
#  ('The Craft', 'English'),
#  ('The English Patient', 'English'),
#  ('The Fan', 'English'),
#  ('The First Wives Club', 'English'),
#  ('The Funeral', 'English'),
#  ('The Ghost and the Darkness', 'English'),
#  ('The Glimmer Man', 'English'),
#  ('The Hunchback of Notre Dame', 'English'),
#  ('The Island of Dr. Moreau', 'English'),
#  ('The Juror', 'English'),
#  ('The Last Big Thing', 'English'),
#  ('The Long Kiss Goodnight', 'English'),
#  ('The Mirror Has Two Faces', 'English'),
#  ('The Nutty Professor', 'English'),
#  ('The Pallbearer', 'English'),
#  ('The Phantom', 'English'),
#  ('The Rock', 'English'),
#  ('Thinner', 'English'),
#  ('Tin Cup', 'English'),
#  ('Trainspotting', 'English'),
#  ('Trees Lounge', 'English'),
#  ('Twister', 'English'),
#  ('Up Close & Personal', 'English'),
#  ('Waiting for Guffman', 'English'),
#  ('Walking and Talking', 'English'),
#  ("When the Cat's Away", 'French'),
#  ('White Squall', 'English'),
#  ('24 7: Twenty Four Seven', 'English'),
#  ('8 Heads in a Duffel Bag', 'English'),
#  ('A Simple Wish', 'English'),
#  ('Absolute Power', 'English'),
#  ('Air Bud', 'English'),
#  ('Air Force One', 'English'),
#  ('Alien: Resurrection', 'English'),
#  ('Amistad', 'English'),
#  ('An Alan Smithee Film: Burn Hollywood Burn', 'English'),
#  ('Anaconda', 'English'),
#  ('Anastasia', 'English'),
#  ('As Good as It Gets', 'English'),
#  ('Austin Powers: International Man of Mystery', 'English'),
#  ('Batman & Robin', 'English'),
#  ('Boogie Nights', 'English'),
#  ('Breakdown', 'English'),
#  ("Cats Don't Dance", 'English'),
#  ('Chasing Amy', 'English'),
#  ('Clockwatchers', 'English'),
#  ('Con Air', 'English'),
#  ('Conspiracy Theory', 'English'),
#  ('Contact', 'English'),
#  ('Cop Land', 'English'),
#  ('Critical Care', 'English'),
#  ('Cube', 'English'),
#  ("Dante's Peak", 'English'),
#  ('Deconstructing Harry', 'English'),
#  ('DÃ©jÃ  Vu', 'English'),
#  ('Donnie Brasco', 'English'),
#  ('Dream with the Fishes', 'English'),
#  ("Eve's Bayou", 'English'),
#  ('Event Horizon', 'English'),
#  ('Face/Off', 'English'),
#  ('First Love, Last Rites', 'English'),
#  ('Flubber', 'English'),
#  ('G.I. Jane', 'English'),
#  ('Gattaca', 'English'),
#  ('George of the Jungle', 'English'),
#  ('Good Will Hunting', 'English'),
#  ('Grosse Pointe Blank', 'English'),
#  ('Hav Plenty', 'English'),
#  ('How to Be a Player', 'English'),
#  ('Hurricane Streets', 'English'),
#  ('I Know What You Did Last Summer', 'English'),
#  ("I Love You, Don't Touch Me!", 'English'),
#  ('I Married a Strange Person!', 'English'),
#  ('In & Out', 'English'),
#  ('In the Company of Men', 'English'),
#  ('Jackie Brown', 'English'),
#  ('Kiss the Girls', 'English'),
#  ('Kundun', 'English'),
#  ('L.A. Confidential', 'English'),
#  ('Liar Liar', 'English'),
#  ('Love and Death on Long Island', 'English'),
#  ('Love Jones', 'English'),
#  ('Mad City', 'English'),
#  ('Men in Black', 'English'),
#  ('Midnight in the Garden of Good and Evil', 'English'),
#  ('Money Talks', 'English'),
#  ('Mortal Kombat: Annihilation', 'English'),
#  ('Mr. Nice Guy', 'English'),
#  ("My Best Friend's Wedding", 'English'),
#  ('Nothing to Lose', 'English'),
#  ('Orgazmo', 'English'),
#  ('Oscar and Lucinda', 'English'),
#  ('Prefontaine', 'English'),
#  ('Scream 2', 'English'),
#  ('Selena', 'English'),
#  ('Seven Years in Tibet', 'English'),
#  ('Shadow Conspiracy', 'English'),
#  ('Shooting Fish', 'English'),
#  ("Smilla's Sense of Snow", 'English'),
#  ('Snow White: A Tale of Terror', 'English'),
#  ('Soul Food', 'English'),
#  ('Sparkler', 'English'),
#  ('Spawn', 'English'),
#  ('Speed 2: Cruise Control', 'English'),
#  ('Spice World', 'English'),
#  ('Starship Troopers', 'English'),
#  ('Steel', 'English'),
#  ('Switchback', 'English'),
#  ('The Apostle', 'English'),
#  ('The Borrowers', 'English'),
#  ('The Chambermaid on the Titanic', 'French'),
#  ("The Devil's Advocate", 'English'),
#  ("The Devil's Own", 'English'),
#  ('The Edge', 'English'),
#  ('The Fifth Element', 'English'),
#  ('The Full Monty', 'English'),
#  ('The Full Monty', 'English'),
#  ('The Game', 'English'),
#  ('The Ice Storm', 'English'),
#  ('The Jackal', 'English'),
#  ('The Last Time I Committed Suicide', 'English'),
#  ('The Lost World: Jurassic Park', 'English'),
#  ('The Man Who Knew Too Little', 'English'),
#  ('The Peacemaker', 'English'),
#  ('The Postman', 'English'),
#  ('The Rainmaker', 'English'),
#  ('The Relic', 'English'),
#  ('The Saint', 'English'),
#  ('The Spanish Prisoner', 'English'),
#  ('The Sticky Fingers of Time', 'English'),
#  ('The Sweet Hereafter', 'English'),
#  ('The Swindle', 'French'),
#  ('Titanic', 'English'),
#  ('Tomorrow Never Dies', 'English'),
#  ...]

# %%
# -- Find the title, certification, and language all films certified NC-17 or R that are in English, Italian, or Greek
cur.execute("""
            
            SELECT title, certification, language 
            FROM films 
            WHERE certification IN ('NC-17', 'R') AND language IN ('English', 'Italian', 'Greek');
            
            """).fetchall()
# Out:
# [('Psycho', 'R', 'English'),
#  ('A Fistful of Dollars', 'R', 'Italian'),
#  ("Rosemary's Baby", 'R', 'English'),
#  ('The Wild Bunch', 'R', 'English'),
#  ('Catch-22', 'R', 'English'),
#  ('Cotton Comes to Harlem', 'R', 'English'),
#  ('The Ballad of Cable Hogue', 'R', 'English'),
#  ('The Conformist', 'R', 'Italian'),
#  ('Woodstock', 'R', 'English'),
#  ("Sweet Sweetback's Baadasssss Song", 'R', 'English'),
#  ('The French Connection', 'R', 'English'),
#  ('The French Connection', 'R', 'English'),
#  ('Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#   'R',
#   'English'),
#  ('Frenzy', 'R', 'English'),
#  ('Pink Flamingos', 'NC-17', 'English'),
#  ('The Godfather', 'R', 'English'),
#  ('High Plains Drifter', 'R', 'English'),
#  ('Mean Streets', 'R', 'English'),
#  ('Pat Garrett & Billy the Kid', 'R', 'English'),
#  ('The Exorcist', 'R', 'English'),
#  ('Blazing Saddles', 'R', 'English'),
#  ('The Godfather: Part II', 'R', 'English'),
#  ('The Texas Chain Saw Massacre', 'R', 'English'),
#  ('The Texas Chain Saw Massacre', 'R', 'English'),
#  ('Death Race 2000', 'R', 'English'),
#  ("One Flew Over the Cuckoo's Nest", 'R', 'English'),
#  ('Network', 'R', 'English'),
#  ('Taxi Driver', 'R', 'English'),
#  ('The Omen', 'R', 'English'),
#  ('The Omen', 'R', 'English'),
#  ('Exorcist II: The Heretic', 'R', 'English'),
#  ('The Kentucky Fried Movie', 'R', 'English'),
#  ('Animal House', 'R', 'English'),
#  ('Halloween', 'R', 'English'),
#  ('Halloween', 'R', 'English'),
#  ('Halloween', 'R', 'English'),
#  ('The Boys from Brazil', 'R', 'English'),
#  ('The Deer Hunter', 'R', 'English'),
#  ('Alien', 'R', 'English'),
#  ('All That Jazz', 'R', 'English'),
#  ('Apocalypse Now', 'R', 'English'),
#  ('Mad Max', 'R', 'English'),
#  ('Penitentiary', 'R', 'English'),
#  ('The Rose', 'R', 'English'),
#  ('Caddyshack', 'R', 'English'),
#  ('Galaxina', 'R', 'English'),
#  ("Heaven's Gate", 'R', 'English'),
#  ('Ordinary People', 'R', 'English'),
#  ('Out of the Blue', 'R', 'English'),
#  ('Private Benjamin', 'R', 'English'),
#  ('Raging Bull', 'R', 'English'),
#  ('The Blue Lagoon', 'R', 'English'),
#  ('The Blues Brothers', 'R', 'English'),
#  ('The Fog', 'R', 'English'),
#  ('The Fog', 'R', 'English'),
#  ('The Long Riders', 'R', 'English'),
#  ('The Shining', 'R', 'English'),
#  ('Blow Out', 'R', 'English'),
#  ('Escape from New York', 'R', 'English'),
#  ('Friday the 13th Part 2', 'R', 'English'),
#  ('Graduation Day', 'R', 'English'),
#  ('Heavy Metal', 'R', 'English'),
#  ('History of the World: Part I', 'R', 'English'),
#  ('History of the World: Part I', 'R', 'English'),
#  ('Mad Max 2: The Road Warrior', 'R', 'English'),
#  ('Mommie Dearest', 'R', 'English'),
#  ('Nighthawks', 'R', 'English'),
#  ("Porky's", 'R', 'English'),
#  ('Stripes', 'R', 'English'),
#  ('The Evil Dead', 'NC-17', 'English'),
#  ('The Howling', 'R', 'English'),
#  ('The Postman Always Rings Twice', 'R', 'English'),
#  ('Blade Runner', 'R', 'English'),
#  ('Butterfly', 'R', 'English'),
#  ('Cat People', 'R', 'English'),
#  ('Cat People', 'R', 'English'),
#  ('Class of 1984', 'R', 'English'),
#  ('Conan the Barbarian', 'R', 'English'),
#  ('Conan the Barbarian', 'R', 'English'),
#  ('Creepshow', 'R', 'English'),
#  ('Creepshow', 'R', 'English'),
#  ('Diner', 'R', 'English'),
#  ('First Blood', 'R', 'English'),
#  ('First Blood', 'R', 'English'),
#  ('Friday the 13th Part III', 'R', 'English'),
#  ('Halloween III: Season of the Witch', 'R', 'English'),
#  ('Jekyll and Hyde... Together Again', 'R', 'English'),
#  ('The Best Little Whorehouse in Texas', 'R', 'English'),
#  ('The Thing', 'R', 'English'),
#  ('The Verdict', 'R', 'English'),
#  ('Flashdance', 'R', 'English'),
#  ("Losin' It", 'R', 'English'),
#  ('Love Letters', 'R', 'English'),
#  ("National Lampoon's Vacation", 'R', 'English'),
#  ('Scarface', 'R', 'English'),
#  ('The Dead Zone', 'R', 'English'),
#  ('The Wicked Lady', 'R', 'English'),
#  ('Trading Places', 'R', 'English'),
#  ('Videodrome', 'R', 'English'),
#  ('Amadeus', 'R', 'English'),
#  ('Beverly Hills Cop', 'R', 'English'),
#  ('Body Double', 'R', 'English'),
#  ('C.H.U.D.', 'R', 'English'),
#  ('Firestarter', 'R', 'English'),
#  ('Friday the 13th: The Final Chapter', 'R', 'English'),
#  ('Once Upon a Time in America', 'R', 'English'),
#  ('Police Academy', 'R', 'English'),
#  ('Repo Man', 'R', 'English'),
#  ('The Cotton Club', 'R', 'English'),
#  ('The Hotel New Hampshire', 'R', 'English'),
#  ('The Terminator', 'R', 'English'),
#  ('Do the Right Thing', 'R', 'English'),
#  ('Friday the 13th Part VIII: Jason Takes Manhattan', 'R', 'English'),
#  ('Glory', 'R', 'English'),
#  ('Glory', 'R', 'English'),
#  ('Major League', 'R', 'English'),
#  ('Pet Sematary', 'R', 'English'),
#  ('Road House', 'R', 'English'),
#  ('Roger & Me', 'R', 'English'),
#  ('Sea of Love', 'R', 'English'),
#  ('Sex, Lies, and Videotape', 'R', 'English'),
#  ('Tango & Cash', 'R', 'English'),
#  ('The Blood of Heroes', 'R', 'English'),
#  ('The Toxic Avenger Part II', 'R', 'English'),
#  ('Warlock', 'R', 'English'),
#  ('When Harry Met Sally...', 'R', 'English'),
#  ("Child's Play 2", 'R', 'English'),
#  ('Die Hard 2', 'R', 'English'),
#  ('Flatliners', 'R', 'English'),
#  ('Goodfellas', 'R', 'English'),
#  ('Midnight Cabaret', 'R', 'English'),
#  ("Mo' Better Blues", 'R', 'English'),
#  ('Predator 2', 'R', 'English'),
#  ('Pretty Woman', 'R', 'English'),
#  ('The Adventures of Ford Fairlane', 'R', 'English'),
#  ('The Godfather: Part III', 'R', 'English'),
#  ('Total Recall', 'R', 'English'),
#  ('Total Recall', 'R', 'English'),
#  ('Two Evil Eyes', 'R', 'English'),
#  ('Boyz n the Hood', 'R', 'English'),
#  ('Cape Fear', 'R', 'English'),
#  ('Double Impact', 'R', 'English'),
#  ("Freddy's Dead: The Final Nightmare", 'R', 'English'),
#  ('Harley Davidson and the Marlboro Man', 'R', 'English'),
#  ('House Party 2', 'R', 'English'),
#  ('Hudson Hawk', 'R', 'English'),
#  ('JFK', 'R', 'English'),
#  ('Johnny Suede', 'R', 'English'),
#  ('My Own Private Idaho', 'R', 'English'),
#  ('Showdown in Little Tokyo', 'R', 'English'),
#  ('Slacker', 'R', 'English'),
#  ('Stone Cold', 'R', 'English'),
#  ('Straight Out of Brooklyn', 'R', 'English'),
#  ('Terminator 2: Judgment Day', 'R', 'English'),
#  ('The Doors', 'R', 'English'),
#  ('The Fisher King', 'R', 'English'),
#  ('The Prince of Tides', 'R', 'English'),
#  ('The Silence of the Lambs', 'R', 'English'),
#  ('A Few Good Men', 'R', 'English'),
#  ('Alien 3', 'R', 'English'),
#  ('Army of Darkness', 'R', 'English'),
#  ('Boomerang', 'R', 'English'),
#  ("Bram Stoker's Dracula", 'R', 'English'),
#  ('Fortress', 'R', 'English'),
#  ('Glengarry Glen Ross', 'R', 'English'),
#  ('Hoffa', 'R', 'English'),
#  ('Lethal Weapon 3', 'R', 'English'),
#  ('Light Sleeper', 'R', 'English'),
#  ('My Cousin Vinny', 'R', 'English'),
#  ('Patriot Games', 'R', 'English'),
#  ('Raising Cain', 'R', 'English'),
#  ('Reservoir Dogs', 'R', 'English'),
#  ('Split Second', 'R', 'English'),
#  ('The Bodyguard', 'R', 'English'),
#  ('The Crying Game', 'R', 'English'),
#  ('The Last of the Mohicans', 'R', 'English'),
#  ('The Lawnmower Man', 'R', 'English'),
#  ('Unforgiven', 'R', 'English'),
#  ('Alive', 'R', 'English'),
#  ('Showgirls', 'NC-17', 'English'),
#  ('Species', 'R', 'English'),
#  ('Tales from the Crypt: Demon Knight', 'R', 'English'),
#  ('Tales from the Hood', 'R', 'English'),
#  ('Tank Girl', 'R', 'English'),
#  ('The Brothers McMullen', 'R', 'English'),
#  ('The Incredibly True Adventure of Two Girls in Love', 'R', 'English'),
#  ('The Jerky Boys', 'R', 'English'),
#  ('The Perez Family', 'R', 'English'),
#  ('The Prophecy', 'R', 'English'),
#  ('The Quick and the Dead', 'R', 'English'),
#  ('The Scarlet Letter', 'R', 'English'),
#  ('The Usual Suspects', 'R', 'English'),
#  ("Things to Do in Denver When You're Dead", 'R', 'English'),
#  ('To Die For', 'R', 'English'),
#  ('Under Siege 2: Dark Territory', 'R', 'English'),
#  ('Vampire in Brooklyn', 'R', 'English'),
#  ('Virtuosity', 'R', 'English'),
#  ('Welcome to the Dollhouse', 'R', 'English'),
#  ('A Thin Line Between Love and Hate', 'R', 'English'),
#  ('A Time to Kill', 'R', 'English'),
#  ('Albino Alligator', 'R', 'English'),
#  ('Basquiat', 'R', 'English'),
#  ('Blood and Wine', 'R', 'English'),
#  ('Bottle Rocket', 'R', 'English'),
#  ('Bound', 'R', 'English'),
#  ('Broken Arrow', 'R', 'English'),
#  ('City Hall', 'R', 'English'),
#  ('Courage Under Fire', 'R', 'English'),
#  ('Eraser', 'R', 'English'),
#  ('Escape from L.A.', 'R', 'English'),
#  ('Everyone Says I Love You', 'R', 'English'),
#  ('Executive Decision', 'R', 'English'),
#  ('Extreme Measures', 'R', 'English'),
#  ('Eye for an Eye', 'R', 'English'),
#  ('Faithful', 'R', 'English'),
#  ('Fled', 'R', 'English'),
#  ('Flirting with Disaster', 'R', 'English'),
#  ('Freeway', 'R', 'English'),
#  ('From Dusk Till Dawn', 'R', 'English'),
#  ('Get on the Bus', 'R', 'English'),
#  ('Girl 6', 'R', 'English'),
#  ('Jerry Maguire', 'R', 'English'),
#  ('Kama Sutra: A Tale of Love', 'R', 'English'),
#  ('Kansas City', 'R', 'English'),
#  ('Lone Star', 'R', 'English'),
#  ('Love and Other Catastrophes', 'R', 'English'),
#  ('Mary Reilly', 'R', 'English'),
#  ('Maximum Risk', 'R', 'English'),
#  ('Michael Collins', 'R', 'English'),
#  ('Ransom', 'R', 'English'),
#  ('Scream', 'R', 'English'),
#  ('Set It Off', 'R', 'English'),
#  ("She's the One", 'R', 'English'),
#  ('Silent Trigger', 'R', 'English'),
#  ('Sleepers', 'R', 'English'),
#  ('Sling Blade', 'R', 'English'),
#  ('Striptease', 'R', 'English'),
#  ('Swingers', 'R', 'English'),
#  ('The Craft', 'R', 'English'),
#  ('The English Patient', 'R', 'English'),
#  ('The Fan', 'R', 'English'),
#  ('The Funeral', 'R', 'English'),
#  ('The Ghost and the Darkness', 'R', 'English'),
#  ('The Glimmer Man', 'R', 'English'),
#  ('The Juror', 'R', 'English'),
#  ('The Last Big Thing', 'R', 'English'),
#  ('The Long Kiss Goodnight', 'R', 'English'),
#  ('The Rock', 'R', 'English'),
#  ('Better Luck Tomorrow', 'R', 'English'),
#  ('Blade II', 'R', 'English'),
#  ('Blood Work', 'R', 'English'),
#  ('Bloody Sunday', 'R', 'English'),
#  ('Blue Car', 'R', 'English'),
#  ('Boat Trip', 'R', 'English'),
#  ('Bowling for Columbine', 'R', 'English'),
#  ('Bubba Ho-Tep', 'R', 'English'),
#  ('Changing Lanes', 'R', 'English'),
#  ('City by the Sea', 'R', 'English'),
#  ('City of Ghosts', 'R', 'English'),
#  ('Civil Brand', 'R', 'English'),
#  ('Collateral Damage', 'R', 'English'),
#  ('Confessions of a Dangerous Mind', 'R', 'English'),
#  ('Cypher', 'R', 'English'),
#  ('Dark Blue', 'R', 'English'),
#  ('Death to Smoochy', 'R', 'English'),
#  ('Deuces Wild', 'R', 'English'),
#  ('Dirty Pretty Things', 'R', 'English'),
#  ('Equilibrium', 'R', 'English'),
#  ('Eye See You', 'R', 'English'),
#  ('Fabled', 'R', 'English'),
#  ('Feardotcom', 'R', 'English'),
#  ('Femme Fatale', 'R', 'English'),
#  ('Frida', 'R', 'English'),
#  ('Friday After Next', 'R', 'English'),
#  ('Full Frontal', 'R', 'English'),
#  ('Gangs of New York', 'R', 'English'),
#  ('Gerry', 'R', 'English'),
#  ('Ghost Ship', 'R', 'English'),
#  ('Halloween: Resurrection', 'R', 'English'),
#  ("Hart's War", 'R', 'English'),
#  ('Highway', 'R', 'English'),
#  ('Igby Goes Down', 'R', 'English'),
#  ('Insomnia', 'R', 'English'),
#  ('Interview with the Assassin', 'R', 'English'),
#  ('Jackass: The Movie', 'R', 'English'),
#  ('Martin Lawrence Live: Runteldat', 'R', 'English'),
#  ('May', 'R', 'English'),
#  ('Men with Brooms', 'R', 'English'),
#  ('Morvern Callar', 'R', 'English'),
#  ('Murder by Numbers', 'R', 'English'),
#  ('Murder by Numbers', 'R', 'English'),
#  ('Narc', 'R', 'English'),
#  ('One Hour Photo', 'R', 'English'),
#  ('Panic Room', 'R', 'English'),
#  ('People I Know', 'R', 'English'),
#  ('Phone Booth', 'R', 'English'),
#  ('Poolhall Junkies', 'R', 'English'),
#  ('Punch-Drunk Love', 'R', 'English'),
#  ('Queen of the Damned', 'R', 'English'),
#  ('Raising Victor Vargas', 'R', 'English'),
#  ('Red Dragon', 'R', 'English'),
#  ('Resident Evil', 'R', 'English'),
#  ("Ripley's Game", 'R', 'English'),
#  ('Road to Perdition', 'R', 'English'),
#  ('Rollerball', 'R', 'English'),
#  ('Secretary', 'R', 'English'),
#  ('Slackers', 'R', 'English'),
#  ('Sorority Boys', 'R', 'English'),
#  ('Spider', 'R', 'English'),
#  ('Spun', 'R', 'English'),
#  ('Swept Away', 'R', 'English'),
#  ('The Banger Sisters', 'R', 'English'),
#  ('The Dangerous Lives of Altar Boys', 'R', 'English'),
#  ('The Good Girl', 'R', 'English'),
#  ('The Good Thief', 'R', 'English'),
#  ('The Guru', 'R', 'English'),
#  ('The Heart of Me', 'R', 'English'),
#  ('The Pianist', 'R', 'English'),
#  ('The Quiet American', 'R', 'English'),
#  ('The Statement', 'R', 'English'),
#  ('The Station Agent', 'R', 'English'),
#  ('Thirteen', 'R', 'English'),
#  ('Touching the Void', 'R', 'English'),
#  ('Tupac: Resurrection', 'R', 'English'),
#  ('Underworld', 'R', 'English'),
#  ('Veronica Guerin', 'R', 'English'),
#  ('Wonderland', 'R', 'English'),
#  ('Wrong Turn', 'R', 'English'),
#  ('A Home at the End of the World', 'R', 'English'),
#  ('Alexander', 'R', 'English'),
#  ('Alfie', 'R', 'English'),
#  ('Before Sunset', 'R', 'English'),
#  ('Being Julia', 'R', 'English'),
#  ('Birth', 'R', 'English'),
#  ('Blade: Trinity', 'R', 'English'),
#  ('Bridget Jones: The Edge of Reason', 'R', 'English'),
#  ('Closer', 'R', 'English'),
#  ('Club Dread', 'R', 'English'),
#  ('Collateral', 'R', 'English'),
#  ('Crash', 'R', 'English'),
#  ('Crash', 'R', 'English'),
#  ('Dawn of the Dead', 'R', 'English'),
#  ('Dawn of the Dead', 'R', 'English'),
#  ('Decoys', 'R', 'English'),
#  ('Eternal Sunshine of the Spotless Mind', 'R', 'English'),
#  ('Eulogy', 'R', 'English'),
#  ('EuroTrip', 'R', 'English'),
#  ('Exorcist: The Beginning', 'R', 'English'),
#  ('Fahrenheit 9/11', 'R', 'English'),
#  ('Fascination', 'R', 'English'),
#  ('Fighting Tommy Riley', 'R', 'English'),
#  ('Freeze Frame', 'R', 'English'),
#  ('Garden State', 'R', 'English'),
#  ('Harold & Kumar Go to White Castle', 'R', 'English'),
#  ('I Heart Huckabees', 'R', 'English'),
#  ('Imaginary Heroes', 'R', 'English'),
#  ("It's All Gone Pete Tong", 'R', 'English'),
#  ('Kill Bill: Vol. 2', 'R', 'English'),
#  ('Kinsey', 'R', 'English'),
#  ('Layer Cake', 'R', 'English'),
#  ('Man on Fire', 'R', 'English'),
#  ('Mean Creek', 'R', 'English'),
#  ('Mindhunters', 'R', 'English'),
#  ('My Summer of Love', 'R', 'English'),
#  ('November', 'R', 'English'),
#  ('On the Outs', 'R', 'English'),
#  ('Resident Evil: Apocalypse', 'R', 'English'),
#  ('Saving Face', 'R', 'English'),
#  ('Saw', 'R', 'English'),
#  ('Seed of Chucky', 'R', 'English'),
#  ('Shaun of the Dead', 'R', 'English'),
#  ...]

# %% [markdown]
# ## 0.2.11 Combining filtering and selecting

# %%
# -- Count the unique titles
cur.execute("""
            
            SELECT COUNT(DISTINCT title) AS nineties_english_films_for_teens 
            FROM films 
            WHERE release_year BETWEEN 1990 AND 1999 AND language = 'English' AND certification IN ('G', 'PG', 'PG-13');
            
            """).fetchall()
# Out:
# [(310,)]

# %% [markdown]
# ## 0.2.14 Practice with NULLs

# %%
# -- List all film titles with missing budgets
cur.execute("""
            
            SELECT title AS no_budget_info 
            FROM films 
            WHERE budget IS NULL;
            
            """).fetchall()
# Out:
# [("Pandora's Box",),
#  ('The Prisoner of Zenda',),
#  ('The Blue Bird',),
#  ('Bambi',),
#  ('State Fair',),
#  ('Open Secret',),
#  ('Deadline - U.S.A.',),
#  ('Ordet',),
#  ("The Party's Over",),
#  ('The Torture Chamber of Dr. Sadism',),
#  ('Charly',),
#  ('Machine Gun McCain',),
#  ('The Night Visitor',),
#  ('The Bad News Bears',),
#  ('The Last Waltz',),
#  ('All That Jazz',),
#  ('The Muppet Movie',),
#  ("Coal Miner's Daughter",),
#  ('Galaxina',),
#  ('The Four Seasons',),
#  ('Butterfly',),
#  ('Gabriela',),
#  ('Trading Places',),
#  ('The Lost Boys',),
#  ('Midnight Cabaret',),
#  ('Howards End',),
#  ("What's Love Got to Do with It",),
#  ('The Inkwell',),
#  ('Bang',),
#  ('The Horseman on the Roof',),
#  ('The Jerky Boys',),
#  ('The Last Big Thing',),
#  ('24 7: Twenty Four Seven',),
#  ('Clockwatchers',),
#  ('DÃ©jÃ  Vu',),
#  ('How to Be a Player',),
#  ("I Love You, Don't Touch Me!",),
#  ('Love and Death on Long Island',),
#  ('Mr. Nice Guy',),
#  ('Sparkler',),
#  ('The Chambermaid on the Titanic',),
#  ('The Edge',),
#  ('Dancer, Texas Pop. 81',),
#  ('Earth',),
#  ('Illuminata',),
#  ('Little Voice',),
#  ('Stiff Upper Lips',),
#  ('The Big Swap',),
#  ('The Land Girls',),
#  ('The Love Letter',),
#  ('The Love Letter',),
#  ('The Mighty',),
#  ('Velvet Goldmine',),
#  ('A Room for Romeo Brass',),
#  ("Felicia's Journey",),
#  ('Ghost Dog: The Way of the Samurai',),
#  ("Trippin'",),
#  ('Dinner Rush',),
#  ('Hum To Mohabbat Karega',),
#  ('Lisa Picard Is Famous',),
#  ('Michael Jordan to the Max',),
#  ('Sexy Beast',),
#  ('The Young Unknowns',),
#  ('Bully',),
#  ('Dogtown and Z-Boys',),
#  ('Knockaround Guys',),
#  ('Madison',),
#  ('The Business of Strangers',),
#  ("The Caveman's Valentine",),
#  ('Ararat',),
#  ('Fabled',),
#  ('Funny Ha Ha',),
#  ('Irreversible',),
#  ('Lilya 4-Ever',),
#  ('Morvern Callar',),
#  ('Sex with Strangers',),
#  ('A Mighty Wind',),
#  ('American Splendor',),
#  ('Chasing Papi',),
#  ('Girl with a Pearl Earring',),
#  ('Grand Theft Parsons',),
#  ('Masked and Anonymous',),
#  ('Nothing',),
#  ('Swimming Pool',),
#  ('The Flower of Evil',),
#  ('The Return',),
#  ('This Thing of Ours',),
#  ('Touching the Void',),
#  ('Tupac: Resurrection',),
#  ('Bobby Jones: Stroke of Genius',),
#  ('Brave New Girl',),
#  ("Breakin' All the Rules",),
#  ('Dear Frankie',),
#  ('Guiana 1838',),
#  ("It's All Gone Pete Tong",),
#  ("My Baby's Daddy",),
#  ('On the Downlow',),
#  ('On the Outs',),
#  ('Riding Giants',),
#  ('Saving Face',),
#  ('The Cookout',),
#  ('The Last Shot',),
#  ('The Libertine',),
#  ('The Prince and Me',),
#  ('What the #$*! Do We (K)now!?',),
#  ('Woman Thou Art Loosed',),
#  ('51 Birch Street',),
#  ('Beauty Shop',),
#  ('Camping sauvage',),
#  ('Ice Princess',),
#  ('Mad Hot Ballroom',),
#  ('Mutual Appreciation',),
#  ('Racing Stripes',),
#  ('Rize',),
#  ('Roll Bounce',),
#  ('Romance & Cigarettes',),
#  ('Shopgirl',),
#  ('Sisters in Law',),
#  ('Supercross',),
#  ('The Californians',),
#  ('The Greatest Game Ever Played',),
#  ('The Motel',),
#  ('The Ring Two',),
#  ('Water',),
#  ('Akeelah and the Bee',),
#  ('An Inconvenient Truth',),
#  ('ATL',),
#  ("Charlotte's Web",),
#  ('Deck the Halls',),
#  ('Driving Lessons',),
#  ('Farce of the Penguins',),
#  ('Garfield 2',),
#  ('Glory Road',),
#  ("Grandma's Boy",),
#  ('Idiocracy',),
#  ('Jackass Number Two',),
#  ('Keeping Up with the Steins',),
#  ('Lake of Fire',),
#  ("Let's Go to Prison",),
#  ('Out of the Blue',),
#  ('Rang De Basanti',),
#  ('Stick It',),
#  ('The Dead Girl',),
#  ('The Naked Ape',),
#  ('The Namesake',),
#  ('The Ultimate Gift',),
#  ('The Wind That Shakes the Barley',),
#  ('Volver',),
#  ('Wordplay',),
#  ('Because I Said So',),
#  ('Blood and Chocolate',),
#  ('Brick Lane',),
#  ('Gandhi, My Father',),
#  ('Hot Rod',),
#  ('How She Move',),
#  ('I Think I Love My Wife',),
#  ('In the Valley of Elah',),
#  ('Jesus People',),
#  ('Music and Lyrics',),
#  ('Namastey London',),
#  ('Run, Fatboy, Run',),
#  ('Shotgun Stories',),
#  ('Snow Angels',),
#  ('Teeth',),
#  ('The Diving Bell and the Butterfly',),
#  ('The Savages',),
#  ('U2 3D',),
#  ('Under the Same Moon',),
#  ('Wild Hogs',),
#  ('Appaloosa',),
#  ('Baghead',),
#  ('Bathory: Countess of Blood',),
#  ('Bronson',),
#  ('CJ7',),
#  ('Definitely, Maybe',),
#  ('Easy Virtue',),
#  ('Eden Lake',),
#  ('Extreme Movie',),
#  ('Food, Inc.',),
#  ('Free Style',),
#  ('Good Dick',),
#  ('Journey to Saturn',),
#  ('Rachel Getting Married',),
#  ('Roadside Romeo',),
#  ('Shine a Light',),
#  ('Soul Men',),
#  ('Standard Operating Procedure',),
#  ('Stargate: The Ark of Truth',),
#  ('Sunday School Musical',),
#  ('The Class',),
#  ('The Poker House',),
#  ('The Sisterhood of the Traveling Pants 2',),
#  ('Train',),
#  ('A Woman, a Gun and a Noodle Shop',),
#  ('A Woman, a Gun and a Noodle Shop',),
#  ('Adam',),
#  ('Adventureland',),
#  ('Ajami',),
#  ('B-Girl',),
#  ('Capitalism: A Love Story',),
#  ('Carriers',),
#  ('Crying with Laughter',),
#  ('Dogtooth',),
#  ('Don McKay',),
#  ('Down for Life',),
#  ('Down Terrace',),
#  ('Exam',),
#  ('Fish Tank',),
#  ('Flying By',),
#  ('Gentlemen Broncos',),
#  ('I Hope They Serve Beer in Hell',),
#  ('Ink',),
#  ('Life During Wartime',),
#  ('Little Nicholas',),
#  ('Madea Goes to Jail',),
#  ("Mao's Last Dancer",),
#  ('My Dog Tulip',),
#  ('Nowhere Boy',),
#  ('Orphan',),
#  ("Perrier's Bounty",),
#  ('Pirate Radio',),
#  ('Rampage',),
#  ('Red Riding: In the Year of Our Lord 1974',),
#  ('Rocket Singh: Salesman of the Year',),
#  ('Stan Helsing',),
#  ('State of Play',),
#  ('The Eclipse',),
#  ('The Exploding Girl',),
#  ('The Girl on the Train',),
#  ('The Goods: Live Hard, Sell Hard',),
#  ('The Janky Promoters',),
#  ('The Loved Ones',),
#  ('The Stepfather',),
#  ('Tidal Wave',),
#  ('Vampire Killers',),
#  ('Wild Grass',),
#  ("World's Greatest Dad",),
#  (3,),
#  ("A Turtle's Tale: Sammy's Adventures",),
#  ('All Good Things',),
#  ('Animals United',),
#  ("Barney's Version",),
#  ('Barry Munday',),
#  ('Biutiful',),
#  ('Blood Done Sign My Name',),
#  ('Centurion',),
#  ('Dinner for Schmucks',),
#  ('Easy Money',),
#  ('For Colored Girls',),
#  ('Four Lions',),
#  ('Get Him to the Greek',),
#  ('Griff the Invisible',),
#  ('Harry Potter and the Deathly Hallows: Part I',),
#  ('Housefull',),
#  ('Inside Job',),
#  ('Just Wright',),
#  ('Loose Cannons',),
#  ('Lottery Ticket',),
#  ("Meek's Cutoff",),
#  ('Mooz-Lum',),
#  ("Mozart's Sister",),
#  ('N-Secure',),
#  ('Please Give',),
#  ('Redemption Road',),
#  ('Standing Ovation',),
#  ('Submarine',),
#  ('The Reef',),
#  ('Tucker and Dale vs Evil',),
#  ('Ultramarines: A Warhammer 40,000 Movie',),
#  ('Welcome to the Rileys',),
#  ('August',),
#  ('Blackthorn',),
#  ('Cedar Rapids',),
#  ('Circumstance',),
#  ('Coriolanus',),
#  ('Damsels in Distress',),
#  ('Dum Maaro Dum',),
#  ('Harry Potter and the Deathly Hallows: Part II',),
#  ('High Road',),
#  ('Higher Ground',),
#  ('Kevin Hart: Laugh at My Pain',),
#  ('Legend of Kung Fu Rabbit',),
#  ('Martha Marcy May Marlene',),
#  ('October Baby',),
#  ('Polisse',),
#  ('Saving Private Perez',),
#  ('Sound of My Voice',),
#  ('The Art of Getting By',),
#  ('The Sitter',),
#  ('We Bought a Zoo',),
#  ('Anna Karenina',),
#  ('Black Rock',),
#  ('Celeste & Jesse Forever',),
#  ('Cirque du Soleil: Worlds Away',),
#  ('Darling Companion',),
#  ('Frances Ha',),
#  ('Good Deeds',),
#  ('Holy Motors',),
#  ('Khiladi 786',),
#  ('Now Is Good',),
#  ('Restless',),
#  ('Shanghai Calling',),
#  ('Stitches',),
#  ('Supercapitalist',),
#  ('Supporting Characters',),
#  ('The Gatekeepers',),
#  ('The Three Stooges',),
#  ('Trade of Innocents',),
#  ('Trouble with the Curve',),
#  ('Vessel',),
#  ('Wanderlust',),
#  ('When the Lights Went Out',),
#  ("Won't Back Down",),
#  ('ABCD (Any Body Can Dance)',),
#  ('All Is Bright',),
#  ('Barfi',),
#  ('Dom Hemingway',),
#  ('Drinking Buddies',),
#  ('Escape from Tomorrow',),
#  ('Firestorm',),
#  ('Grace Unplugged',),
#  ('Green Street 3: Never Back Down',),
#  ('Ida',),
#  ('Metallica Through the Never',),
#  ('My Lucky Star',),
#  ('Out of Inferno',),
#  ('Palo Alto',),
#  ('Plush',),
#  ('Roadside',),
#  ('Signed Sealed Delivered',),
#  ('The Christmas Candle',),
#  ('The Dirties',),
#  ('The Lost Medallion: The Adventures of Billy Stone',),
#  ('Under the Skin',),
#  ('Water & Power',),
#  ('Yeh Jawaani Hai Deewani',),
#  ('Animals',),
#  ('Barbecue',),
#  ('Coming Home',),
#  ('Destiny',),
#  ('Fugly',),
#  ('Good Kill',),
#  ('H.',),
#  ('Hidden Away',),
#  ('I Origins',),
#  ('Listening',),
#  ('Obvious Child',),
#  ('Out of the Dark',),
#  ('Ramanujan',),
#  ('Solitude',),
#  ('The Blue Room',),
#  ('The Calling',),
#  ('The Calling',),
#  ('The Face of an Angel',),
#  ('The Last Five Years',),
#  ('The Skeleton Twins',),
#  ('The Sound and the Shadow',),
#  ('They Came Together',),
#  ('Trash',),
#  ('Abandoned',),
#  ('America Is Still the Place',),
#  ("Animal Kingdom: Let's go Ape",),
#  ('Christmas Eve',),
#  ('Circle',),
#  ('Containment',),
#  ('Eden',),
#  ('Evolution',),
#  ('Exeter',),
#  ('Goddess of Love',),
#  ('Heroes of Dirt',),
#  ('Navy Seals vs. Zombies',),
#  ('Regression',),
#  ('Slow West',),
#  ('Subconscious',),
#  ('The Good Dinosaur',),
#  ('The Looking Glass',),
#  ('The Lovers',),
#  ('The Lovers',),
#  ("A Beginner's Guide to Snuff",),
#  ('Ben-Hur',),
#  ('Cabin Fever',),
#  ('Godzilla Resurgence',),
#  ('Godzilla Resurgence',),
#  ('Indignation',),
#  ('Irreplaceable',),
#  ('Kicks',),
#  ('Our Kind of Traitor',),
#  ('Race',),
#  ('Restoration',),
#  ('The Finest Hours',),
#  ('The Wailing',),
#  ('10,000 B.C.',),
#  ('A Touch of Frost',),
#  ('Anger Management',),
#  ('Animal Kingdom',),
#  ('BrainDead',),
#  ('Carlos',),
#  ('Creature',),
#  ('Del 1 - MÃ¤n som hatar kvinnor',),
#  ('Emma',),
#  ('Fired Up',),
#  ('Get Real',),
#  ('Ghost Hunters',),
#  ('Hit the Floor',),
#  ('In the Heat of the Night',),
#  ('Jesse',),
#  ('Life',),
#  ('Lovesick',),
#  ('Meet the Browns',),
#  ('Nikita',),
#  ('Rogue',),
#  ('Secrets and Lies',),
#  ('The Border',),
#  ('The Company',),
#  ('The Doombolt Chase',),
#  ('The Grand',),
#  ('The Honeymooners',),
#  ('The Messengers',),
#  ('The Missing',),
#  ('The Secret',),
#  ('The Streets of San Francisco',),
#  ('Towering Inferno',),
#  ('Trapped',),
#  ('Twisted',),
#  ('Unforgettable',),
#  ('Unforgotten',),
#  ('Wings',),
#  ('Wolf Creek',),
#  ('Wuthering Heights',),
#  ('Yu-Gi-Oh! Duel Monsters',)]

# %%
# -- Count the number of films we have language data for
cur.execute("""
            
            SELECT COUNT(*) AS count_language_known 
            FROM films 
            WHERE language IS NOT NULL;
            
            """).fetchall()
# Out:
# [(4955,)]

# %%
print('Ok_')
# Out:
# Ok_

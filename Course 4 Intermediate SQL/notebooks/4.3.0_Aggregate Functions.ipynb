# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import pandas as pd
import numpy as np

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import warnings
warnings.filterwarnings("ignore")

# %%
import sys
sys.path.append("../../../") 

from utils.paths import make_dir_line

modality = 'c'
project = 'Intermediate SQL'
data = make_dir_line(modality, project)

raw = data('raw')

# %%
import sqlite3

conn = sqlite3.connect(":memory:")  ## aca se indica el nombre de la db.
cur = conn.cursor()

# %% [markdown]
# # 4.3.0 Aggregate Functions

# %%
conn.executescript(
    """
DROP TABLE IF EXISTS films;

CREATE TABLE films (
    id            INT,
    title         STRING,
    release_year  INT,
    country       STRING,
    duration      INT,
    language      STRING,
    certification STRING,
    gross         DOUBLE,
    budget        DOUBLE
);

DROP TABLE IF EXISTS people;

CREATE TABLE people (
    id        INT,
    name      STRING,
    birthdate STRING,
    deathdate STRING
);

DROP TABLE IF EXISTS reviews;

CREATE TABLE reviews (
    id             INT,
    film_id        INT,
    num_user       INT,
    num_critic     INT,
    imdb_score     DOUBLE,
    num_votes      DOUBLE,
    facebook_likes DOUBLE
);

DROP TABLE IF EXISTS roles;

CREATE TABLE roles (
    id        INT,
    film_id   INT,
    person_id INT,
    role      STRING
);

"""
)
conn.commit()

# %%
df = pd.read_csv(raw / 'films.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','title','release_year','country','duration','language','certification','gross','budget']
films = list(zip(df.id, df.title, df.release_year, df.country, df.duration, df.language, df.certification, df.gross, df.budget))
cur.executemany("INSERT INTO films VALUES  (?,?,?,?,?,?,?,?,?)", films)

# %%
df = pd.read_csv(raw / 'people.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','name','birthdate','deathdate']
people = list(zip(df.id, df.name, df.birthdate, df.deathdate))
cur.executemany("INSERT INTO people VALUES  (?,?,?,?)", people)

# %%
df = pd.read_csv(raw / 'reviews.csv', sep = ',', decimal = '.', header = 0, encoding = 'utf-8')
df.columns = ['id','film_id','num_user','num_critic','imdb_score','num_votes','facebook_likes']
df = df.loc[:,['id','film_id','num_user','num_critic','imdb_score','num_votes','facebook_likes']]
reviews = list(zip(df.id, df.film_id, df.num_user, df.num_critic, df.imdb_score, df.num_votes, df.facebook_likes))
cur.executemany("INSERT INTO reviews VALUES  (?,?,?,?,?,?,?)", reviews)

# %%
df = pd.read_csv(raw / 'roles.csv', sep = ',', decimal = '.', header = None, encoding = 'utf-8')
df.columns = ['id','film_id','person_id','role']
roles = list(zip(df.id, df.film_id, df.person_id, df.role))
cur.executemany("INSERT INTO roles VALUES  (?,?,?,?)", roles)

# %% [markdown]
# ## 4.3.3 Practice with aggregate functions

# %%
# -- Query the sum of film durations
cur.execute("""
            
            SELECT SUM(duration) AS total_duration 
            FROM films;
            
            """).fetchall()
# Out:
# [(534882,)]

# %%
# -- Query the sum of film durations
cur.execute("""
            
            SELECT avg(duration) AS average_duration 
            FROM films;
            
            """).fetchall()
# Out:
# [(107.94793138244198,)]

# %%
# -- Find the latest release_year
cur.execute("""
            
            SELECT MAX(release_year) AS latest_year 
            FROM films;
            
            """).fetchall()
# Out:
# [(2016,)]

# %%
# -- Find the duration of the shortest film
cur.execute("""
            
            SELECT MIN(duration) AS shortest_film 
            FROM films;
            
            """).fetchall()
# Out:
# [(7,)]

# %% [markdown]
# ## 4.3.5 Combining aggregate functions with WHERE

# %%
# -- Calculate the sum of gross from the year 2000 or later
cur.execute("""
            
            SELECT SUM(gross) AS total_gross 
            FROM films 
            WHERE release_year >= 2000;
            
            """).fetchall()
# Out:
# [(150900926358.0,)]

# %%
# -- Calculate the average gross of films that start with A
cur.execute("""
            
            SELECT AVG(gross) AS avg_gross_A 
            FROM films 
            WHERE title LIKE 'A%';
            
            """).fetchall()
# Out:
# [(47893236.42248062,)]

# %%
# -- Calculate the lowest gross film in 1994
cur.execute("""
            
            SELECT MIN(gross) AS lowest_gross 
            FROM films 
            WHERE release_year = 1994;
            
            """).fetchall()
# Out:
# [(125169.0,)]

# %%
# -- Calculate the highest gross film released between 2000-2012
cur.execute("""
            
            SELECT MAX(gross) AS highest_gross 
            FROM films 
            WHERE release_year BETWEEN 2000 AND 2012;
            
            """).fetchall()
# Out:
# [(760505847.0,)]

# %% [markdown]
# ## 4.3.6 Using ROUND()

# %%
# -- Round the average number of facebook_likes to one decimal place
cur.execute("""
            
            SELECT ROUND(AVG(facebook_likes),1) AS avg_facebook_likes 
            FROM reviews;
            
            """).fetchall()
# Out:
# [(7802.9,)]

# %%
# -- Calculate the average budget rounded to the thousands
cur.execute("""
            
            SELECT ROUND(AVG(budget),-3) AS avg_budget_thousands 
            FROM films;
            
            """).fetchall()
# Out:
# [(39902826.0,)]

# %% [markdown]
# ## 4.3.9 Aliasing with functions

# %%
# -- Calculate the title and duration_hours from films
cur.execute("""
            
            SELECT title, (duration/60.0) AS duration_hours 
            FROM films;
            
            """).fetchall()
# Out:
# [("Intolerance: Love's Struggle Throughout the Ages", 2.05),
#  ('Over the Hill to the Poorhouse', 1.8333333333333333),
#  ('The Big Parade', 2.5166666666666666),
#  ('Metropolis', 2.4166666666666665),
#  ("Pandora's Box", 1.8333333333333333),
#  ('The Broadway Melody', 1.6666666666666667),
#  ("Hell's Angels", 1.6),
#  ('A Farewell to Arms', 1.3166666666666667),
#  ('42nd Street', 1.4833333333333334),
#  ('She Done Him Wrong', 1.1),
#  ('It Happened One Night', 1.0833333333333333),
#  ('Top Hat', 1.35),
#  ('Modern Times', 1.45),
#  ('The Charge of the Light Brigade', 1.6666666666666667),
#  ('Snow White and the Seven Dwarfs', 1.3833333333333333),
#  ('The Prisoner of Zenda', 1.6833333333333333),
#  ("Alexander's Ragtime Band", 1.7666666666666666),
#  ("You Can't Take It with You", 2.1),
#  ('Gone with the Wind', 3.7666666666666666),
#  ('Mr. Smith Goes to Washington', 2.0),
#  ('The Wizard of Oz', 1.7),
#  ('Boom Town', 1.9833333333333334),
#  ('Fantasia', 2.0),
#  ('Pinocchio', 1.4666666666666666),
#  ('Rebecca', 2.1666666666666665),
#  ('The Blue Bird', 1.3833333333333333),
#  ('How Green Was My Valley', 1.9666666666666666),
#  ('Bambi', 1.1666666666666667),
#  ('Casablanca', 1.3666666666666667),
#  ('A Guy Named Joe', 2.033333333333333),
#  ('Bathing Beauty', 1.6833333333333333),
#  ('Spellbound', 1.5833333333333333),
#  ('State Fair', 1.6666666666666667),
#  ('The Lost Weekend', 1.6833333333333333),
#  ('The Valley of Decision', 1.9833333333333334),
#  ('Duel in the Sun', 2.4),
#  ("It's a Wonderful Life", 1.9666666666666666),
#  ('The Best Years of Our Lives', 2.8666666666666667),
#  ("Gentleman's Agreement", 1.9666666666666666),
#  ('The Lady from Shanghai', 1.5333333333333334),
#  ('Tycoon', 1.5833333333333333),
#  ('Open Secret', 1.1333333333333333),
#  ('Red River', 2.1),
#  ('The Pirate', 1.7),
#  ('Sands of Iwo Jima', 1.8166666666666667),
#  ('She Wore a Yellow Ribbon', 1.7166666666666666),
#  ('Annie Get Your Gun', 1.7833333333333334),
#  ('A Streetcar Named Desire', 2.0833333333333335),
#  ('Quo Vadis', 2.85),
#  ('Show Boat', 1.8),
#  ('Deadline - U.S.A.', 1.45),
#  ('High Noon', 1.4166666666666667),
#  ("Singin' in the Rain", 1.7166666666666666),
#  ('The Greatest Show on Earth', 2.533333333333333),
#  ('From Here to Eternity', 1.9666666666666666),
#  ('Niagara', 1.5333333333333334),
#  ('The Beast from 20,000 Fathoms', 1.3333333333333333),
#  ('The Robe', 2.25),
#  ('20,000 Leagues Under the Sea', 2.1166666666666667),
#  ('20,000 Leagues Under the Sea', 2.1166666666666667),
#  ('On the Waterfront', 1.8),
#  ('Seven Samurai', 3.3666666666666667),
#  ('The Egyptian', 2.316666666666667),
#  ('Ordet', 2.1),
#  ('The Trouble with Harry', 1.65),
#  ('Love Me Tender', 1.4833333333333334),
#  ('Moby Dick', 1.9166666666666667),
#  ('Trapeze', 1.75),
#  ('12 Angry Men', 1.6),
#  ('The Bridge on the River Kwai', 2.683333333333333),
#  ('Cat on a Hot Tin Roof', 1.8),
#  ('Solomon and Sheba', 2.35),
#  ('Some Like It Hot', 2.0),
#  ("The Nun's Story", 2.4833333333333334),
#  ('Elmer Gantry', 2.433333333333333),
#  ('Psycho', 1.8),
#  ('The Apartment', 2.0833333333333335),
#  ('Judgment at Nuremberg', 3.1),
#  ('Pocketful of Miracles', 2.2666666666666666),
#  ('The Hustler', 2.2333333333333334),
#  ('The Misfits', 2.0),
#  ('West Side Story', 2.533333333333333),
#  ('Dr. No', 1.8333333333333333),
#  ('Lawrence of Arabia', 3.783333333333333),
#  ('Lolita', 2.533333333333333),
#  ('Lolita', 2.533333333333333),
#  ("The Brain That Wouldn't Die", 1.1666666666666667),
#  ('The Longest Day', 2.966666666666667),
#  ('The Man Who Shot Liberty Valance', 1.8833333333333333),
#  ('To Kill a Mockingbird', 2.15),
#  ('55 Days at Peking', 2.566666666666667),
#  ('Cleopatra', 4.183333333333334),
#  ("Donovan's Reef", 1.8166666666666667),
#  ('From Russia with Love', 1.9166666666666667),
#  ('Hud', 1.8666666666666667),
#  ("It's a Mad, Mad, Mad, Mad World", 3.283333333333333),
#  ('The Great Escape', 2.8666666666666667),
#  ('Tom Jones', 2.0166666666666666),
#  ('A Fistful of Dollars', 1.65),
#  ("A Hard Day's Night", 1.45),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   1.5833333333333333),
#  ('Goldfinger', 1.8333333333333333),
#  ('Mary Poppins', 2.316666666666667),
#  ('My Fair Lady', 2.8333333333333335),
#  ('Nothing But a Man', 1.5833333333333333),
#  ('The Fall of the Roman Empire', 2.8666666666666667),
#  ('The Train', 2.216666666666667),
#  ('Une Femme MariÃ©e', 1.5666666666666667),
#  ('Doctor Zhivago', 3.3333333333333335),
#  ('Major Dundee', 2.533333333333333),
#  ('Pierrot le Fou', 1.8333333333333333),
#  ('The Greatest Story Ever Told', 3.75),
#  ("The Party's Over", 1.5666666666666667),
#  ('The Sound of Music', 2.9),
#  ('Thunderball', 2.1666666666666665),
#  ('A Funny Thing Happened on the Way to the Forum', 1.65),
#  ('A Man for All Seasons', 2.0),
#  ('Batman: The Movie', 1.75),
#  ('Harper', 2.0166666666666666),
#  ('The Good, the Bad and the Ugly', 2.3666666666666667),
#  ('Torn Curtain', 2.1333333333333333),
#  ('In Cold Blood', 2.2333333333333334),
#  ('Point Blank', 1.5333333333333334),
#  ('The Torture Chamber of Dr. Sadism', 1.3333333333333333),
#  ('You Only Live Twice', 1.95),
#  ('2001: A Space Odyssey', 2.683333333333333),
#  ('Barbarella', 1.6333333333333333),
#  ('Charly', 1.7166666666666666),
#  ("Hang 'Em High", 1.9),
#  ('Night of the Living Dead', 1.6),
#  ('Night of the Living Dead', 1.6),
#  ('Oliver!', 2.55),
#  ('Once Upon a Time in the West', 2.4166666666666665),
#  ("Rosemary's Baby", 2.2666666666666666),
#  ('Shalako', 1.8833333333333333),
#  ('Yours, Mine and Ours', 1.85),
#  ('Butch Cassidy and the Sundance Kid', 1.8333333333333333),
#  ('Machine Gun McCain', 1.6),
#  ('Midnight Cowboy', 1.8833333333333333),
#  ('Mississippi Mermaid', 2.05),
#  ("On Her Majesty's Secret Service", 2.3666666666666667),
#  ('Paint Your Wagon', 2.6333333333333333),
#  ('Sweet Charity', 2.566666666666667),
#  ('The Stewardesses', 1.55),
#  ('The Wild Bunch', 2.4),
#  ('Topaz', 2.1166666666666667),
#  ('Beneath the Planet of the Apes', 1.5833333333333333),
#  ('Beyond the Valley of the Dolls', 1.8166666666666667),
#  ('Catch-22', 2.033333333333333),
#  ('Cotton Comes to Harlem', 1.6166666666666667),
#  ('Darling Lili', 2.3833333333333333),
#  ('Patton', 2.8666666666666667),
#  ('The Ballad of Cable Hogue', 2.0166666666666666),
#  ('The Conformist', 1.7666666666666666),
#  ('The Molly Maguires', 2.066666666666667),
#  ('Tora! Tora! Tora!', 2.6666666666666665),
#  ('Waterloo', 2.2333333333333334),
#  ('Woodstock', 3.5833333333333335),
#  ('Bananas', 1.3666666666666667),
#  ('Diamonds Are Forever', 2.0),
#  ('Escape from the Planet of the Apes', 1.6333333333333333),
#  ('Fiddler on the Roof', 3.0166666666666666),
#  ('Pink Narcissus', 1.0833333333333333),
#  ("Sweet Sweetback's Baadasssss Song", 1.6166666666666667),
#  ('The Andromeda Strain', 1.9166666666666667),
#  ('The French Connection', 1.7333333333333334),
#  ('The French Connection', 1.7333333333333334),
#  ('The Night Visitor', 1.7666666666666666),
#  ('Willy Wonka & the Chocolate Factory', 1.4833333333333334),
#  (1776, 2.8),
#  ('Conquest of the Planet of the Apes', 1.4666666666666666),
#  ('Cries & Whispers', 1.5166666666666666),
#  ('Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#   1.4666666666666666),
#  ('Frenzy', 1.9333333333333333),
#  ('Pink Flamingos', 1.8),
#  ('Silent Running', 1.4833333333333334),
#  ('Solaris', 1.9166666666666667),
#  ('The Godfather', 2.9166666666666665),
#  ('American Graffiti', 1.8666666666666667),
#  ('Battle for the Planet of the Apes', 1.6),
#  ('High Plains Drifter', 1.75),
#  ('Live and Let Die', 2.0166666666666666),
#  ('Mean Streets', 1.8666666666666667),
#  ('Pat Garrett & Billy the Kid', 1.7666666666666666),
#  ('Sleeper', 1.4833333333333334),
#  ('The Exorcist', 2.2),
#  ('The Sting', 2.15),
#  ('Benji', 1.4333333333333333),
#  ('Blazing Saddles', 1.55),
#  ('The Conversation', 1.8833333333333333),
#  ('The Front Page', 1.75),
#  ('The Godfather: Part II', 3.6666666666666665),
#  ('The Man with the Golden Gun', 2.0833333333333335),
#  ('The Texas Chain Saw Massacre', 1.4666666666666666),
#  ('The Texas Chain Saw Massacre', 1.4666666666666666),
#  ('Young Frankenstein', 1.7666666666666666),
#  ('Barry Lyndon', 3.066666666666667),
#  ('Death Race 2000', 1.3333333333333333),
#  ('Jaws', 2.1666666666666665),
#  ('Monty Python and the Holy Grail', 1.5166666666666666),
#  ("One Flew Over the Cuckoo's Nest", 2.216666666666667),
#  ('The Return of the Pink Panther', 1.8833333333333333),
#  ('Family Plot', 2.0),
#  ("Logan's Run", 1.9833333333333334),
#  ('Network', 2.0166666666666666),
#  ('Robin and Marian', 1.7666666666666666),
#  ('Rocky', 2.4166666666666665),
#  ('Silent Movie', 1.45),
#  ('Taxi Driver', 1.8333333333333333),
#  ('The Bad News Bears', 1.7),
#  ('The Omen', 1.7833333333333334),
#  ('The Omen', 1.7833333333333334),
#  ('A Bridge Too Far', 2.9166666666666665),
#  ('Annie Hall', 1.55),
#  ('Capricorn One', 2.1666666666666665),
#  ('Close Encounters of the Third Kind', 2.25),
#  ('Damnation Alley', 1.5166666666666666),
#  ('Eraserhead', 1.4833333333333334),
#  ('Exorcist II: The Heretic', 1.9666666666666666),
#  ('High Anxiety', 1.5666666666666667),
#  ('Julia', 1.95),
#  ('Kingdom of the Spiders', 1.6166666666666667),
#  ('March or Die', 1.7833333333333334),
#  ('New York, New York', 2.2666666666666666),
#  ('Sorcerer', 1.5333333333333334),
#  ('Star Wars: Episode IV - A New Hope', 2.0833333333333335),
#  ('The Kentucky Fried Movie', 1.3833333333333333),
#  ('The Spy Who Loved Me', 2.05),
#  ('Alien Zone', 1.3166666666666667),
#  ('Animal House', 1.8166666666666667),
#  ('Caravans', 2.1166666666666667),
#  ('Days of Heaven', 1.5666666666666667),
#  ('F.I.S.T.', 2.4166666666666665),
#  ('Force 10 from Navarone', 2.1),
#  ('Grease', 1.8333333333333333),
#  ('Halloween', 1.6833333333333333),
#  ('Halloween', 1.6833333333333333),
#  ('Halloween', 1.6833333333333333),
#  ('Jaws 2', 2.183333333333333),
#  ('Superman', 3.1333333333333333),
#  ('The Boys from Brazil', 2.0833333333333335),
#  ('The Deer Hunter', 3.05),
#  ('The Last Waltz', 1.95),
#  ('The Wiz', 1.9666666666666666),
#  (1941, 2.3666666666666667),
#  ('Alien', 1.9333333333333333),
#  ('All That Jazz', 2.05),
#  ('Apocalypse Now', 4.816666666666666),
#  ('Escape from Alcatraz', 1.8666666666666667),
#  ('Mad Max', 1.55),
#  ('Meteor', 1.8),
#  ('Moonraker', 2.1),
#  ('Penitentiary', 1.65),
#  ('Prophecy', 1.7),
#  ('Star Trek: The Motion Picture', 2.3833333333333333),
#  ('The Black Hole', 1.6333333333333333),
#  ('The Black Stallion', 1.9666666666666666),
#  ('The Great Train Robbery', 1.8333333333333333),
#  ('The Muppet Movie', 1.5833333333333333),
#  ('The Rose', 2.0833333333333335),
#  ('Airplane!', 1.4666666666666666),
#  ('Caddyshack', 1.6333333333333333),
#  ("Can't Stop the Music", 2.066666666666667),
#  ("Coal Miner's Daughter", 2.066666666666667),
#  ('Dressed to Kill', 1.7333333333333334),
#  ('Flash Gordon', 1.85),
#  ('Galaxina', 1.5833333333333333),
#  ("Heaven's Gate", 5.416666666666667),
#  ('Lion of the Desert', 2.6),
#  ('Ordinary People', 2.066666666666667),
#  ('Out of the Blue', 1.5666666666666667),
#  ('Private Benjamin', 1.8166666666666667),
#  ('Raging Bull', 2.0166666666666666),
#  ('Raise the Titanic', 1.9833333333333334),
#  ('Somewhere in Time', 1.7166666666666666),
#  ('Star Wars: Episode V - The Empire Strikes Back', 2.1166666666666667),
#  ('Superman II', 1.9333333333333333),
#  ('The Blue Lagoon', 1.7333333333333334),
#  ('The Blues Brothers', 2.466666666666667),
#  ('The Elephant Man', 2.066666666666667),
#  ('The Fog', 1.4833333333333334),
#  ('The Fog', 1.4833333333333334),
#  ('The Long Riders', 1.6666666666666667),
#  ('The Shining', 2.433333333333333),
#  ('Blow Out', 1.7833333333333334),
#  ('Chariots of Fire', 2.0833333333333335),
#  ('Das Boot', 4.883333333333334),
#  ('Dragonslayer', 1.8),
#  ('Escape from New York', 1.7666666666666666),
#  ('For Your Eyes Only', 2.1166666666666667),
#  ('Friday the 13th Part 2', 1.45),
#  ('Graduation Day', 1.6),
#  ('Heartbeeps', 1.3),
#  ('Heavy Metal', 1.5),
#  ('History of the World: Part I', 1.5333333333333334),
#  ('History of the World: Part I', 1.5333333333333334),
#  ('Inchon', 2.3333333333333335),
#  ('Mad Max 2: The Road Warrior', 1.45),
#  ('Modern Problems', 1.55),
#  ('Mommie Dearest', 2.15),
#  ('Nighthawks', 1.65),
#  ("Porky's", 1.5666666666666667),
#  ('Quest for Fire', 1.6666666666666667),
#  ('Raiders of the Lost Ark', 1.9166666666666667),
#  ('Reds', 3.25),
#  ('Roar', 1.7),
#  ('Sphinx', 1.9666666666666666),
#  ('Stripes', 1.95),
#  ('The Beyond', 1.3666666666666667),
#  ('The Evil Dead', 1.6),
#  ('The Four Seasons', 1.7833333333333334),
#  ('The Howling', 1.5166666666666666),
#  ('The Legend of the Lone Ranger', 1.6333333333333333),
#  ('The Postman Always Rings Twice', 2.033333333333333),
#  ('The Pursuit of D.B. Cooper', 1.6666666666666667),
#  ('Time Bandits', 1.7166666666666666),
#  ('Under the Rainbow', 1.6333333333333333),
#  ('Blade Runner', 1.95),
#  ('Butterfly', 1.8),
#  ('Cat People', 1.55),
#  ('Cat People', 1.55),
#  ('Class of 1984', 1.6333333333333333),
#  ('Conan the Barbarian', 2.15),
#  ('Conan the Barbarian', 2.15),
#  ('Creepshow', 2.1666666666666665),
#  ('Creepshow', 2.1666666666666665),
#  ('Diner', 1.8333333333333333),
#  ('E.T. the Extra-Terrestrial', 2.0),
#  ('Fast Times at Ridgemont High', 1.5),
#  ('Firefox', 2.2666666666666666),
#  ('First Blood', 1.55),
#  ('First Blood', 1.55),
#  ('Friday the 13th Part III', 1.5166666666666666),
#  ('Gandhi', 4.0),
#  ('Halloween III: Season of the Witch', 1.6333333333333333),
#  ('Jekyll and Hyde... Together Again', 1.45),
#  ('Megaforce', 1.65),
#  ('Poltergeist', 2.0),
#  ('Poltergeist', 2.0),
#  ('Star Trek II: The Wrath of Khan', 1.9333333333333333),
#  ('The Ballad of Gregorio Cortez', 1.75),
#  ('The Beastmaster', 1.5),
#  ('The Best Little Whorehouse in Texas', 1.9),
#  ('The Man from Snowy River', 1.7),
#  ('The Thing', 1.8166666666666667),
#  ('The Verdict', 2.15),
#  ('Tootsie', 1.9333333333333333),
#  ('A Christmas Story', 1.5666666666666667),
#  ('Flashdance', 1.5833333333333333),
#  ('Gabriela', 1.65),
#  ('Krull', 1.9333333333333333),
#  ('Lone Wolf McQuade', 1.7833333333333334),
#  ("Losin' It", 1.6666666666666667),
#  ('Love Letters', 1.4666666666666666),
#  ("National Lampoon's Vacation", 1.6333333333333333),
#  ('Never Say Never Again', 2.0166666666666666),
#  ('Octopussy', 2.183333333333333),
#  ('Scarface', 2.3666666666666667),
#  ('Star Wars: Episode VI - Return of the Jedi', 2.2333333333333334),
#  ('Superman III', 2.0833333333333335),
#  ('The Dead Zone', 1.7166666666666666),
#  ('The Outsiders', 1.9),
#  ('The Right Stuff', 3.216666666666667),
#  ('The Wicked Lady', 1.6333333333333333),
#  ('Trading Places', 1.9333333333333333),
#  ('Twilight Zone: The Movie', 1.6833333333333333),
#  ('Videodrome', 1.4833333333333334),
#  ('WarGames', 1.9),
#  ('Yentl', 2.2),
#  ('A Nightmare on Elm Street', 1.6833333333333333),
#  ('A Nightmare on Elm Street', 1.6833333333333333),
#  ('A Passage to India', 2.7333333333333334),
#  ('Amadeus', 3.0),
#  ('Beverly Hills Cop', 1.75),
#  ('Body Double', 1.9),
#  ('C.H.U.D.', 1.6),
#  ('Conan the Destroyer', 1.7166666666666666),
#  ('Dune', 2.95),
#  ('Firestarter', 1.9),
#  ('Footloose', 1.7833333333333334),
#  ('Footloose', 1.7833333333333334),
#  ('Friday the 13th: The Final Chapter', 1.6166666666666667),
#  ('Gremlins', 1.7666666666666666),
#  ('Indiana Jones and the Temple of Doom', 1.9666666666666666),
#  ('Once Upon a Time in America', 4.183333333333334),
#  ('Police Academy', 1.6),
#  ('Red Dawn', 1.9),
#  ('Repo Man', 1.5333333333333334),
#  ('Sheena', 1.95),
#  ('Splash', 1.85),
#  ('Star Trek III: The Search for Spock', 1.75),
#  ('The Bounty', 2.2),
#  ('The Cotton Club', 2.05),
#  ('The Hotel New Hampshire', 1.8166666666666667),
#  ('The Ice Pirates', 1.5166666666666666),
#  ('The Karate Kid', 2.1),
#  ('The Karate Kid', 2.1),
#  ('The NeverEnding Story', 1.5666666666666667),
#  ('The Terminator', 1.7833333333333334),
#  ('The Toxic Avenger', 1.5166666666666666),
#  ("A Nightmare on Elm Street 2: Freddy's Revenge", 1.45),
#  ('A Room with a View', 1.95),
#  ('A View to a Kill', 2.183333333333333),
#  ('Back to the Future', 1.9333333333333333),
#  ('Brazil', 2.3666666666666667),
#  ('Commando', 1.25),
#  ('Day of the Dead', 1.45),
#  ('Day of the Dead', 1.45),
#  ('Def-Con 4', 1.4666666666666666),
#  ('Friday the 13th: A New Beginning', 1.5333333333333334),
#  ('Invasion U.S.A.', 1.7833333333333334),
#  ('Krush Groove', 1.6166666666666667),
#  ('Ladyhawke', 2.0166666666666666),
#  ('Lifeforce', 1.6833333333333333),
#  ('Mad Max Beyond Thunderdome', 1.7833333333333334),
#  ('My Beautiful Laundrette', 1.6166666666666667),
#  ('Out of Africa', 2.683333333333333),
#  ('Pale Rider', 1.9166666666666667),
#  ('Rambo: First Blood Part II', 1.6),
#  ('Red Sonja', 1.4833333333333334),
#  ('Return to Oz', 1.8166666666666667),
#  ('Silverado', 2.216666666666667),
#  ('Subway', 1.6333333333333333),
#  ('The Color Purple', 2.566666666666667),
#  ('The Last Dragon', 1.8166666666666667),
#  ('The Return of the Living Dead', 1.8),
#  ('The Return of the Living Dead', 1.8),
#  ('Witness', 1.8666666666666667),
#  ('Young Sherlock Holmes', 1.8166666666666667),
#  ('9Â½ Weeks', 1.8666666666666667),
#  ('Aliens', 2.566666666666667),
#  ("April Fool's Day", 1.4833333333333334),
#  ('Big Trouble in Little China', 1.65),
#  ('Crocodile Dundee', 1.55),
#  ('Highlander', 1.8333333333333333),
#  ('Howard the Duck', 1.8333333333333333),
#  ('Invaders from Mars', 1.6666666666666667),
#  ('Jason Lives: Friday the 13th Part VI', 1.4333333333333333),
#  ('Legal Eagles', 1.9333333333333333),
#  ('Little Shop of Horrors', 1.7),
#  ('Peggy Sue Got Married', 1.7166666666666666),
#  ('Platoon', 2.0),
#  ("River's Edge", 1.65),
#  ('Salvador', 2.033333333333333),
#  ('Shanghai Surprise', 1.6166666666666667),
#  ("She's Gotta Have It", 1.4666666666666666),
#  ('Stand by Me', 1.4833333333333334),
#  ('Star Trek IV: The Voyage Home', 1.9833333333333334),
#  ('The Clan of the Cave Bear', 1.6333333333333333),
#  ('The Color of Money', 1.9833333333333334),
#  ('The Golden Child', 1.5666666666666667),
#  ('The Texas Chainsaw Massacre 2', 1.6833333333333333),
#  ('The Wraith', 1.55),
#  ('Top Gun', 1.8333333333333333),
#  ('Witchboard', 1.6333333333333333),
#  ('3 Men and a Baby', 1.7),
#  ('A Nightmare on Elm Street 3: Dream Warriors', 1.4666666666666666),
#  ('American Ninja 2: The Confrontation', 1.5),
#  ('Beverly Hills Cop II', 1.6666666666666667),
#  ('Creepshow 2', 1.4166666666666667),
#  ('Cry Freedom', 2.45),
#  ('Evil Dead II', 0.6166666666666667),
#  ('Fatal Attraction', 1.9833333333333334),
#  ('From a Whisper to a Scream', 1.5333333333333334),
#  ('Good Morning, Vietnam', 2.0166666666666666),
#  ('Hellraiser', 1.4333333333333333),
#  ('Hollywood Shuffle', 1.35),
#  ('Ishtar', 1.7833333333333334),
#  ('Jaws: The Revenge', 1.5333333333333334),
#  ('La Bamba', 1.8),
#  ('Malone', 1.5333333333333334),
#  ('Maurice', 2.3333333333333335),
#  ('Predator', 1.7833333333333334),
#  ('Prison', 1.7),
#  ('Radio Days', 1.4666666666666666),
#  ('Spaceballs', 1.6),
#  ('Superman IV: The Quest for Peace', 2.2333333333333334),
#  ('Teen Wolf Too', 1.5833333333333333),
#  ('The Barbarians', 1.45),
#  ('The Brave Little Toaster', 1.5),
#  ('The Last Emperor', 3.65),
#  ('The Living Daylights', 2.1666666666666665),
#  ('The Lost Boys', 1.6166666666666667),
#  ('The Princess Bride', 1.6333333333333333),
#  ('The Running Man', 1.6833333333333333),
#  ('The Untouchables', 1.9833333333333334),
#  ('Wall Street', 2.1),
#  ('A Nightmare on Elm Street 4: The Dream Master', 1.65),
#  ('Action Jackson', 1.6),
#  ('Akira', 2.066666666666667),
#  ('Beetlejuice', 1.5333333333333334),
#  ('Big', 2.1666666666666665),
#  ('Bloodsport', 1.5333333333333334),
#  ('Bright Lights, Big City', 1.7833333333333334),
#  ("Child's Play", 1.45),
#  ('Crocodile Dundee II', 1.8),
#  ('Dangerous Liaisons', 1.9833333333333334),
#  ('Dangerous Liaisons', 1.9833333333333334),
#  ('Die Hard', 2.183333333333333),
#  ('Friday the 13th Part VII: The New Blood', 1.4666666666666666),
#  ('Halloween 4: The Return of Michael Myers', 1.4666666666666666),
#  ('Iguana', 1.6166666666666667),
#  ('Lady in White', 1.9666666666666666),
#  ('Midnight Run', 2.1),
#  ('My Stepmother Is an Alien', 1.75),
#  ('Mystic Pizza', 1.7333333333333334),
#  ('Phantasm II', 1.6166666666666667),
#  ('Poltergeist III', 1.6333333333333333),
#  ('Rain Man', 2.216666666666667),
#  ('Rambo III', 1.45),
#  ('School Daze', 2.0166666666666666),
#  ('Scrooged', 1.6833333333333333),
#  ('Talk Radio', 1.8333333333333333),
#  ('The Land Before Time', 1.15),
#  ('The Last Temptation of Christ', 2.7333333333333334),
#  ('They Live', 1.55),
#  ('Twins', 1.7833333333333334),
#  ('Young Guns', 1.7833333333333334),
#  ('A Nightmare on Elm Street 5: The Dream Child', 1.4833333333333334),
#  ('Back to the Future Part II', 1.8),
#  ('Batman', 2.1),
#  ("Bill & Ted's Excellent Adventure", 1.5),
#  ('Black Rain', 2.0833333333333335),
#  ('Born on the Fourth of July', 2.4166666666666665),
#  ('Dead Poets Society', 2.1333333333333333),
#  ('Do the Right Thing', 2.0),
#  ('Driving Miss Daisy', 1.65),
#  ('Friday the 13th Part VIII: Jason Takes Manhattan', 1.6666666666666667),
#  ('Glory', 2.033333333333333),
#  ('Glory', 2.033333333333333),
#  ('Halloween 5', 1.6),
#  ('Henry V', 2.283333333333333),
#  ('Indiana Jones and the Last Crusade', 2.1166666666666667),
#  ('Licence to Kill', 2.216666666666667),
#  ('Major League', 1.7833333333333334),
#  ('New York Stories', 2.066666666666667),
#  ('Pet Sematary', 1.7166666666666666),
#  ('Road House', 1.9),
#  ('Roger & Me', 1.5166666666666666),
#  ('Sea of Love', 1.8833333333333333),
#  ('Sex, Lies, and Videotape', 1.6666666666666667),
#  ('Star Trek V: The Final Frontier', 1.7833333333333334),
#  ('Tango & Cash', 1.6166666666666667),
#  ('The Abyss', 2.85),
#  ('The Blood of Heroes', 1.5),
#  ('The Toxic Avenger Part II', 1.6),
#  ('Troop Beverly Hills', 1.75),
#  ('UHF', 2.5),
#  ('Warlock', 1.7166666666666666),
#  ("We're No Angels", 1.7666666666666666),
#  ('When Harry Met Sally...', 1.4833333333333334),
#  ('Arachnophobia', 1.7166666666666666),
#  ('Back to the Future Part III', 1.9666666666666666),
#  ("Child's Play 2", 1.2),
#  ('Dances with Wolves', 3.933333333333333),
#  ('Days of Thunder', 1.7833333333333334),
#  ('Dick Tracy', 1.75),
#  ('Die Hard 2', 2.066666666666667),
#  ('Edward Scissorhands', 1.75),
#  ('Flatliners', 1.9166666666666667),
#  ('Ghost', 2.1166666666666667),
#  ('Goodfellas', 2.433333333333333),
#  ('Gremlins 2: The New Batch', 1.7666666666666666),
#  ('Home Alone', 1.7166666666666666),
#  ('Kindergarten Cop', 1.85),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 0.5666666666666667),
#  ('Metropolitan', 1.6333333333333333),
#  ('Midnight Cabaret', 1.5666666666666667),
#  ("Mo' Better Blues", 2.15),
#  ('Predator 2', 1.7166666666666666),
#  ('Pretty Woman', 2.0833333333333335),
#  ('Quigley Down Under', 1.9833333333333334),
#  ('Shipwrecked', 1.5333333333333334),
#  ('Spaced Invaders', 1.6666666666666667),
#  ('The Adventures of Ford Fairlane', 1.7333333333333334),
#  ('The Godfather: Part III', 2.8333333333333335),
#  ('The Hunt for Red October', 2.25),
#  ('Total Recall', 1.8833333333333333),
#  ('Total Recall', 1.8833333333333333),
#  ('Tremors', 1.6),
#  ('Two Evil Eyes', 2.0),
#  ('Beastmaster 2: Through the Portal of Time', 1.7833333333333334),
#  ("Bill & Ted's Bogus Journey", 1.55),
#  ('Boyz n the Hood', 1.8666666666666667),
#  ('Cape Fear', 2.1333333333333333),
#  ('Double Impact', 1.8333333333333333),
#  ('Flight of the Intruder', 1.9166666666666667),
#  ("Freddy's Dead: The Final Nightmare", 1.55),
#  ('Harley Davidson and the Marlboro Man', 1.6333333333333333),
#  ('Hook', 2.3666666666666667),
#  ('House Party 2', 1.5666666666666667),
#  ('Hudson Hawk', 1.6666666666666667),
#  ('JFK', 3.433333333333333),
#  ('Johnny Suede', 1.6166666666666667),
#  ('My Girl', 1.7),
#  ('My Own Private Idaho', 1.7333333333333334),
#  ('Return to the Blue Lagoon', 1.7),
#  ('Robin Hood: Prince of Thieves', 2.5833333333333335),
#  ('Showdown in Little Tokyo', 1.3166666666666667),
#  ('Slacker', 1.6666666666666667),
#  ('Star Trek VI: The Undiscovered Country', 1.8333333333333333),
#  ('Stone Cold', 1.4666666666666666),
#  ('Straight Out of Brooklyn', 1.5166666666666666),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze',
#   1.4666666666666666),
#  ('Terminator 2: Judgment Day', 2.55),
#  ('The Addams Family', 1.65),
#  ('The Doors', 2.3333333333333335),
#  ('The Fisher King', 2.283333333333333),
#  ('The Naked Gun 2Â½: The Smell of Fear', 1.4166666666666667),
#  ('The Prince of Tides', 2.2),
#  ('The Silence of the Lambs', 2.3),
#  ('White Fang', 1.7833333333333334),
#  ('A Few Good Men', 2.3),
#  ('A League of Their Own', 2.1333333333333333),
#  ('Aladdin', 1.5),
#  ('Alien 3', 2.4166666666666665),
#  ('Army of Darkness', 1.4666666666666666),
#  ('Batman Returns', 2.1),
#  ('Boomerang', 1.95),
#  ("Bram Stoker's Dracula", 2.5833333333333335),
#  ('Death Becomes Her', 1.7333333333333334),
#  ('El Mariachi', 1.35),
#  ('Fortress', 1.5833333333333333),
#  ('Glengarry Glen Ross', 1.6666666666666667),
#  ('Hoffa', 2.3333333333333335),
#  ('Home Alone 2: Lost in New York', 2.0),
#  ('Howards End', 2.3333333333333335),
#  ('Lethal Weapon 3', 2.0166666666666666),
#  ('Light Sleeper', 1.7166666666666666),
#  ('Malcolm X', 3.3666666666666667),
#  ('Medicine Man', 1.7666666666666666),
#  ('Memoirs of an Invisible Man', 1.65),
#  ('My Cousin Vinny', 2.0),
#  ('Patriot Games', 1.95),
#  ('Radio Flyer', 1.9),
#  ('Raising Cain', 1.5166666666666666),
#  ('Reservoir Dogs', 1.65),
#  ('Split Second', 1.6),
#  ('The Bodyguard', 2.15),
#  ('The Crying Game', 1.8666666666666667),
#  ('The Last of the Mohicans', 1.95),
#  ('The Lawnmower Man', 2.3333333333333335),
#  ('The Mighty Ducks', 1.6666666666666667),
#  ('The Muppet Christmas Carol', 1.4833333333333334),
#  ('Unforgiven', 2.183333333333333),
#  ("Wayne's World", 1.5666666666666667),
#  ('Airborne', 1.5166666666666666),
#  ('Alive', 2.0),
#  ('Blood In, Blood Out', 5.5),
#  ('Cliffhanger', 2.066666666666667),
#  ('Cool Runnings', 1.6333333333333333),
#  ('Dazed and Confused', 1.7),
#  ('Ed and His Dead Mother', 1.55),
#  ('Excessive Force', 1.45),
#  ('Gettysburg', 4.516666666666667),
#  ('Groundhog Day', 1.6833333333333333),
#  ('Hocus Pocus', 1.6),
#  ('Jason Goes to Hell: The Final Friday', 1.5166666666666666),
#  ('Jurassic Park', 2.1166666666666667),
#  ('Killing Zoe', 1.65),
#  ('Last Action Hero', 2.1666666666666665),
#  ('Les visiteurs', 1.7833333333333334),
#  ('Loaded Weapon 1', 1.4),
#  ('Madadayo', 2.2333333333333334),
#  ('Menace II Society', 1.6166666666666667),
#  ('Mrs. Doubtfire', 2.0833333333333335),
#  ('Much Ado About Nothing', 1.85),
#  ('Nowhere to Run', 1.5666666666666667),
#  ('Only the Strong', 1.65),
#  ('Philadelphia', 2.0833333333333335),
#  ('Poetic Justice', 1.8166666666666667),
#  ('Return of the Living Dead III', 1.6166666666666667),
#  ('RoboCop 3', 1.7333333333333334),
#  ('Romeo Is Bleeding', 1.6666666666666667),
#  ('Ruby in Paradise', 1.9),
#  ("Schindler's List", 3.0833333333333335),
#  ('Shadowlands', 1.9166666666666667),
#  ('Sugar Hill', 2.05),
#  ('Super Mario Bros.', 1.7333333333333334),
#  ('Teenage Mutant Ninja Turtles III', 1.6),
#  ('The Adventures of Huck Finn', 1.8),
#  ('The Age of Innocence', 2.316666666666667),
#  ('The Firm', 2.566666666666667),
#  ('The Fugitive', 2.1666666666666665),
#  ('The Nutcracker', 1.5333333333333334),
#  ('The Pelican Brief', 2.35),
#  ('The Piano', 2.0166666666666666),
#  ('The Princess and the Cobbler', 1.3333333333333333),
#  ('The Remains of the Day', 2.2333333333333334),
#  ('Tombstone', 2.2333333333333334),
#  ('True Romance', 2.0166666666666666),
#  ('Warlock: The Armageddon', 1.6333333333333333),
#  ("What's Eating Gilbert Grape", 1.9666666666666666),
#  ("What's Love Got to Do with It", 1.9666666666666666),
#  ('3 Ninjas Kick Back', 1.55),
#  ('A Low Down Dirty Shame', 1.6666666666666667),
#  ('Ace Ventura: Pet Detective', 1.3),
#  ("Baby's Day Out", 1.65),
#  ('Beverly Hills Cop III', 1.7333333333333334),
#  ('Bullets Over Broadway', 1.6333333333333333),
#  ('Clear and Present Danger', 2.35),
#  ('Clerks', 1.7),
#  ('Crooklyn', 1.9166666666666667),
#  ('Disclosure', 2.1333333333333333),
#  ('Don Juan DeMarco', 1.6166666666666667),
#  ('Dumb & Dumber', 1.8833333333333333),
#  ('Ed Wood', 2.1166666666666667),
#  ('Exotica', 1.7166666666666666),
#  ('Forrest Gump', 2.3666666666666667),
#  ('Four Weddings and a Funeral', 1.95),
#  ('Heavenly Creatures', 1.8),
#  ('Highlander: The Final Dimension', 1.65),
#  ('Hoop Dreams', 2.8333333333333335),
#  ('Interview with the Vampire: The Vampire Chronicles', 2.05),
#  ('Legends of the Fall', 2.216666666666667),
#  ('Little Women', 1.9166666666666667),
#  ('Men of War', 1.2666666666666666),
#  ('Naked Gun 33 1/3: The Final Insult', 1.3833333333333333),
#  ('New Nightmare', 1.7833333333333334),
#  ('On Deadly Ground', 1.6833333333333333),
#  ('PCU', 1.3166666666666667),
#  ('Police Academy: Mission to Moscow', 1.3833333333333333),
#  ('Pulp Fiction', 2.966666666666667),
#  ('Rapa Nui', 1.7833333333333334),
#  ('Renaissance Man', 2.1333333333333333),
#  ('RiÂ¢hie RiÂ¢h', 1.5833333333333333),
#  ('Serial Mom', 1.5833333333333333),
#  ('Speed', 1.9333333333333333),
#  ('Star Trek: Generations', 1.9666666666666666),
#  ('Street Fighter', 1.7),
#  ('The Client', 1.9833333333333334),
#  ('The Crow', 1.6333333333333333),
#  ('The Flintstones', 1.5166666666666666),
#  ('The Hudsucker Proxy', 1.85),
#  ('The Inkwell', 1.8333333333333333),
#  ('The Legend of Drunken Master', 1.7),
#  ('The Lion King', 1.2166666666666666),
#  ('The Mask', 1.9),
#  ('The River Wild', 1.85),
#  ('The Santa Clause', 1.6166666666666667),
#  ('The Shadow', 1.55),
#  ('The Shawshank Redemption', 2.3666666666666667),
#  ('The Specialist', 1.8333333333333333),
#  ('There Goes My Baby', 1.65),
#  ('Timecop', 1.65),
#  ('True Lies', 2.35),
#  ('Wolf', 2.0833333333333335),
#  ('Wyatt Earp', 3.533333333333333),
#  ('Ace Ventura: When Nature Calls', 1.5),
#  ('Apollo 13', 2.3333333333333335),
#  ('Assassins', 2.2),
#  ('Babe', 1.5166666666666666),
#  ('Bad Boys', 1.9833333333333334),
#  ('Bang', 1.6333333333333333),
#  ('Batman Forever', 2.0166666666666666),
#  ('Before Sunrise', 1.75),
#  ('Braveheart', 2.966666666666667),
#  ('Casino', 2.966666666666667),
#  ('Casper', 1.6666666666666667),
#  ('Clueless', 1.6166666666666667),
#  ('Congo', 1.8166666666666667),
#  ('Copycat', 2.05),
#  ('Crimson Tide', 2.05),
#  ('Cutthroat Island', 2.066666666666667),
#  ('Dead Man Walking', 2.033333333333333),
#  ('Desperado', 1.7333333333333334),
#  ('Die Hard with a Vengeance', 2.1333333333333333),
#  ('First Knight', 2.2333333333333334),
#  ('Four Rooms', 1.8333333333333333),
#  ('Friday', 1.6166666666666667),
#  ('Get Shorty', 1.75),
#  ('GoldenEye', 2.1666666666666665),
#  ('Hackers', 1.7833333333333334),
#  ('Halloween: The Curse of Michael Myers', 1.55),
#  ('Home for the Holidays', 1.7166666666666666),
#  ('Jade', 1.7833333333333334),
#  ('Jefferson in Paris', 2.316666666666667),
#  ('Kids', 1.5166666666666666),
#  ('Kiss of Death', 1.6833333333333333),
#  ('Leaving Las Vegas', 1.85),
#  ('Mallrats', 2.05),
#  ('Money Train', 1.75),
#  ('Mortal Kombat', 1.6833333333333333),
#  ("Mr. Holland's Opus", 2.3833333333333333),
#  ('Nixon', 3.533333333333333),
#  ('Outbreak', 2.1166666666666667),
#  ('Pocahontas', 1.4),
#  ('Richard III', 1.7333333333333334),
#  ('Rob Roy', 2.316666666666667),
#  ('Rumble in the Bronx', 1.4833333333333334),
#  ('Se7en', 2.1166666666666667),
#  ('Sense and Sensibility', 2.2666666666666666),
#  ('Showgirls', 2.183333333333333),
#  ('Species', 1.8),
#  ('Tales from the Crypt: Demon Knight', 1.5333333333333334),
#  ('Tales from the Hood', 1.6333333333333333),
#  ('Tank Girl', 1.7333333333333334),
#  ('The American President', 1.9),
#  ('The Bridges of Madison County', 2.25),
#  ('The Brothers McMullen', 1.6333333333333333),
#  ('The Horseman on the Roof', 2.25),
#  ('The Incredibly True Adventure of Two Girls in Love', 1.5666666666666667),
#  ('The Indian in the Cupboard', 1.6),
#  ('The Jerky Boys', 1.3666666666666667),
#  ('The Net', 1.9),
#  ('The Perez Family', 1.8833333333333333),
#  ('The Prophecy', 1.6333333333333333),
#  ('The Quick and the Dead', 1.7833333333333334),
#  ('The Scarlet Letter', 2.25),
#  ('The Usual Suspects', 1.7666666666666666),
#  ("Things to Do in Denver When You're Dead", 1.9166666666666667),
#  ('To Die For', 1.7666666666666666),
#  ('Toy Story', 1.2333333333333334),
#  ('Under Siege 2: Dark Territory', 1.5333333333333334),
#  ('Vampire in Brooklyn', 1.6666666666666667),
#  ('Virtuosity', 1.7666666666666666),
#  ('Waterworld', 2.933333333333333),
#  ('Welcome to the Dollhouse', 1.4666666666666666),
#  ('A Thin Line Between Love and Hate', 1.8),
#  ('A Time to Kill', 2.4833333333333334),
#  ('Albino Alligator', 1.6166666666666667),
#  ('Basquiat', 1.8),
#  ('Beavis and Butt-Head Do America', 1.35),
#  ('Blood and Wine', 1.6833333333333333),
#  ('Bogus', 1.8333333333333333),
#  ('Bottle Rocket', 1.5166666666666666),
#  ('Bound', 1.8166666666666667),
#  ('Broken Arrow', 1.8),
#  ('Chain Reaction', 1.7833333333333334),
#  ('City Hall', 1.85),
#  ('Courage Under Fire', 1.9333333333333333),
#  ('Daylight', 1.9),
#  ('DragonHeart', 1.7166666666666666),
#  ('Eraser', 1.9166666666666667),
#  ('Escape from L.A.', 1.6833333333333333),
#  ('Everyone Says I Love You', 1.6833333333333333),
#  ('Evita', 2.25),
#  ('Executive Decision', 2.216666666666667),
#  ('Extreme Measures', 1.9666666666666666),
#  ('Eye for an Eye', 1.6833333333333333),
#  ('Faithful', 1.5166666666666666),
#  ('Fled', 1.75),
#  ('Flipper', 1.5833333333333333),
#  ('Flirting with Disaster', 1.5333333333333334),
#  ('Freeway', 1.7),
#  ('From Dusk Till Dawn', 1.8),
#  ('Get on the Bus', 2.0),
#  ('Ghosts of Mississippi', 2.1666666666666665),
#  ('Girl 6', 1.8),
#  ('Hamlet', 2.5),
#  ('Hamlet', 2.5),
#  ('Happy Gilmore', 1.5333333333333334),
#  ('Harriet the Spy', 1.6666666666666667),
#  ('Independence Day', 2.566666666666667),
#  ('Jerry Maguire', 2.316666666666667),
#  ('Jingle All the Way', 1.5666666666666667),
#  ('Kama Sutra: A Tale of Love', 1.8166666666666667),
#  ('Kansas City', 1.9333333333333333),
#  ('Kingpin', 1.95),
#  ('Lone Star', 2.25),
#  ('Love and Other Catastrophes', 1.2666666666666666),
#  ('Mars Attacks!', 1.7666666666666666),
#  ("Marvin's Room", 1.6333333333333333),
#  ('Mary Reilly', 1.8),
#  ('Maximum Risk', 1.6833333333333333),
#  ('Michael Collins', 2.216666666666667),
#  ('Mission: Impossible', 1.8333333333333333),
#  ('Mrs. Winterbourne', 1.75),
#  ('Multiplicity', 1.95),
#  ('My Fellow Americans', 1.6833333333333333),
#  ('Phenomenon', 2.05),
#  ('Ransom', 2.316666666666667),
#  ('Romeo + Juliet', 2.0),
#  ('Scream', 1.7166666666666666),
#  ('Set It Off', 2.05),
#  ('Sgt. Bilko', 1.55),
#  ("She's the One", 1.6),
#  ('Shine', 1.75),
#  ('Silent Trigger', 1.4666666666666666),
#  ('Sleepers', 2.45),
#  ('Sling Blade', 2.466666666666667),
#  ('Space Jam', 1.4666666666666666),
#  ('Spy Hard', 1.35),
#  ('Star Trek: First Contact', 1.85),
#  ('Striptease', 1.95),
#  ('Swingers', 1.6),
#  ('That Thing You Do!', 2.4833333333333334),
#  ('The Adventures of Pinocchio', 1.5),
#  ('The Cable Guy', 1.6),
#  ('The Craft', 1.6833333333333333),
#  ('The Dress', 1.5833333333333333),
#  ('The English Patient', 2.7),
#  ('The Fan', 1.9333333333333333),
#  ('The First Wives Club', 1.7166666666666666),
#  ('The Funeral', 1.65),
#  ('The Ghost and the Darkness', 1.8333333333333333),
#  ('The Glimmer Man', 1.5166666666666666),
#  ('The Hunchback of Notre Dame', 1.5166666666666666),
#  ('The Island of Dr. Moreau', 1.65),
#  ('The Juror', 1.9666666666666666),
#  ('The Last Big Thing', 1.6333333333333333),
#  ('The Long Kiss Goodnight', 2.0166666666666666),
#  ('The Mirror Has Two Faces', 2.033333333333333),
#  ('The Nutty Professor', 1.5833333333333333),
#  ('The Pallbearer', 1.6333333333333333),
#  ('The Phantom', 1.6666666666666667),
#  ('The Rock', 2.2666666666666666),
#  ('Thinner', 1.55),
#  ('Tin Cup', 2.25),
#  ('Trainspotting', 1.5666666666666667),
#  ('Trees Lounge', 1.5833333333333333),
#  ('Twister', 1.8833333333333333),
#  ('Up Close & Personal', 2.066666666666667),
#  ('Waiting for Guffman', 1.4),
#  ('Walking and Talking', 1.4333333333333333),
#  ("When the Cat's Away", 1.5166666666666666),
#  ('White Squall', 2.15),
#  ('24 7: Twenty Four Seven', 1.6),
#  ('8 Heads in a Duffel Bag', 1.5833333333333333),
#  ('A Simple Wish', 1.4833333333333334),
#  ('Absolute Power', 2.0166666666666666),
#  ('Air Bud', 1.6333333333333333),
#  ('Air Force One', 2.066666666666667),
#  ('Alien: Resurrection', 1.9333333333333333),
#  ('Amistad', 2.5833333333333335),
#  ('An Alan Smithee Film: Burn Hollywood Burn', 1.4333333333333333),
#  ('Anaconda', 1.4833333333333334),
#  ('Anastasia', 1.5666666666666667),
#  ('As Good as It Gets', 2.316666666666667),
#  ('Austin Powers: International Man of Mystery', 1.1333333333333333),
#  ('Batman & Robin', 2.0833333333333335),
#  ('Boogie Nights', 2.5833333333333335),
#  ('Breakdown', 1.55),
#  ("Cats Don't Dance", 1.25),
#  ('Character', 2.033333333333333),
#  ('Chasing Amy', 1.8833333333333333),
#  ('Children of Heaven', 1.4833333333333334),
#  ('Clockwatchers', 1.6),
#  ('Con Air', 2.05),
#  ('Conspiracy Theory', 2.25),
#  ('Contact', 2.5),
#  ('Cop Land', 2.0),
#  ('Critical Care', 1.7833333333333334),
#  ('Cube', 1.5),
#  ("Dante's Peak", 1.8),
#  ('Deconstructing Harry', 1.6),
#  ('DÃ©jÃ  Vu', 1.95),
#  ('Donnie Brasco', 2.45),
#  ('Dream with the Fishes', 1.6166666666666667),
#  ("Eve's Bayou", 1.8166666666666667),
#  ('Event Horizon', 2.1666666666666665),
#  ('Face/Off', 2.3),
#  ('First Love, Last Rites', 1.5666666666666667),
#  ('Flubber', 1.5),
#  ('G.I. Jane', 2.0833333333333335),
#  ('Gattaca', 1.7666666666666666),
#  ('George of the Jungle', 1.5333333333333334),
#  ('Good Will Hunting', 2.1),
#  ('Grosse Pointe Blank', 1.7833333333333334),
#  ('Hav Plenty', 1.4),
#  ('How to Be a Player', 1.55),
#  ('Hurricane Streets', 1.4333333333333333),
#  ('I Know What You Did Last Summer', 1.65),
#  ("I Love You, Don't Touch Me!", 1.4333333333333333),
#  ('I Married a Strange Person!', 1.25),
#  ('In & Out', 1.5),
#  ('In the Company of Men', 1.6166666666666667),
#  ('Jackie Brown', 2.566666666666667),
#  ('Kiss the Girls', 1.9166666666666667),
#  ('Kundun', 2.2333333333333334),
#  ('L.A. Confidential', 2.3),
#  ('Liar Liar', 1.4333333333333333),
#  ('Love and Death on Long Island', 1.55),
#  ('Love Jones', 1.7333333333333334),
#  ('Mad City', 1.9166666666666667),
#  ('Men in Black', 1.6333333333333333),
#  ('Midnight in the Garden of Good and Evil', 2.5833333333333335),
#  ('Money Talks', 1.6166666666666667),
#  ('Mortal Kombat: Annihilation', 1.5833333333333333),
#  ('Mr. Nice Guy', 1.4333333333333333),
#  ("My Best Friend's Wedding", 1.75),
#  ('Nothing to Lose', 1.6333333333333333),
#  ('Orgazmo', 1.5333333333333334),
#  ('Oscar and Lucinda', 2.2),
#  ('Prefontaine', 1.7666666666666666),
#  ('Princess Mononoke', 2.2333333333333334),
#  ('Scream 2', 2.0),
#  ('Selena', 2.1166666666666667),
#  ('Seven Years in Tibet', 2.2666666666666666),
#  ('Shadow Conspiracy', 1.7166666666666666),
#  ('Shooting Fish', 1.65),
#  ("Smilla's Sense of Snow", 2.0166666666666666),
#  ('Snow White: A Tale of Terror', 1.6666666666666667),
#  ('Soul Food', 1.9166666666666667),
#  ('Sparkler', 1.5),
#  ('Spawn', 1.6333333333333333),
#  ('Speed 2: Cruise Control', 2.0166666666666666),
#  ('Spice World', 1.55),
#  ('Starship Troopers', 2.15),
#  ('Steel', 1.6166666666666667),
#  ...]

# %%
# -- Calculate the percentage of people who are no longer alive
cur.execute("""
            
            SELECT COUNT(deathdate) * 100.0 / COUNT(*) AS percentage_dead 
            FROM people;
            
            """).fetchall()
# Out:
# [(9.372394902941526,)]

# %%
# -- Find the number of decades in the films table
cur.execute("""
            
            SELECT (MAX(release_year) - MIN(release_year)) / 10.0 AS number_of_decades 
            FROM films;
            
            """).fetchall()
# Out:
# [(10.0,)]

# %% [markdown]
# ## 4.3.10 Rounding results

# %%
# -- Round duration_hours to two decimal places
cur.execute("""
            
            SELECT title, ROUND(duration / 60.0,2) AS duration_hours 
            FROM films;
            
            """).fetchall()
# Out:
# [("Intolerance: Love's Struggle Throughout the Ages", 2.05),
#  ('Over the Hill to the Poorhouse', 1.83),
#  ('The Big Parade', 2.52),
#  ('Metropolis', 2.42),
#  ("Pandora's Box", 1.83),
#  ('The Broadway Melody', 1.67),
#  ("Hell's Angels", 1.6),
#  ('A Farewell to Arms', 1.32),
#  ('42nd Street', 1.48),
#  ('She Done Him Wrong', 1.1),
#  ('It Happened One Night', 1.08),
#  ('Top Hat', 1.35),
#  ('Modern Times', 1.45),
#  ('The Charge of the Light Brigade', 1.67),
#  ('Snow White and the Seven Dwarfs', 1.38),
#  ('The Prisoner of Zenda', 1.68),
#  ("Alexander's Ragtime Band", 1.77),
#  ("You Can't Take It with You", 2.1),
#  ('Gone with the Wind', 3.77),
#  ('Mr. Smith Goes to Washington', 2.0),
#  ('The Wizard of Oz', 1.7),
#  ('Boom Town', 1.98),
#  ('Fantasia', 2.0),
#  ('Pinocchio', 1.47),
#  ('Rebecca', 2.17),
#  ('The Blue Bird', 1.38),
#  ('How Green Was My Valley', 1.97),
#  ('Bambi', 1.17),
#  ('Casablanca', 1.37),
#  ('A Guy Named Joe', 2.03),
#  ('Bathing Beauty', 1.68),
#  ('Spellbound', 1.58),
#  ('State Fair', 1.67),
#  ('The Lost Weekend', 1.68),
#  ('The Valley of Decision', 1.98),
#  ('Duel in the Sun', 2.4),
#  ("It's a Wonderful Life", 1.97),
#  ('The Best Years of Our Lives', 2.87),
#  ("Gentleman's Agreement", 1.97),
#  ('The Lady from Shanghai', 1.53),
#  ('Tycoon', 1.58),
#  ('Open Secret', 1.13),
#  ('Red River', 2.1),
#  ('The Pirate', 1.7),
#  ('Sands of Iwo Jima', 1.82),
#  ('She Wore a Yellow Ribbon', 1.72),
#  ('Annie Get Your Gun', 1.78),
#  ('A Streetcar Named Desire', 2.08),
#  ('Quo Vadis', 2.85),
#  ('Show Boat', 1.8),
#  ('Deadline - U.S.A.', 1.45),
#  ('High Noon', 1.42),
#  ("Singin' in the Rain", 1.72),
#  ('The Greatest Show on Earth', 2.53),
#  ('From Here to Eternity', 1.97),
#  ('Niagara', 1.53),
#  ('The Beast from 20,000 Fathoms', 1.33),
#  ('The Robe', 2.25),
#  ('20,000 Leagues Under the Sea', 2.12),
#  ('20,000 Leagues Under the Sea', 2.12),
#  ('On the Waterfront', 1.8),
#  ('Seven Samurai', 3.37),
#  ('The Egyptian', 2.32),
#  ('Ordet', 2.1),
#  ('The Trouble with Harry', 1.65),
#  ('Love Me Tender', 1.48),
#  ('Moby Dick', 1.92),
#  ('Trapeze', 1.75),
#  ('12 Angry Men', 1.6),
#  ('The Bridge on the River Kwai', 2.68),
#  ('Cat on a Hot Tin Roof', 1.8),
#  ('Solomon and Sheba', 2.35),
#  ('Some Like It Hot', 2.0),
#  ("The Nun's Story", 2.48),
#  ('Elmer Gantry', 2.43),
#  ('Psycho', 1.8),
#  ('The Apartment', 2.08),
#  ('Judgment at Nuremberg', 3.1),
#  ('Pocketful of Miracles', 2.27),
#  ('The Hustler', 2.23),
#  ('The Misfits', 2.0),
#  ('West Side Story', 2.53),
#  ('Dr. No', 1.83),
#  ('Lawrence of Arabia', 3.78),
#  ('Lolita', 2.53),
#  ('Lolita', 2.53),
#  ("The Brain That Wouldn't Die", 1.17),
#  ('The Longest Day', 2.97),
#  ('The Man Who Shot Liberty Valance', 1.88),
#  ('To Kill a Mockingbird', 2.15),
#  ('55 Days at Peking', 2.57),
#  ('Cleopatra', 4.18),
#  ("Donovan's Reef", 1.82),
#  ('From Russia with Love', 1.92),
#  ('Hud', 1.87),
#  ("It's a Mad, Mad, Mad, Mad World", 3.28),
#  ('The Great Escape', 2.87),
#  ('Tom Jones', 2.02),
#  ('A Fistful of Dollars', 1.65),
#  ("A Hard Day's Night", 1.45),
#  ('Dr. Strangelove or: How I Learned to Stop Worrying and Love the Bomb',
#   1.58),
#  ('Goldfinger', 1.83),
#  ('Mary Poppins', 2.32),
#  ('My Fair Lady', 2.83),
#  ('Nothing But a Man', 1.58),
#  ('The Fall of the Roman Empire', 2.87),
#  ('The Train', 2.22),
#  ('Une Femme MariÃ©e', 1.57),
#  ('Doctor Zhivago', 3.33),
#  ('Major Dundee', 2.53),
#  ('Pierrot le Fou', 1.83),
#  ('The Greatest Story Ever Told', 3.75),
#  ("The Party's Over", 1.57),
#  ('The Sound of Music', 2.9),
#  ('Thunderball', 2.17),
#  ('A Funny Thing Happened on the Way to the Forum', 1.65),
#  ('A Man for All Seasons', 2.0),
#  ('Batman: The Movie', 1.75),
#  ('Harper', 2.02),
#  ('The Good, the Bad and the Ugly', 2.37),
#  ('Torn Curtain', 2.13),
#  ('In Cold Blood', 2.23),
#  ('Point Blank', 1.53),
#  ('The Torture Chamber of Dr. Sadism', 1.33),
#  ('You Only Live Twice', 1.95),
#  ('2001: A Space Odyssey', 2.68),
#  ('Barbarella', 1.63),
#  ('Charly', 1.72),
#  ("Hang 'Em High", 1.9),
#  ('Night of the Living Dead', 1.6),
#  ('Night of the Living Dead', 1.6),
#  ('Oliver!', 2.55),
#  ('Once Upon a Time in the West', 2.42),
#  ("Rosemary's Baby", 2.27),
#  ('Shalako', 1.88),
#  ('Yours, Mine and Ours', 1.85),
#  ('Butch Cassidy and the Sundance Kid', 1.83),
#  ('Machine Gun McCain', 1.6),
#  ('Midnight Cowboy', 1.88),
#  ('Mississippi Mermaid', 2.05),
#  ("On Her Majesty's Secret Service", 2.37),
#  ('Paint Your Wagon', 2.63),
#  ('Sweet Charity', 2.57),
#  ('The Stewardesses', 1.55),
#  ('The Wild Bunch', 2.4),
#  ('Topaz', 2.12),
#  ('Beneath the Planet of the Apes', 1.58),
#  ('Beyond the Valley of the Dolls', 1.82),
#  ('Catch-22', 2.03),
#  ('Cotton Comes to Harlem', 1.62),
#  ('Darling Lili', 2.38),
#  ('Patton', 2.87),
#  ('The Ballad of Cable Hogue', 2.02),
#  ('The Conformist', 1.77),
#  ('The Molly Maguires', 2.07),
#  ('Tora! Tora! Tora!', 2.67),
#  ('Waterloo', 2.23),
#  ('Woodstock', 3.58),
#  ('Bananas', 1.37),
#  ('Diamonds Are Forever', 2.0),
#  ('Escape from the Planet of the Apes', 1.63),
#  ('Fiddler on the Roof', 3.02),
#  ('Pink Narcissus', 1.08),
#  ("Sweet Sweetback's Baadasssss Song", 1.62),
#  ('The Andromeda Strain', 1.92),
#  ('The French Connection', 1.73),
#  ('The French Connection', 1.73),
#  ('The Night Visitor', 1.77),
#  ('Willy Wonka & the Chocolate Factory', 1.48),
#  (1776, 2.8),
#  ('Conquest of the Planet of the Apes', 1.47),
#  ('Cries & Whispers', 1.52),
#  ('Everything You Always Wanted to Know About Sex * But Were Afraid to Ask',
#   1.47),
#  ('Frenzy', 1.93),
#  ('Pink Flamingos', 1.8),
#  ('Silent Running', 1.48),
#  ('Solaris', 1.92),
#  ('The Godfather', 2.92),
#  ('American Graffiti', 1.87),
#  ('Battle for the Planet of the Apes', 1.6),
#  ('High Plains Drifter', 1.75),
#  ('Live and Let Die', 2.02),
#  ('Mean Streets', 1.87),
#  ('Pat Garrett & Billy the Kid', 1.77),
#  ('Sleeper', 1.48),
#  ('The Exorcist', 2.2),
#  ('The Sting', 2.15),
#  ('Benji', 1.43),
#  ('Blazing Saddles', 1.55),
#  ('The Conversation', 1.88),
#  ('The Front Page', 1.75),
#  ('The Godfather: Part II', 3.67),
#  ('The Man with the Golden Gun', 2.08),
#  ('The Texas Chain Saw Massacre', 1.47),
#  ('The Texas Chain Saw Massacre', 1.47),
#  ('Young Frankenstein', 1.77),
#  ('Barry Lyndon', 3.07),
#  ('Death Race 2000', 1.33),
#  ('Jaws', 2.17),
#  ('Monty Python and the Holy Grail', 1.52),
#  ("One Flew Over the Cuckoo's Nest", 2.22),
#  ('The Return of the Pink Panther', 1.88),
#  ('Family Plot', 2.0),
#  ("Logan's Run", 1.98),
#  ('Network', 2.02),
#  ('Robin and Marian', 1.77),
#  ('Rocky', 2.42),
#  ('Silent Movie', 1.45),
#  ('Taxi Driver', 1.83),
#  ('The Bad News Bears', 1.7),
#  ('The Omen', 1.78),
#  ('The Omen', 1.78),
#  ('A Bridge Too Far', 2.92),
#  ('Annie Hall', 1.55),
#  ('Capricorn One', 2.17),
#  ('Close Encounters of the Third Kind', 2.25),
#  ('Damnation Alley', 1.52),
#  ('Eraserhead', 1.48),
#  ('Exorcist II: The Heretic', 1.97),
#  ('High Anxiety', 1.57),
#  ('Julia', 1.95),
#  ('Kingdom of the Spiders', 1.62),
#  ('March or Die', 1.78),
#  ('New York, New York', 2.27),
#  ('Sorcerer', 1.53),
#  ('Star Wars: Episode IV - A New Hope', 2.08),
#  ('The Kentucky Fried Movie', 1.38),
#  ('The Spy Who Loved Me', 2.05),
#  ('Alien Zone', 1.32),
#  ('Animal House', 1.82),
#  ('Caravans', 2.12),
#  ('Days of Heaven', 1.57),
#  ('F.I.S.T.', 2.42),
#  ('Force 10 from Navarone', 2.1),
#  ('Grease', 1.83),
#  ('Halloween', 1.68),
#  ('Halloween', 1.68),
#  ('Halloween', 1.68),
#  ('Jaws 2', 2.18),
#  ('Superman', 3.13),
#  ('The Boys from Brazil', 2.08),
#  ('The Deer Hunter', 3.05),
#  ('The Last Waltz', 1.95),
#  ('The Wiz', 1.97),
#  (1941, 2.37),
#  ('Alien', 1.93),
#  ('All That Jazz', 2.05),
#  ('Apocalypse Now', 4.82),
#  ('Escape from Alcatraz', 1.87),
#  ('Mad Max', 1.55),
#  ('Meteor', 1.8),
#  ('Moonraker', 2.1),
#  ('Penitentiary', 1.65),
#  ('Prophecy', 1.7),
#  ('Star Trek: The Motion Picture', 2.38),
#  ('The Black Hole', 1.63),
#  ('The Black Stallion', 1.97),
#  ('The Great Train Robbery', 1.83),
#  ('The Muppet Movie', 1.58),
#  ('The Rose', 2.08),
#  ('Airplane!', 1.47),
#  ('Caddyshack', 1.63),
#  ("Can't Stop the Music", 2.07),
#  ("Coal Miner's Daughter", 2.07),
#  ('Dressed to Kill', 1.73),
#  ('Flash Gordon', 1.85),
#  ('Galaxina', 1.58),
#  ("Heaven's Gate", 5.42),
#  ('Lion of the Desert', 2.6),
#  ('Ordinary People', 2.07),
#  ('Out of the Blue', 1.57),
#  ('Private Benjamin', 1.82),
#  ('Raging Bull', 2.02),
#  ('Raise the Titanic', 1.98),
#  ('Somewhere in Time', 1.72),
#  ('Star Wars: Episode V - The Empire Strikes Back', 2.12),
#  ('Superman II', 1.93),
#  ('The Blue Lagoon', 1.73),
#  ('The Blues Brothers', 2.47),
#  ('The Elephant Man', 2.07),
#  ('The Fog', 1.48),
#  ('The Fog', 1.48),
#  ('The Long Riders', 1.67),
#  ('The Shining', 2.43),
#  ('Blow Out', 1.78),
#  ('Chariots of Fire', 2.08),
#  ('Das Boot', 4.88),
#  ('Dragonslayer', 1.8),
#  ('Escape from New York', 1.77),
#  ('For Your Eyes Only', 2.12),
#  ('Friday the 13th Part 2', 1.45),
#  ('Graduation Day', 1.6),
#  ('Heartbeeps', 1.3),
#  ('Heavy Metal', 1.5),
#  ('History of the World: Part I', 1.53),
#  ('History of the World: Part I', 1.53),
#  ('Inchon', 2.33),
#  ('Mad Max 2: The Road Warrior', 1.45),
#  ('Modern Problems', 1.55),
#  ('Mommie Dearest', 2.15),
#  ('Nighthawks', 1.65),
#  ("Porky's", 1.57),
#  ('Quest for Fire', 1.67),
#  ('Raiders of the Lost Ark', 1.92),
#  ('Reds', 3.25),
#  ('Roar', 1.7),
#  ('Sphinx', 1.97),
#  ('Stripes', 1.95),
#  ('The Beyond', 1.37),
#  ('The Evil Dead', 1.6),
#  ('The Four Seasons', 1.78),
#  ('The Howling', 1.52),
#  ('The Legend of the Lone Ranger', 1.63),
#  ('The Postman Always Rings Twice', 2.03),
#  ('The Pursuit of D.B. Cooper', 1.67),
#  ('Time Bandits', 1.72),
#  ('Under the Rainbow', 1.63),
#  ('Blade Runner', 1.95),
#  ('Butterfly', 1.8),
#  ('Cat People', 1.55),
#  ('Cat People', 1.55),
#  ('Class of 1984', 1.63),
#  ('Conan the Barbarian', 2.15),
#  ('Conan the Barbarian', 2.15),
#  ('Creepshow', 2.17),
#  ('Creepshow', 2.17),
#  ('Diner', 1.83),
#  ('E.T. the Extra-Terrestrial', 2.0),
#  ('Fast Times at Ridgemont High', 1.5),
#  ('Firefox', 2.27),
#  ('First Blood', 1.55),
#  ('First Blood', 1.55),
#  ('Friday the 13th Part III', 1.52),
#  ('Gandhi', 4.0),
#  ('Halloween III: Season of the Witch', 1.63),
#  ('Jekyll and Hyde... Together Again', 1.45),
#  ('Megaforce', 1.65),
#  ('Poltergeist', 2.0),
#  ('Poltergeist', 2.0),
#  ('Star Trek II: The Wrath of Khan', 1.93),
#  ('The Ballad of Gregorio Cortez', 1.75),
#  ('The Beastmaster', 1.5),
#  ('The Best Little Whorehouse in Texas', 1.9),
#  ('The Man from Snowy River', 1.7),
#  ('The Thing', 1.82),
#  ('The Verdict', 2.15),
#  ('Tootsie', 1.93),
#  ('A Christmas Story', 1.57),
#  ('Flashdance', 1.58),
#  ('Gabriela', 1.65),
#  ('Krull', 1.93),
#  ('Lone Wolf McQuade', 1.78),
#  ("Losin' It", 1.67),
#  ('Love Letters', 1.47),
#  ("National Lampoon's Vacation", 1.63),
#  ('Never Say Never Again', 2.02),
#  ('Octopussy', 2.18),
#  ('Scarface', 2.37),
#  ('Star Wars: Episode VI - Return of the Jedi', 2.23),
#  ('Superman III', 2.08),
#  ('The Dead Zone', 1.72),
#  ('The Outsiders', 1.9),
#  ('The Right Stuff', 3.22),
#  ('The Wicked Lady', 1.63),
#  ('Trading Places', 1.93),
#  ('Twilight Zone: The Movie', 1.68),
#  ('Videodrome', 1.48),
#  ('WarGames', 1.9),
#  ('Yentl', 2.2),
#  ('A Nightmare on Elm Street', 1.68),
#  ('A Nightmare on Elm Street', 1.68),
#  ('A Passage to India', 2.73),
#  ('Amadeus', 3.0),
#  ('Beverly Hills Cop', 1.75),
#  ('Body Double', 1.9),
#  ('C.H.U.D.', 1.6),
#  ('Conan the Destroyer', 1.72),
#  ('Dune', 2.95),
#  ('Firestarter', 1.9),
#  ('Footloose', 1.78),
#  ('Footloose', 1.78),
#  ('Friday the 13th: The Final Chapter', 1.62),
#  ('Gremlins', 1.77),
#  ('Indiana Jones and the Temple of Doom', 1.97),
#  ('Once Upon a Time in America', 4.18),
#  ('Police Academy', 1.6),
#  ('Red Dawn', 1.9),
#  ('Repo Man', 1.53),
#  ('Sheena', 1.95),
#  ('Splash', 1.85),
#  ('Star Trek III: The Search for Spock', 1.75),
#  ('The Bounty', 2.2),
#  ('The Cotton Club', 2.05),
#  ('The Hotel New Hampshire', 1.82),
#  ('The Ice Pirates', 1.52),
#  ('The Karate Kid', 2.1),
#  ('The Karate Kid', 2.1),
#  ('The NeverEnding Story', 1.57),
#  ('The Terminator', 1.78),
#  ('The Toxic Avenger', 1.52),
#  ("A Nightmare on Elm Street 2: Freddy's Revenge", 1.45),
#  ('A Room with a View', 1.95),
#  ('A View to a Kill', 2.18),
#  ('Back to the Future', 1.93),
#  ('Brazil', 2.37),
#  ('Commando', 1.25),
#  ('Day of the Dead', 1.45),
#  ('Day of the Dead', 1.45),
#  ('Def-Con 4', 1.47),
#  ('Friday the 13th: A New Beginning', 1.53),
#  ('Invasion U.S.A.', 1.78),
#  ('Krush Groove', 1.62),
#  ('Ladyhawke', 2.02),
#  ('Lifeforce', 1.68),
#  ('Mad Max Beyond Thunderdome', 1.78),
#  ('My Beautiful Laundrette', 1.62),
#  ('Out of Africa', 2.68),
#  ('Pale Rider', 1.92),
#  ('Rambo: First Blood Part II', 1.6),
#  ('Red Sonja', 1.48),
#  ('Return to Oz', 1.82),
#  ('Silverado', 2.22),
#  ('Subway', 1.63),
#  ('The Color Purple', 2.57),
#  ('The Last Dragon', 1.82),
#  ('The Return of the Living Dead', 1.8),
#  ('The Return of the Living Dead', 1.8),
#  ('Witness', 1.87),
#  ('Young Sherlock Holmes', 1.82),
#  ('9Â½ Weeks', 1.87),
#  ('Aliens', 2.57),
#  ("April Fool's Day", 1.48),
#  ('Big Trouble in Little China', 1.65),
#  ('Crocodile Dundee', 1.55),
#  ('Highlander', 1.83),
#  ('Howard the Duck', 1.83),
#  ('Invaders from Mars', 1.67),
#  ('Jason Lives: Friday the 13th Part VI', 1.43),
#  ('Legal Eagles', 1.93),
#  ('Little Shop of Horrors', 1.7),
#  ('Peggy Sue Got Married', 1.72),
#  ('Platoon', 2.0),
#  ("River's Edge", 1.65),
#  ('Salvador', 2.03),
#  ('Shanghai Surprise', 1.62),
#  ("She's Gotta Have It", 1.47),
#  ('Stand by Me', 1.48),
#  ('Star Trek IV: The Voyage Home', 1.98),
#  ('The Clan of the Cave Bear', 1.63),
#  ('The Color of Money', 1.98),
#  ('The Golden Child', 1.57),
#  ('The Texas Chainsaw Massacre 2', 1.68),
#  ('The Wraith', 1.55),
#  ('Top Gun', 1.83),
#  ('Witchboard', 1.63),
#  ('3 Men and a Baby', 1.7),
#  ('A Nightmare on Elm Street 3: Dream Warriors', 1.47),
#  ('American Ninja 2: The Confrontation', 1.5),
#  ('Beverly Hills Cop II', 1.67),
#  ('Creepshow 2', 1.42),
#  ('Cry Freedom', 2.45),
#  ('Evil Dead II', 0.62),
#  ('Fatal Attraction', 1.98),
#  ('From a Whisper to a Scream', 1.53),
#  ('Good Morning, Vietnam', 2.02),
#  ('Hellraiser', 1.43),
#  ('Hollywood Shuffle', 1.35),
#  ('Ishtar', 1.78),
#  ('Jaws: The Revenge', 1.53),
#  ('La Bamba', 1.8),
#  ('Malone', 1.53),
#  ('Maurice', 2.33),
#  ('Predator', 1.78),
#  ('Prison', 1.7),
#  ('Radio Days', 1.47),
#  ('Spaceballs', 1.6),
#  ('Superman IV: The Quest for Peace', 2.23),
#  ('Teen Wolf Too', 1.58),
#  ('The Barbarians', 1.45),
#  ('The Brave Little Toaster', 1.5),
#  ('The Last Emperor', 3.65),
#  ('The Living Daylights', 2.17),
#  ('The Lost Boys', 1.62),
#  ('The Princess Bride', 1.63),
#  ('The Running Man', 1.68),
#  ('The Untouchables', 1.98),
#  ('Wall Street', 2.1),
#  ('A Nightmare on Elm Street 4: The Dream Master', 1.65),
#  ('Action Jackson', 1.6),
#  ('Akira', 2.07),
#  ('Beetlejuice', 1.53),
#  ('Big', 2.17),
#  ('Bloodsport', 1.53),
#  ('Bright Lights, Big City', 1.78),
#  ("Child's Play", 1.45),
#  ('Crocodile Dundee II', 1.8),
#  ('Dangerous Liaisons', 1.98),
#  ('Dangerous Liaisons', 1.98),
#  ('Die Hard', 2.18),
#  ('Friday the 13th Part VII: The New Blood', 1.47),
#  ('Halloween 4: The Return of Michael Myers', 1.47),
#  ('Iguana', 1.62),
#  ('Lady in White', 1.97),
#  ('Midnight Run', 2.1),
#  ('My Stepmother Is an Alien', 1.75),
#  ('Mystic Pizza', 1.73),
#  ('Phantasm II', 1.62),
#  ('Poltergeist III', 1.63),
#  ('Rain Man', 2.22),
#  ('Rambo III', 1.45),
#  ('School Daze', 2.02),
#  ('Scrooged', 1.68),
#  ('Talk Radio', 1.83),
#  ('The Land Before Time', 1.15),
#  ('The Last Temptation of Christ', 2.73),
#  ('They Live', 1.55),
#  ('Twins', 1.78),
#  ('Young Guns', 1.78),
#  ('A Nightmare on Elm Street 5: The Dream Child', 1.48),
#  ('Back to the Future Part II', 1.8),
#  ('Batman', 2.1),
#  ("Bill & Ted's Excellent Adventure", 1.5),
#  ('Black Rain', 2.08),
#  ('Born on the Fourth of July', 2.42),
#  ('Dead Poets Society', 2.13),
#  ('Do the Right Thing', 2.0),
#  ('Driving Miss Daisy', 1.65),
#  ('Friday the 13th Part VIII: Jason Takes Manhattan', 1.67),
#  ('Glory', 2.03),
#  ('Glory', 2.03),
#  ('Halloween 5', 1.6),
#  ('Henry V', 2.28),
#  ('Indiana Jones and the Last Crusade', 2.12),
#  ('Licence to Kill', 2.22),
#  ('Major League', 1.78),
#  ('New York Stories', 2.07),
#  ('Pet Sematary', 1.72),
#  ('Road House', 1.9),
#  ('Roger & Me', 1.52),
#  ('Sea of Love', 1.88),
#  ('Sex, Lies, and Videotape', 1.67),
#  ('Star Trek V: The Final Frontier', 1.78),
#  ('Tango & Cash', 1.62),
#  ('The Abyss', 2.85),
#  ('The Blood of Heroes', 1.5),
#  ('The Toxic Avenger Part II', 1.6),
#  ('Troop Beverly Hills', 1.75),
#  ('UHF', 2.5),
#  ('Warlock', 1.72),
#  ("We're No Angels", 1.77),
#  ('When Harry Met Sally...', 1.48),
#  ('Arachnophobia', 1.72),
#  ('Back to the Future Part III', 1.97),
#  ("Child's Play 2", 1.2),
#  ('Dances with Wolves', 3.93),
#  ('Days of Thunder', 1.78),
#  ('Dick Tracy', 1.75),
#  ('Die Hard 2', 2.07),
#  ('Edward Scissorhands', 1.75),
#  ('Flatliners', 1.92),
#  ('Ghost', 2.12),
#  ('Goodfellas', 2.43),
#  ('Gremlins 2: The New Batch', 1.77),
#  ('Home Alone', 1.72),
#  ('Kindergarten Cop', 1.85),
#  ("Marilyn Hotchkiss' Ballroom Dancing and Charm School", 0.57),
#  ('Metropolitan', 1.63),
#  ('Midnight Cabaret', 1.57),
#  ("Mo' Better Blues", 2.15),
#  ('Predator 2', 1.72),
#  ('Pretty Woman', 2.08),
#  ('Quigley Down Under', 1.98),
#  ('Shipwrecked', 1.53),
#  ('Spaced Invaders', 1.67),
#  ('The Adventures of Ford Fairlane', 1.73),
#  ('The Godfather: Part III', 2.83),
#  ('The Hunt for Red October', 2.25),
#  ('Total Recall', 1.88),
#  ('Total Recall', 1.88),
#  ('Tremors', 1.6),
#  ('Two Evil Eyes', 2.0),
#  ('Beastmaster 2: Through the Portal of Time', 1.78),
#  ("Bill & Ted's Bogus Journey", 1.55),
#  ('Boyz n the Hood', 1.87),
#  ('Cape Fear', 2.13),
#  ('Double Impact', 1.83),
#  ('Flight of the Intruder', 1.92),
#  ("Freddy's Dead: The Final Nightmare", 1.55),
#  ('Harley Davidson and the Marlboro Man', 1.63),
#  ('Hook', 2.37),
#  ('House Party 2', 1.57),
#  ('Hudson Hawk', 1.67),
#  ('JFK', 3.43),
#  ('Johnny Suede', 1.62),
#  ('My Girl', 1.7),
#  ('My Own Private Idaho', 1.73),
#  ('Return to the Blue Lagoon', 1.7),
#  ('Robin Hood: Prince of Thieves', 2.58),
#  ('Showdown in Little Tokyo', 1.32),
#  ('Slacker', 1.67),
#  ('Star Trek VI: The Undiscovered Country', 1.83),
#  ('Stone Cold', 1.47),
#  ('Straight Out of Brooklyn', 1.52),
#  ('Teenage Mutant Ninja Turtles II: The Secret of the Ooze', 1.47),
#  ('Terminator 2: Judgment Day', 2.55),
#  ('The Addams Family', 1.65),
#  ('The Doors', 2.33),
#  ('The Fisher King', 2.28),
#  ('The Naked Gun 2Â½: The Smell of Fear', 1.42),
#  ('The Prince of Tides', 2.2),
#  ('The Silence of the Lambs', 2.3),
#  ('White Fang', 1.78),
#  ('A Few Good Men', 2.3),
#  ('A League of Their Own', 2.13),
#  ('Aladdin', 1.5),
#  ('Alien 3', 2.42),
#  ('Army of Darkness', 1.47),
#  ('Batman Returns', 2.1),
#  ('Boomerang', 1.95),
#  ("Bram Stoker's Dracula", 2.58),
#  ('Death Becomes Her', 1.73),
#  ('El Mariachi', 1.35),
#  ('Fortress', 1.58),
#  ('Glengarry Glen Ross', 1.67),
#  ('Hoffa', 2.33),
#  ('Home Alone 2: Lost in New York', 2.0),
#  ('Howards End', 2.33),
#  ('Lethal Weapon 3', 2.02),
#  ('Light Sleeper', 1.72),
#  ('Malcolm X', 3.37),
#  ('Medicine Man', 1.77),
#  ('Memoirs of an Invisible Man', 1.65),
#  ('My Cousin Vinny', 2.0),
#  ('Patriot Games', 1.95),
#  ('Radio Flyer', 1.9),
#  ('Raising Cain', 1.52),
#  ('Reservoir Dogs', 1.65),
#  ('Split Second', 1.6),
#  ('The Bodyguard', 2.15),
#  ('The Crying Game', 1.87),
#  ('The Last of the Mohicans', 1.95),
#  ('The Lawnmower Man', 2.33),
#  ('The Mighty Ducks', 1.67),
#  ('The Muppet Christmas Carol', 1.48),
#  ('Unforgiven', 2.18),
#  ("Wayne's World", 1.57),
#  ('Airborne', 1.52),
#  ('Alive', 2.0),
#  ('Blood In, Blood Out', 5.5),
#  ('Cliffhanger', 2.07),
#  ('Cool Runnings', 1.63),
#  ('Dazed and Confused', 1.7),
#  ('Ed and His Dead Mother', 1.55),
#  ('Excessive Force', 1.45),
#  ('Gettysburg', 4.52),
#  ('Groundhog Day', 1.68),
#  ('Hocus Pocus', 1.6),
#  ('Jason Goes to Hell: The Final Friday', 1.52),
#  ('Jurassic Park', 2.12),
#  ('Killing Zoe', 1.65),
#  ('Last Action Hero', 2.17),
#  ('Les visiteurs', 1.78),
#  ('Loaded Weapon 1', 1.4),
#  ('Madadayo', 2.23),
#  ('Menace II Society', 1.62),
#  ('Mrs. Doubtfire', 2.08),
#  ('Much Ado About Nothing', 1.85),
#  ('Nowhere to Run', 1.57),
#  ('Only the Strong', 1.65),
#  ('Philadelphia', 2.08),
#  ('Poetic Justice', 1.82),
#  ('Return of the Living Dead III', 1.62),
#  ('RoboCop 3', 1.73),
#  ('Romeo Is Bleeding', 1.67),
#  ('Ruby in Paradise', 1.9),
#  ("Schindler's List", 3.08),
#  ('Shadowlands', 1.92),
#  ('Sugar Hill', 2.05),
#  ('Super Mario Bros.', 1.73),
#  ('Teenage Mutant Ninja Turtles III', 1.6),
#  ('The Adventures of Huck Finn', 1.8),
#  ('The Age of Innocence', 2.32),
#  ('The Firm', 2.57),
#  ('The Fugitive', 2.17),
#  ('The Nutcracker', 1.53),
#  ('The Pelican Brief', 2.35),
#  ('The Piano', 2.02),
#  ('The Princess and the Cobbler', 1.33),
#  ('The Remains of the Day', 2.23),
#  ('Tombstone', 2.23),
#  ('True Romance', 2.02),
#  ('Warlock: The Armageddon', 1.63),
#  ("What's Eating Gilbert Grape", 1.97),
#  ("What's Love Got to Do with It", 1.97),
#  ('3 Ninjas Kick Back', 1.55),
#  ('A Low Down Dirty Shame', 1.67),
#  ('Ace Ventura: Pet Detective', 1.3),
#  ("Baby's Day Out", 1.65),
#  ('Beverly Hills Cop III', 1.73),
#  ('Bullets Over Broadway', 1.63),
#  ('Clear and Present Danger', 2.35),
#  ('Clerks', 1.7),
#  ('Crooklyn', 1.92),
#  ('Disclosure', 2.13),
#  ('Don Juan DeMarco', 1.62),
#  ('Dumb & Dumber', 1.88),
#  ('Ed Wood', 2.12),
#  ('Exotica', 1.72),
#  ('Forrest Gump', 2.37),
#  ('Four Weddings and a Funeral', 1.95),
#  ('Heavenly Creatures', 1.8),
#  ('Highlander: The Final Dimension', 1.65),
#  ('Hoop Dreams', 2.83),
#  ('Interview with the Vampire: The Vampire Chronicles', 2.05),
#  ('Legends of the Fall', 2.22),
#  ('Little Women', 1.92),
#  ('Men of War', 1.27),
#  ('Naked Gun 33 1/3: The Final Insult', 1.38),
#  ('New Nightmare', 1.78),
#  ('On Deadly Ground', 1.68),
#  ('PCU', 1.32),
#  ('Police Academy: Mission to Moscow', 1.38),
#  ('Pulp Fiction', 2.97),
#  ('Rapa Nui', 1.78),
#  ('Renaissance Man', 2.13),
#  ('RiÂ¢hie RiÂ¢h', 1.58),
#  ('Serial Mom', 1.58),
#  ('Speed', 1.93),
#  ('Star Trek: Generations', 1.97),
#  ('Street Fighter', 1.7),
#  ('The Client', 1.98),
#  ('The Crow', 1.63),
#  ('The Flintstones', 1.52),
#  ('The Hudsucker Proxy', 1.85),
#  ('The Inkwell', 1.83),
#  ('The Legend of Drunken Master', 1.7),
#  ('The Lion King', 1.22),
#  ('The Mask', 1.9),
#  ('The River Wild', 1.85),
#  ('The Santa Clause', 1.62),
#  ('The Shadow', 1.55),
#  ('The Shawshank Redemption', 2.37),
#  ('The Specialist', 1.83),
#  ('There Goes My Baby', 1.65),
#  ('Timecop', 1.65),
#  ('True Lies', 2.35),
#  ('Wolf', 2.08),
#  ('Wyatt Earp', 3.53),
#  ('Ace Ventura: When Nature Calls', 1.5),
#  ('Apollo 13', 2.33),
#  ('Assassins', 2.2),
#  ('Babe', 1.52),
#  ('Bad Boys', 1.98),
#  ('Bang', 1.63),
#  ('Batman Forever', 2.02),
#  ('Before Sunrise', 1.75),
#  ('Braveheart', 2.97),
#  ('Casino', 2.97),
#  ('Casper', 1.67),
#  ('Clueless', 1.62),
#  ('Congo', 1.82),
#  ('Copycat', 2.05),
#  ('Crimson Tide', 2.05),
#  ('Cutthroat Island', 2.07),
#  ('Dead Man Walking', 2.03),
#  ('Desperado', 1.73),
#  ('Die Hard with a Vengeance', 2.13),
#  ('First Knight', 2.23),
#  ('Four Rooms', 1.83),
#  ('Friday', 1.62),
#  ('Get Shorty', 1.75),
#  ('GoldenEye', 2.17),
#  ('Hackers', 1.78),
#  ('Halloween: The Curse of Michael Myers', 1.55),
#  ('Home for the Holidays', 1.72),
#  ('Jade', 1.78),
#  ('Jefferson in Paris', 2.32),
#  ('Kids', 1.52),
#  ('Kiss of Death', 1.68),
#  ('Leaving Las Vegas', 1.85),
#  ('Mallrats', 2.05),
#  ('Money Train', 1.75),
#  ('Mortal Kombat', 1.68),
#  ("Mr. Holland's Opus", 2.38),
#  ('Nixon', 3.53),
#  ('Outbreak', 2.12),
#  ('Pocahontas', 1.4),
#  ('Richard III', 1.73),
#  ('Rob Roy', 2.32),
#  ('Rumble in the Bronx', 1.48),
#  ('Se7en', 2.12),
#  ('Sense and Sensibility', 2.27),
#  ('Showgirls', 2.18),
#  ('Species', 1.8),
#  ('Tales from the Crypt: Demon Knight', 1.53),
#  ('Tales from the Hood', 1.63),
#  ('Tank Girl', 1.73),
#  ('The American President', 1.9),
#  ('The Bridges of Madison County', 2.25),
#  ('The Brothers McMullen', 1.63),
#  ('The Horseman on the Roof', 2.25),
#  ('The Incredibly True Adventure of Two Girls in Love', 1.57),
#  ('The Indian in the Cupboard', 1.6),
#  ('The Jerky Boys', 1.37),
#  ('The Net', 1.9),
#  ('The Perez Family', 1.88),
#  ('The Prophecy', 1.63),
#  ('The Quick and the Dead', 1.78),
#  ('The Scarlet Letter', 2.25),
#  ('The Usual Suspects', 1.77),
#  ("Things to Do in Denver When You're Dead", 1.92),
#  ('To Die For', 1.77),
#  ('Toy Story', 1.23),
#  ('Under Siege 2: Dark Territory', 1.53),
#  ('Vampire in Brooklyn', 1.67),
#  ('Virtuosity', 1.77),
#  ('Waterworld', 2.93),
#  ('Welcome to the Dollhouse', 1.47),
#  ('A Thin Line Between Love and Hate', 1.8),
#  ('A Time to Kill', 2.48),
#  ('Albino Alligator', 1.62),
#  ('Basquiat', 1.8),
#  ('Beavis and Butt-Head Do America', 1.35),
#  ('Blood and Wine', 1.68),
#  ('Bogus', 1.83),
#  ('Bottle Rocket', 1.52),
#  ('Bound', 1.82),
#  ('Broken Arrow', 1.8),
#  ('Chain Reaction', 1.78),
#  ('City Hall', 1.85),
#  ('Courage Under Fire', 1.93),
#  ('Daylight', 1.9),
#  ('DragonHeart', 1.72),
#  ('Eraser', 1.92),
#  ('Escape from L.A.', 1.68),
#  ('Everyone Says I Love You', 1.68),
#  ('Evita', 2.25),
#  ('Executive Decision', 2.22),
#  ('Extreme Measures', 1.97),
#  ('Eye for an Eye', 1.68),
#  ('Faithful', 1.52),
#  ('Fled', 1.75),
#  ('Flipper', 1.58),
#  ('Flirting with Disaster', 1.53),
#  ('Freeway', 1.7),
#  ('From Dusk Till Dawn', 1.8),
#  ('Get on the Bus', 2.0),
#  ('Ghosts of Mississippi', 2.17),
#  ('Girl 6', 1.8),
#  ('Hamlet', 2.5),
#  ('Hamlet', 2.5),
#  ('Happy Gilmore', 1.53),
#  ('Harriet the Spy', 1.67),
#  ('Independence Day', 2.57),
#  ('Jerry Maguire', 2.32),
#  ('Jingle All the Way', 1.57),
#  ('Kama Sutra: A Tale of Love', 1.82),
#  ('Kansas City', 1.93),
#  ('Kingpin', 1.95),
#  ('Lone Star', 2.25),
#  ('Love and Other Catastrophes', 1.27),
#  ('Mars Attacks!', 1.77),
#  ("Marvin's Room", 1.63),
#  ('Mary Reilly', 1.8),
#  ('Maximum Risk', 1.68),
#  ('Michael Collins', 2.22),
#  ('Mission: Impossible', 1.83),
#  ('Mrs. Winterbourne', 1.75),
#  ('Multiplicity', 1.95),
#  ('My Fellow Americans', 1.68),
#  ('Phenomenon', 2.05),
#  ('Ransom', 2.32),
#  ('Romeo + Juliet', 2.0),
#  ('Scream', 1.72),
#  ('Set It Off', 2.05),
#  ('Sgt. Bilko', 1.55),
#  ("She's the One", 1.6),
#  ('Shine', 1.75),
#  ('Silent Trigger', 1.47),
#  ('Sleepers', 2.45),
#  ('Sling Blade', 2.47),
#  ('Space Jam', 1.47),
#  ('Spy Hard', 1.35),
#  ('Star Trek: First Contact', 1.85),
#  ('Striptease', 1.95),
#  ('Swingers', 1.6),
#  ('That Thing You Do!', 2.48),
#  ('The Adventures of Pinocchio', 1.5),
#  ('The Cable Guy', 1.6),
#  ('The Craft', 1.68),
#  ('The Dress', 1.58),
#  ('The English Patient', 2.7),
#  ('The Fan', 1.93),
#  ('The First Wives Club', 1.72),
#  ('The Funeral', 1.65),
#  ('The Ghost and the Darkness', 1.83),
#  ('The Glimmer Man', 1.52),
#  ('The Hunchback of Notre Dame', 1.52),
#  ('The Island of Dr. Moreau', 1.65),
#  ('The Juror', 1.97),
#  ('The Last Big Thing', 1.63),
#  ('The Long Kiss Goodnight', 2.02),
#  ('The Mirror Has Two Faces', 2.03),
#  ('The Nutty Professor', 1.58),
#  ('The Pallbearer', 1.63),
#  ('The Phantom', 1.67),
#  ('The Rock', 2.27),
#  ('Thinner', 1.55),
#  ('Tin Cup', 2.25),
#  ('Trainspotting', 1.57),
#  ('Trees Lounge', 1.58),
#  ('Twister', 1.88),
#  ('Up Close & Personal', 2.07),
#  ('Waiting for Guffman', 1.4),
#  ('Walking and Talking', 1.43),
#  ("When the Cat's Away", 1.52),
#  ('White Squall', 2.15),
#  ('24 7: Twenty Four Seven', 1.6),
#  ('8 Heads in a Duffel Bag', 1.58),
#  ('A Simple Wish', 1.48),
#  ('Absolute Power', 2.02),
#  ('Air Bud', 1.63),
#  ('Air Force One', 2.07),
#  ('Alien: Resurrection', 1.93),
#  ('Amistad', 2.58),
#  ('An Alan Smithee Film: Burn Hollywood Burn', 1.43),
#  ('Anaconda', 1.48),
#  ('Anastasia', 1.57),
#  ('As Good as It Gets', 2.32),
#  ('Austin Powers: International Man of Mystery', 1.13),
#  ('Batman & Robin', 2.08),
#  ('Boogie Nights', 2.58),
#  ('Breakdown', 1.55),
#  ("Cats Don't Dance", 1.25),
#  ('Character', 2.03),
#  ('Chasing Amy', 1.88),
#  ('Children of Heaven', 1.48),
#  ('Clockwatchers', 1.6),
#  ('Con Air', 2.05),
#  ('Conspiracy Theory', 2.25),
#  ('Contact', 2.5),
#  ('Cop Land', 2.0),
#  ('Critical Care', 1.78),
#  ('Cube', 1.5),
#  ("Dante's Peak", 1.8),
#  ('Deconstructing Harry', 1.6),
#  ('DÃ©jÃ  Vu', 1.95),
#  ('Donnie Brasco', 2.45),
#  ('Dream with the Fishes', 1.62),
#  ("Eve's Bayou", 1.82),
#  ('Event Horizon', 2.17),
#  ('Face/Off', 2.3),
#  ('First Love, Last Rites', 1.57),
#  ('Flubber', 1.5),
#  ('G.I. Jane', 2.08),
#  ('Gattaca', 1.77),
#  ('George of the Jungle', 1.53),
#  ('Good Will Hunting', 2.1),
#  ('Grosse Pointe Blank', 1.78),
#  ('Hav Plenty', 1.4),
#  ('How to Be a Player', 1.55),
#  ('Hurricane Streets', 1.43),
#  ('I Know What You Did Last Summer', 1.65),
#  ("I Love You, Don't Touch Me!", 1.43),
#  ('I Married a Strange Person!', 1.25),
#  ('In & Out', 1.5),
#  ('In the Company of Men', 1.62),
#  ('Jackie Brown', 2.57),
#  ('Kiss the Girls', 1.92),
#  ('Kundun', 2.23),
#  ('L.A. Confidential', 2.3),
#  ('Liar Liar', 1.43),
#  ('Love and Death on Long Island', 1.55),
#  ('Love Jones', 1.73),
#  ('Mad City', 1.92),
#  ('Men in Black', 1.63),
#  ('Midnight in the Garden of Good and Evil', 2.58),
#  ('Money Talks', 1.62),
#  ('Mortal Kombat: Annihilation', 1.58),
#  ('Mr. Nice Guy', 1.43),
#  ("My Best Friend's Wedding", 1.75),
#  ('Nothing to Lose', 1.63),
#  ('Orgazmo', 1.53),
#  ('Oscar and Lucinda', 2.2),
#  ('Prefontaine', 1.77),
#  ('Princess Mononoke', 2.23),
#  ('Scream 2', 2.0),
#  ('Selena', 2.12),
#  ('Seven Years in Tibet', 2.27),
#  ('Shadow Conspiracy', 1.72),
#  ('Shooting Fish', 1.65),
#  ("Smilla's Sense of Snow", 2.02),
#  ('Snow White: A Tale of Terror', 1.67),
#  ('Soul Food', 1.92),
#  ('Sparkler', 1.5),
#  ('Spawn', 1.63),
#  ('Speed 2: Cruise Control', 2.02),
#  ('Spice World', 1.55),
#  ('Starship Troopers', 2.15),
#  ('Steel', 1.62),
#  ...]

# %%
print('Ok_')
# Out:
# Ok_

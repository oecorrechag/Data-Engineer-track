# %% [markdown]
# #  12.1.0 Introduction to Cloud Computing
#
# ## 12.1.2 Understanding the cloud
#
# ![image.png](attachment:image.png)
#
# Question:
#
# Which statement about cloud computing is false?
#
# R:/ A cloud solution is always better than an on-premise solution. Some use cases require an on-premise solution.
#
# ## 12.1.3 Cloud vs. on-premise
#
# ![image-2.png](attachment:image-2.png)
#
# ## 12.1.4 Cloud computing services
#
# Question:
#
# Which service is included in the AWS offer?
#
# R:/ All of the above
#
# ## 12.1.5 Primary cloud services
#
# ![image-3.png](attachment:image-3.png)
#
# ## 12.1.6 Key characteristics
#
# ![image-5.png](attachment:image-5.png)
#
# ## 12.1.7 Outsourcing IT services
#
# ![image-4.png](attachment:image-4.png)
#
# ## 12.1.8 IaaS, PaaS, or SaaS?
#
# ![image-6.png](attachment:image-6.png)
#
#
# ## 12.1.9 Level of abstraction
#
# ![image-7.png](attachment:image-7.png)

# %%
print('Ok_')
# Out:
# Ok_

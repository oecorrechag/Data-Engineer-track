# %% [markdown]
# #  12.3.0 Cloud Providers and Case Studies
#
# ## 12.3.2 AWS
#
# Question:
#
# What does AWS stand for?
#
# R:/ Amazon Web Services
#
# ## 12.3.3 NerdWallet
#
# Question:
#
# What was the outcome of NerdWallet's move to Amazon SageMaker?
#
# R:/ Models now take days to train instead of months. Faster training times means the engineering team can iterate and improve the product.
#
# ## 12.3.5 The Ottawa hospital
#
# Question:
#
# Why did the Ottawa hospital decide to use Microsoft Azure Site Recovery?
#
# R:/ They needed a reliable solution to protect their data and essential operations in the event of a disaster.
#
# ## 12.3.6 That doesn't seem right
#
# Question:
#
# Which of the following statements is false?
#
# R:/ Azure Blob Storage is a database service. Azure Blob Storage is actually a file storage service. Azure SQL Database is the database solution that was presented in the video for Microsoft Azure. In general, if the service name contains "blob", it's very likely a file storage solution.
#
#
# ## 12.3.8 Lush migration
#
# Question:
#
# What was the expected outcome?
#
# R:/ Lush wanted to improve the scalability and availability of their e-commerce platform when traffic increases. Lush had experienced website outages on their e-commerce platform during the previous Boxing Day, and wanted to prevent this situation from happening again.
#
# ## 12.3.9 True or false?
#
# ![image.png](attachment:image.png)
#
# ## 12.3.11 State of the competition
#
# ![image-2.png](attachment:image-2.png)
#
# ## 12.3.12 Cloud providers and their services
#
# ![image-3.png](attachment:image-3.png)

# %%
print('Ok_')
# Out:
# Ok_
